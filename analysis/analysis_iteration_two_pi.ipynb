# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "2_Iteration_Two_PI" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.9999938787278 €/MWh
# Price statistics: {'mean': 60.89947342839347, 'median': 64.2889652147962, 'std_dev': 155.81546296255627, 'min': 0.019959219366284617, 'max': 3999.9999938787278}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 4038.8283675481644 MW
# Total installed offshore DC capacity: 41759.86539672803 MW
# Total installed offshore floating capacity: 0.42177183381299516 MW
# Total installed onshore wind capacity: 44178.88782658912 MW
# Total installed solar capacity: 107.05770837083855 MW
# Total installed solar HSAT capacity: 163499.71772305222 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 22021.428250788336 MW
# Total installed OCGT capacity: 53781.84339598409 MW
# Total installed battery capacity: 17510.904678818937 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 38553.83887298615 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 569357184.8322728 MWh
# Total offshore DC generation: 6557553528.479972 MWh
# Total offshore floating generation: 35627.27149385006 MWh
# Total onshore wind generation: 3892799042.682422 MWh
# Total solar generation: 2776111.6660560034 MWh
# Total solar HSAT generation: 7182179359.9562435 MWh
# Total CCGT generation: 2383928545.5012627 MWh
# Total OCGT generation: 1228657283.5438378 MWh
# Total battery discharge: -42744158.595948115 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1856030.1874374454 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.236729e+06
# DE0 0 1 onwind    3.131865e+06
# DE0 0 2 onwind    3.117311e+06
# DE0 0 3 onwind    3.107271e+06
# DE0 0 4 onwind    3.099764e+06
# DE0 0 5 onwind    3.095990e+06
# DE0 0 6 onwind    3.085633e+06
# DE0 0 7 onwind    3.080336e+06
# DE0 0 8 onwind    3.068244e+06
# DE0 0 9 onwind    3.062136e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.585184e+06
# DE0 0 1 offwind-ac    6.589784e+06
# DE0 0 2 offwind-ac    6.840020e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.325883e+06
# DE0 0 2 offwind-dc    7.355536e+06
# DE0 0 3 offwind-dc    8.034543e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    9.681747e+06
# DE0 0 1 offwind-float    9.548042e+06
# DE0 0 2 offwind-float    9.902798e+06
# DE0 0 3 offwind-float    1.090072e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.102925e+06
# DE0 0 1 solar    1.102616e+06
# DE0 0 2 solar    1.102540e+06
# DE0 0 3 solar    1.102403e+06
# DE0 0 4 solar    1.102511e+06
# DE0 0 5 solar    1.102280e+06
# DE0 0 6 solar    1.102687e+06
# DE0 0 7 solar    1.103992e+06
# DE0 0 8 solar    1.103582e+06
# DE0 0 9 solar    1.104588e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.277491e+06
# DE0 0 1 solar-hsat    1.277138e+06
# DE0 0 2 solar-hsat    1.277172e+06
# DE0 0 3 solar-hsat    1.276957e+06
# DE0 0 4 solar-hsat    1.276567e+06
# DE0 0 5 solar-hsat    1.276263e+06
# DE0 0 6 solar-hsat    1.276119e+06
# DE0 0 7 solar-hsat    1.276926e+06
# DE0 0 8 solar-hsat    1.276275e+06
# DE0 0 9 solar-hsat    1.277448e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        0.281074
# DE0 0 1 onwind        0.736157
# DE0 0 2 onwind        1.087462
# DE0 0 3 onwind        1.660586
# DE0 0 4 onwind        2.157589
# DE0 0 5 onwind        2.226082
# DE0 0 6 onwind        6.801866
# DE0 0 7 onwind     6069.288380
# DE0 0 8 onwind    21592.121467
# DE0 0 9 onwind    16502.527164
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.284935
# DE0 0 1 offwind-ac    1328.859711
# DE0 0 2 offwind-ac    2709.683722
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.799054
# DE0 0 2 offwind-dc    13833.537102
# DE0 0 3 offwind-dc    27922.529241
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.100143
# DE0 0 1 offwind-float    0.100324
# DE0 0 2 offwind-float    0.110426
# DE0 0 3 offwind-float    0.110879
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar     7.822307
# DE0 0 1 solar     9.569342
# DE0 0 2 solar    10.261863
# DE0 0 3 solar    10.914195
# DE0 0 4 solar     9.779560
# DE0 0 5 solar     9.676515
# DE0 0 6 solar    10.605623
# DE0 0 7 solar    13.593056
# DE0 0 8 solar    16.270918
# DE0 0 9 solar     8.564330
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       53.228749
# DE0 0 1 solar-hsat       55.941381
# DE0 0 2 solar-hsat      318.127393
# DE0 0 3 solar-hsat     2356.392743
# DE0 0 4 solar-hsat       92.274018
# DE0 0 5 solar-hsat       40.119698
# DE0 0 6 solar-hsat    37943.016851
# DE0 0 7 solar-hsat    34557.761670
# DE0 0 8 solar-hsat    43254.239078
# DE0 0 9 solar-hsat    44828.616142
# Name: p_nom_opt, dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17510.904679
# DE0 0 H2             0.652903
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 954112649.1495165 MWh
# Total PHS output: 430448325.2380353 MWh
# Total H2 output: 10641.483904107596 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['pi'])

# %%
importlib.reload(af)
scenario = 'pi'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pi: 4227411.3358657835
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pi: 5649940.645839569
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pi: 6620038.733475053
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pi: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pi: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pi: 6570546.215599847
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pi: 6625061.142125455
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pi: 6889581.8582907105
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pi: 1461114.2334786365
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pi: 2258978.309359988
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pi: 3095044.4935560892
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pi: 3379818.717707653
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario pi: 1070820.6730737193
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario pi: 1782927.561862079
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario pi: 1980954.4167638489
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario pi: 2142089.204603558
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario pi: 2218102.814793024
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario pi: 2234628.022213182
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario pi: 2436366.487452083
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario pi: 2555728.067500865
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 8, scenario pi: 2799158.984972354
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 9, scenario pi: 3743587.667553357
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 0, scenario pi: 1176985.4203152775
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 1, scenario pi: 1188759.0349814063
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 2, scenario pi: 1192339.512729966
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 3, scenario pi: 1195861.0090371368
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 4, scenario pi: 1190929.411336467
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 5, scenario pi: 1191037.597243392
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 6, scenario pi: 1197632.4032173173
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 7, scenario pi: 1212207.7894881472
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 8, scenario pi: 1256240.6236182966
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 9, scenario pi: 1344502.9888568742
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario pi: 1440334.171637369
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario pi: 1440584.1878354133
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario pi: 1455412.2946570942
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario pi: 1459326.4683597733
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario pi: 1446649.4596342791
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario pi: 1434766.573597062
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario pi: 1459452.916414773
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario pi: 1460512.0371423508
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario pi: 1495080.801893359
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario pi: 1609328.0177895287
# -----------------------------------

# %%
importlib.reload(af)
scenario = 'pi'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):  
        risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Relative revenue risk per MW of {carrier}, rc {rc}, scenario {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pi: 0.038954572400564755
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pi: 0.013138464430061132
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pi: 0.006853693182322992
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pi: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pi: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pi: 0.014572412326174582
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pi: 0.008654830539468824
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pi: 0.006816694709837274
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario pi: 0.07415033143298347
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario pi: 0.016357535032383557
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario pi: 0.024656455077304996
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario pi: 0.02999525158563206
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario pi: 0.1798471301148769
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario pi: 0.0859419635972585
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario pi: 0.07183838318207574
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario pi: 0.06191577174794046
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario pi: 0.054592713686225064
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario pi: 0.05088549933131459
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario pi: 0.040212246954099674
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario pi: 0.034833896942698464
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario pi: 0.023258357401880477
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario pi: 0.016282592889846202
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario pi: 0.008194485209518213
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario pi: 0.00754326143669154
# -----------------------------------
# Relative revenue risk per MW of solar, rc 2, scenario pi: 0.007228363727673894
# -----------------------------------
# Relative revenue risk per MW of solar, rc 3, scenario pi: 0.007107278204189751
# -----------------------------------
# Relative revenue risk per MW of solar, rc 4, scenario pi: 0.007919286331215126
# -----------------------------------
# Relative revenue risk per MW of solar, rc 5, scenario pi: 0.0066067016150625525
# -----------------------------------
# Relative revenue risk per MW of solar, rc 6, scenario pi: 0.007983538196053925
# -----------------------------------
# Relative revenue risk per MW of solar, rc 7, scenario pi: 0.012636633849725536
# -----------------------------------
# Relative revenue risk per MW of solar, rc 8, scenario pi: 0.010817565324750734
# -----------------------------------
# Relative revenue risk per MW of solar, rc 9, scenario pi: 0.012653636340482789
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 0, scenario pi: 0.011513884394500984
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 1, scenario pi: 0.010554736272762396
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 2, scenario pi: 0.01065137264802475
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 3, scenario pi: 0.010085690953926313
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 4, scenario pi: 0.00912294221805371
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 5, scenario pi: 0.008262398142790034
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 6, scenario pi: 0.007801135083972584
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 7, scenario pi: 0.010215512852880977
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 8, scenario pi: 0.008406357427441849
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 9, scenario pi: 0.011496723264039495
# -----------------------------------

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='pi')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PI/my_plots/revenue_violin_plot_onwind_rc8.png

# %%
importlib.reload(af)
scenario = 'pi'
af.calculate_annual_state_cfd_payments(run_name, n, scenario=scenario)
avg = af.average_state_cfd_payments(run_name, n, scenario=scenario)
print(f"Average state CfD payments for scenario {scenario}: {avg} €")
std = af.std_dev_state_cfd_payments(run_name, n, scenario=scenario)
print(f"Standard deviation of state CfD payments for scenario {scenario}: {std} €/year")
print('-----------------------------------')
# Out:
# Average state CfD payments for scenario pi: -1.4168875558035715e-06 €
# Standard deviation of state CfD payments for scenario pi: 5855259981.894644 €/year
# -----------------------------------

# %%
importlib.reload(af)
scenario = 'pi'
af.plot_annual_state_CfD_payments(run_name, scenario=scenario, cap=130, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PI/my_plots/annual_state_CfD_payments_pi.png

# %%
importlib.reload(af)
scenario = 'pi'
af.plot_wind_vs_solar_cfd_payments(run_name, scenario=scenario, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PI/my_plots/wind_vs_solar_cfd_payments_pi.png
