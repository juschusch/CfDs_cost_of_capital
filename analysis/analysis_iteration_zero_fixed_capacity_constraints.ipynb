# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "0_Iteration_Zero_No_VOLL" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.2.0 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 1670097.7806802941 €/MWh
# Price statistics: {'mean': 64.6965269057497, 'median': 64.29465071418147, 'std_dev': 3016.5405147736133, 'min': 0.02003133827936384, 'max': 1670097.7806802941}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
# load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
# print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 2711.6627233292447 MW
# Total installed offshore DC capacity: 44021.16370002794 MW
# Total installed offshore floating capacity: 0.4439132513388747 MW
# Total installed onshore wind capacity: 38100.17008325516 MW
# Total installed solar capacity: 31.84516907795078 MW
# Total installed solar HSAT capacity: 148674.33446671872 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 22884.25134943469 MW
# Total installed OCGT capacity: 69515.76885497177 MW
# Total installed battery capacity: 22865.48704364461 MW
# Total installed hydrogen capacity: 0.0 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
# load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
# print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 403052316.3548963 MWh
# Total offshore DC generation: 6769506502.45303 MWh
# Total offshore floating generation: 41959.79113678912 MWh
# Total onshore wind generation: 3688222908.3669786 MWh
# Total solar generation: 969230.6065196638 MWh
# Total solar HSAT generation: 6983761880.12214 MWh
# Total CCGT generation: 2598384110.3047853 MWh
# Total OCGT generation: 1192184503.9615264 MWh
# Total battery discharge: -44695969.988024846 MWh
# Total hydrogen discharge: 0.0 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        0.199601
# DE0 0 1 onwind        0.269347
# DE0 0 2 onwind        0.324790
# DE0 0 3 onwind        0.438854
# DE0 0 4 onwind        0.565968
# DE0 0 5 onwind        0.636156
# DE0 0 6 onwind        1.046573
# DE0 0 7 onwind        2.030085
# DE0 0 8 onwind    21592.106457
# DE0 0 9 onwind    16502.552251
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.162594
# DE0 0 1 offwind-ac       1.787943
# DE0 0 2 offwind-ac    2709.712186
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.802766
# DE0 0 2 offwind-dc    13833.535316
# DE0 0 3 offwind-dc    30183.825617
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.101648
# DE0 0 1 offwind-float    0.102217
# DE0 0 2 offwind-float    0.132465
# DE0 0 3 offwind-float    0.107584
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar    1.938288
# DE0 0 1 solar    2.179876
# DE0 0 2 solar    2.409810
# DE0 0 3 solar    2.607225
# DE0 0 4 solar    2.717130
# DE0 0 5 solar    3.121239
# DE0 0 6 solar    3.702572
# DE0 0 7 solar    4.448686
# DE0 0 8 solar    5.553930
# DE0 0 9 solar    3.166414
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat        3.550924
# DE0 0 1 solar-hsat        3.857654
# DE0 0 2 solar-hsat        6.330390
# DE0 0 3 solar-hsat        8.107346
# DE0 0 4 solar-hsat        6.667761
# DE0 0 5 solar-hsat        6.320003
# DE0 0 6 solar-hsat    18962.283440
# DE0 0 7 solar-hsat    41578.288302
# DE0 0 8 solar-hsat    43264.903912
# DE0 0 9 solar-hsat    44834.024735
# Name: p_nom_opt, dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    22865.487044
# DE0 0 H2             0.103168
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 1069957187.0451652 MWh
# Total PHS output: 346643227.79138 MWh
# Total H2 output: 1355.3549442412746 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['pc'])

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['pc', 'mb', 'pb', 'pi', 'cb']:    
            avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pc: 4323583.156183902
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario mb: 4455175.303296147
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pb: 4454660.512647017
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pi: 4454040.461600949
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario cb: 4453767.996606909
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pc: 5769336.6637166925
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario mb: 5952331.977879691
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pb: 5951668.332954873
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pi: 5951197.136184492
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario cb: 5950924.671190454
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pc: 6799947.247421541
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario mb: 7019468.31333212
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pb: 7018333.12363179
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pi: 7018333.471636922
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario cb: 7018061.006642882
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pc: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario mb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pi: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pc: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario mb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pi: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pc: 6689588.047929839
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario mb: 6916125.107006059
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pb: 6915574.551368915
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pi: 6914836.264460579
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario cb: 6914182.649502293
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pc: 6889764.679223201
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario mb: 7106017.68380749
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pb: 7104594.569277044
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pi: 7104728.84126201
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario cb: 7104075.226303726
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pc: 7152450.222985478
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario mb: 7380186.669459838
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pb: 7378971.546921829
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pi: 7378897.826914357
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario cb: 7378244.211956073
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pc: 1763646.237050941
# Average lifetime revenue per MW of offwind-float, rc 0, scenario mb: 1806920.558833752
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pb: 1810021.3123722195
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pi: 1812001.9382326705
# Average lifetime revenue per MW of offwind-float, rc 0, scenario cb: 1812002.6190495712
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pc: 2522164.64096967
# Average lifetime revenue per MW of offwind-float, rc 1, scenario mb: 2588416.5266870856
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pb: 2592916.5320635187
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pi: 2593497.906086005
# Average lifetime revenue per MW of offwind-float, rc 1, scenario cb: 2593498.586902905
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pc: 3400355.30503018
# Average lifetime revenue per MW of offwind-float, rc 2, scenario mb: 3496236.9099180405
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pb: 3502170.184096977
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pi: 3501318.289316959
# Average lifetime revenue per MW of offwind-float, rc 2, scenario cb: 3501318.9701338606
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pc: 3781287.7915246515
# Average lifetime revenue per MW of offwind-float, rc 3, scenario mb: 3884669.2994492417
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pb: 3891103.443780408
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pi: 3889750.67884816
# Average lifetime revenue per MW of offwind-float, rc 3, scenario cb: 3889751.3596650604
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario pc: 957581.0482751541
# Average lifetime revenue per MW of onwind, rc 0, scenario mb: 996053.1877430115
# Average lifetime revenue per MW of onwind, rc 0, scenario pb: 995756.9821875015
# Average lifetime revenue per MW of onwind, rc 0, scenario pi: 995244.0874893866
# Average lifetime revenue per MW of onwind, rc 0, scenario cb: 995232.685573467
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario pc: 1731470.2233521137
# Average lifetime revenue per MW of onwind, rc 1, scenario mb: 1796112.1895119403
# Average lifetime revenue per MW of onwind, rc 1, scenario pb: 1795689.2615782707
# Average lifetime revenue per MW of onwind, rc 1, scenario pi: 1795303.0892583157
# Average lifetime revenue per MW of onwind, rc 1, scenario cb: 1795291.6873423958
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario pc: 1919929.020451983
# Average lifetime revenue per MW of onwind, rc 2, scenario mb: 1988907.1143142162
# Average lifetime revenue per MW of onwind, rc 2, scenario pb: 1988395.7864403732
# Average lifetime revenue per MW of onwind, rc 2, scenario pi: 1988098.0140605918
# Average lifetime revenue per MW of onwind, rc 2, scenario cb: 1988086.6121446716
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario pc: 2124246.6227923776
# Average lifetime revenue per MW of onwind, rc 3, scenario mb: 2196223.9871633337
# Average lifetime revenue per MW of onwind, rc 3, scenario pb: 2195617.809782755
# Average lifetime revenue per MW of onwind, rc 3, scenario pi: 2195414.886909709
# Average lifetime revenue per MW of onwind, rc 3, scenario cb: 2195403.484993789
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario pc: 2286804.0256493883
# Average lifetime revenue per MW of onwind, rc 4, scenario mb: 2359081.854512284
# Average lifetime revenue per MW of onwind, rc 4, scenario pb: 2358503.263849996
# Average lifetime revenue per MW of onwind, rc 4, scenario pi: 2358272.7542586597
# Average lifetime revenue per MW of onwind, rc 4, scenario cb: 2358261.3523427397
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario pc: 2349190.570038222
# Average lifetime revenue per MW of onwind, rc 5, scenario mb: 2420265.8517250014
# Average lifetime revenue per MW of onwind, rc 5, scenario pb: 2419782.4089009087
# Average lifetime revenue per MW of onwind, rc 5, scenario pi: 2419456.751471377
# Average lifetime revenue per MW of onwind, rc 5, scenario cb: 2419445.3495554575
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario pc: 2554377.7711185035
# Average lifetime revenue per MW of onwind, rc 6, scenario mb: 2630261.466695409
# Average lifetime revenue per MW of onwind, rc 6, scenario pb: 2629634.8771235086
# Average lifetime revenue per MW of onwind, rc 6, scenario pi: 2629452.366441784
# Average lifetime revenue per MW of onwind, rc 6, scenario cb: 2629440.9645258645
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario pc: 2715924.538044223
# Average lifetime revenue per MW of onwind, rc 7, scenario mb: 2795117.7763900245
# Average lifetime revenue per MW of onwind, rc 7, scenario pb: 2794343.9601852875
# Average lifetime revenue per MW of onwind, rc 7, scenario pi: 2794308.6761363987
# Average lifetime revenue per MW of onwind, rc 7, scenario cb: 2794297.2742204797
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 8, scenario pc: 3043954.519581728
# Average lifetime revenue per MW of onwind, rc 8, scenario mb: 3131466.256428141
# Average lifetime revenue per MW of onwind, rc 8, scenario pb: 3130658.8677958255
# Average lifetime revenue per MW of onwind, rc 8, scenario pi: 3130657.1561745163
# Average lifetime revenue per MW of onwind, rc 8, scenario cb: 3130645.7542585963
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 9, scenario pc: 4033479.281422058
# Average lifetime revenue per MW of onwind, rc 9, scenario mb: 4150616.196780948
# Average lifetime revenue per MW of onwind, rc 9, scenario pb: 4149808.283452565
# Average lifetime revenue per MW of onwind, rc 9, scenario pi: 4149807.096527324
# Average lifetime revenue per MW of onwind, rc 9, scenario cb: 4149795.6946114046
# -----------------------------------
# Average lifetime revenue per MW of solar, rc
# Relative revenue risk per MW of offwind-ac, rc 1, scenario mb: 0.07817016401984633
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pb: 0.008388048371774042
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pi: 0.015807268192363232
# Relative revenue risk per MW of offwind-ac, rc 1, scenario cb: 0.012597138644763499
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pc: 0.062481199384439405
# Relative revenue risk per MW of offwind-ac, rc 2, scenario mb: 0.07653403873894005
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pb: 0.00674734549726136
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pi: 0.006745417854351318
# Relative revenue risk per MW of offwind-ac, rc 2, scenario cb: 8.585219659506687e-06
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pc: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario mb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pi: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pc: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario mb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pi: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pc: 0.06228657752921977
# Relative revenue risk per MW of offwind-dc, rc 1, scenario mb: 0.07688135263203337
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pb: 0.0072716085196993865
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pi: 0.01028960217879458
# Relative revenue risk per MW of offwind-dc, rc 1, scenario cb: 0.00903896650773707
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pc: 0.06179550782856855
# Relative revenue risk per MW of offwind-dc, rc 2, scenario mb: 0.07549482287372257
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pb: 0.0076812644420895465
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pi: 0.008802217984219962
# Relative revenue risk per MW of offwind-dc, rc 2, scenario cb: 0.0033640310841730366
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pc: 0.062060059609968
# Relative revenue risk per MW of offwind-dc, rc 3, scenario mb: 0.07592214263416265
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pb: 0.007270265535512146
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pi: 0.007012159928838598
# Relative revenue risk per MW of offwind-dc, rc 3, scenario cb: 0.0014847957085834227
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario pc: 0.08366128989148641
# Relative revenue risk per MW of offwind-float, rc 0, scenario mb: 0.09759939591575229
# Relative revenue risk per MW of offwind-float, rc 0, scenario pb: 0.015460156671928318
# Relative revenue risk per MW of offwind-float, rc 0, scenario pi: 0.06070546580537781
# Relative revenue risk per MW of offwind-float, rc 0, scenario cb: 0.0637243855528526
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario pc: 0.08438976578241668
# Relative revenue risk per MW of offwind-float, rc 1, scenario mb: 0.09931149141269902
# Relative revenue risk per MW of offwind-float, rc 1, scenario pb: 0.013552407308317155
# Relative revenue risk per MW of offwind-float, rc 1, scenario pi: 0.01673945970579525
# Relative revenue risk per MW of offwind-float, rc 1, scenario cb: 0.014257918668794715
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario pc: 0.08103072636534574
# Relative revenue risk per MW of offwind-float, rc 2, scenario mb: 0.09713309162202707
# Relative revenue risk per MW of offwind-float, rc 2, scenario pb: 0.011386248207922415
# Relative revenue risk per MW of offwind-float, rc 2, scenario pi: 0.019936064541038686
# Relative revenue risk per MW of offwind-float, rc 2, scenario cb: 0.014364271326134338
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario pc: 0.08055229083933746
# Relative revenue risk per MW of offwind-float, rc 3, scenario mb: 0.09589443807374874
# Relative revenue risk per MW of offwind-float, rc 3, scenario pb: 0.01087031519921534
# Relative revenue risk per MW of offwind-float, rc 3, scenario pi: 0.025639830085392445
# Relative revenue risk per MW of offwind-float, rc 3, scenario cb: 0.0218921057057521
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario pc: 0.06382587651753757
# Relative revenue risk per MW of onwind, rc 0, scenario mb: 0.08051323433797086
# Relative revenue risk per MW of onwind, rc 0, scenario pb: 0.020104827291338462
# Relative revenue risk per MW of onwind, rc 0, scenario pi: 0.2138423106011835
# Relative revenue risk per MW of onwind, rc 0, scenario cb: 0.19078832875947144
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario pc: 0.05590772483651538
# Relative revenue risk per MW of onwind, rc 1, scenario mb: 0.07143770028792679
# Relative revenue risk per MW of onwind, rc 1, scenario pb: 0.02383462550239898
# Relative revenue risk per MW of onwind, rc 1, scenario pi: 0.09603399104402291
# Relative revenue risk per MW of onwind, rc 1, scenario cb: 0.08295860970447176
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario pc: 0.054627402094013115
# Relative revenue risk per MW of onwind, rc 2, scenario mb: 0.06999641959899541
# Relative revenue risk per MW of onwind, rc 2, scenario pb: 0.021271293931574304
# Relative revenue risk per MW of onwind, rc 2, scenario pi: 0.08024399563091411
# Relative revenue risk per MW of onwind, rc 2, scenario cb: 0.06846980251619036
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario pc: 0.05424960843607666
# Relative revenue risk per MW of onwind, rc 3, scenario mb: 0.06889461719297577
# Relative revenue risk per MW of onwind, rc 3, scenario pb: 0.019602317458361256
# Relative revenue risk per MW of onwind, rc 3, scenario pi: 0.0669614397587782
# Relative revenue risk per MW of onwind, rc 3, scenario cb: 0.055887962539719796
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario pc: 0.05595558299959031
# Relative revenue risk per MW of onwind, rc 4, scenario mb: 0.0697033500543065
# Relative revenue risk per MW of onwind, rc 4, scenario pb: 0.018775511217712634
# Relative revenue risk per MW of onwind, rc 4, scenario pi: 0.05730521689228653
# Relative revenue risk per MW of onwind, rc 4, scenario cb: 0.04581936519201198
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario pc: 0.057953476348241606
# Relative revenue risk per MW of onwind, rc 5, scenario mb: 0.07116492856754454
# Relative revenue risk per MW of onwind, rc 5, scenario pb: 0.01785604555442854
# Relative revenue risk per MW of onwind, rc 5, scenario pi: 0.052495035123841884
# Relative revenue risk per MW of onwind, rc 5, scenario cb: 0.040563544529812104
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario pc: 0.057166984051154605
# Relative revenue risk per MW of onwind, rc 6, scenario mb: 0.07016475529940139
# Relative revenue risk per MW of onwind, rc 6, scenario pb: 0.016273703599453227
# Relative revenue risk per MW of onwind, rc 6, scenario pi: 0.042898057655453264
# Relative revenue risk per MW of onwind, rc 6, scenario cb: 0.03179761670862702
# -----------------------------------
# Relative revenue risk per MW of onwind, rc
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1260: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pc: 0.029209199130192015
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario cb: 0.07
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1260: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pc: 0.01859681309784364
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario cb: 0.07
# -----------------------------------
# Updated WACC for offwind-dc, rc 1, scenario pc: 0.06524394426993851
# Updated WACC for offwind-dc, rc 1, scenario mb: 0.06039117355274421
# Updated WACC for offwind-dc, rc 1, scenario pb: 0.05776747064500985
# Updated WACC for offwind-dc, rc 1, scenario pi: 0.05787884229832326
# Updated WACC for offwind-dc, rc 1, scenario cb: 0.05783266489316427
# -----------------------------------
# Updated WACC for offwind-dc, rc 2, scenario pc: 0.06484264235444984
# Updated WACC for offwind-dc, rc 2, scenario mb: 0.060337774288954725
# Updated WACC for offwind-dc, rc 2, scenario pb: 0.05778257554145923
# Updated WACC for offwind-dc, rc 2, scenario pi: 0.05782392749852562
# Updated WACC for offwind-dc, rc 2, scenario cb: 0.05762358609040919
# -----------------------------------
# Updated WACC for offwind-dc, rc 3, scenario pc: 0.06527522779923776
# Updated WACC for offwind-dc, rc 3, scenario mb: 0.060354226589259236
# Updated WACC for offwind-dc, rc 3, scenario pb: 0.057767421132716365
# Updated WACC for offwind-dc, rc 3, scenario pi: 0.05775790623768907
# Updated WACC for offwind-dc, rc 3, scenario cb: 0.05755451532753032
# -----------------------------------
# Updated WACC for offwind-float, rc 0, scenario pc: 0.06784701072095811
# Updated WACC for offwind-float, rc 0, scenario mb: 0.06238890113431075
# Updated WACC for offwind-float, rc 0, scenario pb: 0.058255087639228105
# Updated WACC for offwind-float, rc 0, scenario pi: 0.06050637446340221
# Updated WACC for offwind-float, rc 0, scenario cb: 0.06065881975965706
# -----------------------------------
# Updated WACC for offwind-float, rc 1, scenario pc: 0.06832571875570381
# Updated WACC for offwind-float, rc 1, scenario mb: 0.06247730164427176
# Updated WACC for offwind-float, rc 1, scenario pb: 0.05816152531883218
# Updated WACC for offwind-float, rc 1, scenario pi: 0.058317890006839526
# Updated WACC for offwind-float, rc 1, scenario cb: 0.058196113213219075
# -----------------------------------
# Updated WACC for offwind-float, rc 2, scenario pc: 0.0687868595273693
# Updated WACC for offwind-float, rc 2, scenario mb: 0.06236484059751581
# Updated WACC for offwind-float, rc 2, scenario pb: 0.05805542187813415
# Updated WACC for offwind-float, rc 2, scenario pi: 0.05847502960999642
# Updated WACC for offwind-float, rc 2, scenario cb: 0.05820132847585499
# -----------------------------------
# Updated WACC for offwind-float, rc 3, scenario pc: 0.06909672094209798
# Updated WACC for offwind-float, rc 3, scenario mb: 0.06230096159497905
# Updated WACC for offwind-float, rc 3, scenario pb: 0.05803017099594239
# Updated WACC for offwind-float, rc 3, scenario pi: 0.058756180894203376
# Updated WACC for offwind-float, rc 3, scenario cb: 0.0585713367797934
# -----------------------------------
# Updated WACC for onwind, rc 0, scenario pc: 0.06003881286664911
# Updated WACC for onwind, rc 0, scenario mb: 0.05584348376338424
# Updated WACC for onwind, rc 0, scenario pb: 0.05362116705264085
# Updated WACC for onwind, rc 0, scenario pi: 0.06105861782042234
# Updated WACC for onwind, rc 0, scenario cb: 0.06012503813695341
# -----------------------------------
# Updated WACC for onwind, rc 1, scenario pc: 0.05941303965085785
# Updated WACC for onwind, rc 1, scenario mb: 0.055504208991057784
# Updated WACC for onwind, rc 1, scenario pb: 0.05375595601003458
# Updated WACC for onwind, rc 1, scenario pi: 0.05642821137106391
# Updated WACC for onwind, rc 1, scenario cb: 0.05593523197724187
# -----------------------------------
# Updated WACC for onwind, rc 2, scenario pc: 0.05920008788519772
# Updated WACC for onwind, rc 2, scenario mb: 0.05545050682262087
# Updated WACC for onwind, rc 2, scenario pb: 0.05366328749855677
# Updated WACC for onwind, rc 2, scenario pi: 0.05583339079908441
# Updated WACC for onwind, rc 2, scenario cb: 0.05539367803262413
# -----------------------------------
# Updated WACC for onwind, rc 3, scenario pc: 0.05893153591929804
# Updated WACC for onwind, rc 3, scenario mb: 0.05540948641605974
# Updated WACC for onwind, rc 3, scenario pb: 0.053603031179225956
# Updated WACC for onwind, rc 3, scenario pi: 0.055337582273269466
# Updated WACC for onwind, rc 3, scenario cb: 0.05492738447440542
# -----------------------------------
# Updated WACC for onwind, rc 4, scenario pc: 0.058714898981787535
# Updated WACC for onwind, rc 4, scenario mb: 0.055439592990441516
# Updated WACC for onwind, rc 4, scenario pb: 0.05357320366265557
# Updated WACC for onwind, rc 4, scenario pi: 0.054979725217887195
# Updated WACC for onwind, rc 4, scenario cb: 0.054556876977824284
# -----------------------------------
# Updated WACC for onwind, rc 5, scenario pc: 0.05862407696444053
# Updated WACC for onwind, rc 5, scenario mb: 0.055494041775343554
# Updated WACC for onwind, rc 5, scenario pb: 0.05354005151406929
# Updated WACC for onwind, rc 5, scenario pi: 0.05480226892734172
# Updated WACC for onwind, rc 5, scenario cb: 0.05436439885320169
# -----------------------------------
# Updated WACC for onwind, rc 6, scenario pc: 0.0585191398147318
# Updated WACC for onwind, rc 6, scenario mb: 0.0554567765083142
# Updated WACC for onwind, rc 6, scenario pb: 0.053483043390598874
# Updated WACC for onwind, rc 6, scenario pi: 0.05444981488194703
# Updated WACC for onwind, rc 6, scenario cb: 0.05404478089812109
# -----------------------------------
# Updated WACC for onwind, rc 7, scenario pc: 0.05843057865580203
# Updated WACC for onwind, rc 7, scenario mb: 0.055430898855731284
# Updated WACC for onwind, rc 7, scenario pb: 0.05344965888435718
# Updated WACC for onwind, rc 7, scenario pi: 0.054229950156786985
# Updated WACC for onwind, rc 7, scenario cb: 0.053851621388641385
# -----------------------------------
# Updated WACC for onwind, rc 8, scenario pc: 0.05841215502670557
# Updated WACC for onwind, rc 8, scenario mb: 0.05545452455737069
# Updated WACC for onwind, rc 8, scenario pb: 0.053460508745922314
# Updated WACC for onwind, rc 8, scenario pi: 0.05383819204404094
# Updated WACC for onwind, rc 8, scenario cb: 0.053452511165705964
# -----------------------------------
# Updated WACC for onwind, rc 9, scenario pc: 0.05876300316366934
# Updated WACC for onwind, rc 9, scenario mb: 0.05577511089907398
# Updated WACC for onwind, rc 9, scenario pb: 0.05333172350300951
# Updated WACC for onwind, rc 9, scenario pi: 0.05343323135169646
# Updated WACC for onwind, rc 9, scenario cb: 0.05344560216379461
# -----------------------------------
# Updated WACC for solar, rc 0, scenario pc: 0.05269661347187066
# Updated WACC for solar, rc 0, scenario mb: 0.05057727217114636
# Updated WACC for solar, rc 0, scenario pb: 0.048858825351703064
# Updated WACC for solar, rc 0, scenario pi: 0.048833194687442946
# Updated WACC for solar, rc 0, scenario cb: 0.04876611256894876
# -----------------------------------
# Updated WACC for solar, rc 1, scenario pc: 0.052689041149546395
# Updated WACC for solar, rc 1, scenario mb: 0.050564272639695464
# Updated WACC for solar, rc 1, scenario pb: 0.048855805852108275
# Updated WACC for solar, rc 1, scenario pi: 0.04882600680009454
# Updated WACC for solar, rc 1, scenario cb: 0.048725922045952844
# -----------------------------------
# Updated WACC for solar, rc 2, scenario pc: 0.05265606829983702
# Updated WACC for solar, rc 2, scenario mb: 0.05054744760510121
# Updated WACC for solar, rc 2, scenario pb: 0.04884970663739948
# Updated WACC for solar, rc 2, scenario pi: 0.048824628748137255
# Updated WACC for solar, rc 2, scenario cb: 0.048720072725192555
# -----------------------------------
# Updated WACC for solar, rc 3, scenario pc: 0.05264046949770652
# Updated WACC for solar, rc 3, scenario mb: 0.05053172845668358
# Updated WACC for solar, rc 3, scenario pb: 0.048848507780211485
# Updated WACC for solar, rc 3, scenario pi: 0.04882226083351713
# Updated WACC for solar, rc 3, scenario cb: 0.048690012460289034
# -----------------------------------
# Updated WACC for solar, rc 4, scenario pc: 0.05260694991363654
# Updated WACC for solar, rc 4, scenario mb: 0.05050851810690009
# Updated WACC for solar, rc 4, scenario pb: 0.04884779716058353
# Updated WACC for solar, rc 4, scenario pi: 0.04882834275613517
# Updated WACC for solar, rc 4, scenario cb: 0.048676643736129184
# -----------------------------------
# Updated WACC for solar, rc 5, scenario pc: 0.052588051125790986
# Updated WACC for solar, rc 5, scenario mb: 0.05049990611405299
# Updated WACC for solar, rc 5, scenario pb: 0.04884135456246759
# Updated WACC for solar, rc 5, scenario pi: 0.04882275649897005
# Updated WACC for solar, rc 5, scenario cb: 0.04867043715076645
# -----------------------------------
# Updated WACC for solar, rc 6, scenario pc: 0.052583696193666055
# Updated WACC for solar, rc 6, scenario mb: 0.050488644798252394
# Updated WACC for solar, rc 6, scenario pb: 0.04884605414367522
# Updated WACC for solar, rc 6, scenario pi: 0.04883418759912931
# Updated WACC for solar, rc 6, scenario cb: 0.0486594351058414
# -----------------------------------
# Updated WACC for solar-hsat, rc 5, scenario pi: 0.04885876910982303
# Updated WACC for solar-hsat, rc 5, scenario cb: 0.04874471243166878
# -----------------------------------
# Updated WACC for solar-hsat, rc 6, scenario pc: 0.05296121530016054
# Updated WACC for solar-hsat, rc 6, scenario mb: 0.05052632320959697
# Updated WACC for solar-hsat, rc 6, scenario pb: 0.04890663857263411
# Updated WACC for solar-hsat, rc 6, scenario pi: 0.04885015444903926
# Updated WACC for solar-hsat, rc 6, scenario cb: 0.04869706116113801
# -----------------------------------
# Updated WACC for solar-hsat, rc 7, scenario pc: 0.05284518546988418
# Updated WACC for solar-hsat, rc 7, scenario mb: 0.050474352423201065
# Updated WACC for solar-hsat, rc 7, scenario pb: 0.048896998345752604
# Updated WACC for solar-hsat, rc 7, scenario pi: 0.04885988600087636
# Updated WACC for solar-hsat, rc 7, scenario cb: 0.048688352011155546
# -----------------------------------
# Updated WACC for solar-hsat, rc 8, scenario pc: 0.05280756019760194
# Updated WACC for solar-hsat, rc 8, scenario mb: 0.05043672169983285
# Updated WACC for solar-hsat, rc 8, scenario pb: 0.04883740389121653
# Updated WACC for solar-hsat, rc 8, scenario pi: 0.048838694390626186
# Updated WACC for solar-hsat, rc 8, scenario cb: 0.04865822222686139
# -----------------------------------
# Updated WACC for solar-hsat, rc 9, scenario pc: 0.05297200660266815
# Updated WACC for solar-hsat, rc 9, scenario mb: 0.05047072831013855
# Updated WACC for solar-hsat, rc 9, scenario pb: 0.04881251450390132
# Updated WACC for solar-hsat, rc 9, scenario pi: 0.04890450339823788
# Updated WACC for solar-hsat, rc 9, scenario cb: 0.048725775591810086
# -----------------------------------

# %%
importlib.reload(af)
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    af.plot_lifetime_risk_per_rc(run_name, carrier)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_offwind-ac_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_offwind-dc_scenarios.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_offwind-float_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_onwind_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_solar_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lifetime_risk_per_resource_class_solar-hsat_scenarios.png

# %%
importlib.reload(af)
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    af.plot_effective_wacc_per_rc(run_name, carrier)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_offwind-ac_scenarios.png
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_offwind-dc_scenarios.png
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_offwind-float_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_onwind_scenarios.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_solar_scenarios.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/effective_wacc_per_resource_class_solar-hsat_scenarios.png

# %%
importlib.reload(af)

for scenario in ['mb', 'cb', 'pc']:
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='offwind-dc', N=10000)
    af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='onwind', N=10000)
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar-hsat', N=10000)
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/norm_revenue_dist_MCS_onwind_mb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Log-Normal:  KS Stat = 0.0032, p-value = 2.5374e-01
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/norm_revenue_dist_MCS_onwind_cb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Student's t: KS Stat = 0.0126, p-value = 3.8365e-14 (df = 1.8)
# -> The Student's t distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/norm_revenue_dist_MCS_onwind_pc.png
# --- Goodness of Fit Results for Onshore Wind ---
# Log-Normal:  KS Stat = 0.0029, p-value = 3.6539e-01
# -> The Log-Normal distribution fits the data best (lowest KS statistic).

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 9
cap = 100
years_capped = range(2010, 2017)
rev = [af.annual_revenue_per_MW(costs, carrier, year, n, rc) for year in years_capped]
rev_cap = [af.annual_revenue_per_MW_with_price_cap(costs, carrier, year, n, rc, cap=cap) for year in years_capped]
print(f"Annual revenues per MW for {carrier}, rc {rc} with price cap in years {years_capped}: {rev_cap}")
lost_rev = [rev[i] - rev_cap[i] for i in range(len(years_capped))]
print(f"Lost revenues due to price cap for {carrier}, rc {rc} in years {years_capped}: {lost_rev}")
lost_rev_perc = [lost_rev[i] / rev[i] * 100 for i in range(len(years_capped))]
print(f"Percentage of lost revenues due to price cap for {carrier}, rc {rc} in years {years_capped}: {lost_rev_perc}")
print('------------------------------------')
years = n.generators_t.p.index.year.unique()
rev_all = sum([af.annual_revenue_per_MW(costs, carrier, year, n, rc) for year in years])
rev_cap_all = sum([af.annual_revenue_per_MW_with_price_cap(costs, carrier, year, n, rc, cap=cap) for year in years])
lost_rev_pct = (rev_all - rev_cap_all) / rev_all * 100
print(f"Total lost revenues due to price cap for {carrier}, rc {rc} over all years: {lost_rev_pct} %")
# Out:
# Annual revenues per MW for onwind, rc 9 with price cap in years range(2010, 2017): [166712.36494541354, 141400.09345188455, 138911.6931066856, 148005.56872031544, 149394.88220217638, 139784.4226146688, 139687.90617836293]
# Lost revenues due to price cap for onwind, rc 9 in years range(2010, 2017): [73807.41797741552, 51322.59117596154, 56637.55671388921, 62384.288175701106, 56388.21554796063, 51813.566761285474, 58036.26239950134]
# Percentage of lost revenues due to price cap for onwind, rc 9 in years range(2010, 2017): [30.686630879380377, 26.63028033003337, 28.963320885074577, 29.65175655142635, 27.401772139919633, 27.042855162543855, 29.352133741124582]
# ------------------------------------
# Total lost revenues due to price cap for onwind, rc 9 over all years: 8.476806909813412 %

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 8
af.plot_lost_revenue_due_to_price_cap(run_name, carrier, n, rc)
# Out:
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/lost_revenue_due_to_price_cap_onwind_8_80_200.png

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='mb')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_No_VOLL/my_plots/revenue_violin_plot_onwind_rc8.png
