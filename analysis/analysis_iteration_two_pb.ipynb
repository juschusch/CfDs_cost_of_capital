# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "2_Iteration_Two_PB" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 4000.000016354363 €/MWh
# Price statistics: {'mean': 60.88249852578476, 'median': 64.28920566299485, 'std_dev': 155.7922199602021, 'min': 0.018904930040475526, 'max': 4000.000016354363}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 4114.571949609945 MW
# Total installed offshore DC capacity: 41277.80018217269 MW
# Total installed offshore floating capacity: 0.5379270478560969 MW
# Total installed onshore wind capacity: 44956.40760226095 MW
# Total installed solar capacity: 156.50198339602056 MW
# Total installed solar HSAT capacity: 163817.68040925154 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 22082.065998884882 MW
# Total installed OCGT capacity: 53675.84840978313 MW
# Total installed battery capacity: 17575.86265029147 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 33138.15923376472 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 590189100.0807874 MWh
# Total offshore DC generation: 6438252357.669037 MWh
# Total offshore floating generation: 48210.86326144073 MWh
# Total onshore wind generation: 3942737855.929557 MWh
# Total solar generation: 5151756.199306444 MWh
# Total solar HSAT generation: 7224030502.425322 MWh
# Total CCGT generation: 2390656333.9125443 MWh
# Total OCGT generation: 1225866812.4545372 MWh
# Total battery discharge: -40995614.48933315 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1845275.864889768 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.068908e+06
# DE0 0 1 onwind    3.069932e+06
# DE0 0 2 onwind    3.067516e+06
# DE0 0 3 onwind    3.066033e+06
# DE0 0 4 onwind    3.065272e+06
# DE0 0 5 onwind    3.064389e+06
# DE0 0 6 onwind    3.062730e+06
# DE0 0 7 onwind    3.062376e+06
# DE0 0 8 onwind    3.060782e+06
# DE0 0 9 onwind    3.057063e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.534093e+06
# DE0 0 1 offwind-ac    6.577820e+06
# DE0 0 2 offwind-ac    6.840112e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.314609e+06
# DE0 0 2 offwind-dc    7.353549e+06
# DE0 0 3 offwind-dc    8.034744e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    9.509569e+06
# DE0 0 1 offwind-float    9.536845e+06
# DE0 0 2 offwind-float    9.870163e+06
# DE0 0 3 offwind-float    1.085076e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.102767e+06
# DE0 0 1 solar    1.102712e+06
# DE0 0 2 solar    1.102646e+06
# DE0 0 3 solar    1.102627e+06
# DE0 0 4 solar    1.102635e+06
# DE0 0 5 solar    1.102566e+06
# DE0 0 6 solar    1.102631e+06
# DE0 0 7 solar    1.102589e+06
# DE0 0 8 solar    1.102192e+06
# DE0 0 9 solar    1.102019e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.277172e+06
# DE0 0 1 solar-hsat    1.277092e+06
# DE0 0 2 solar-hsat    1.276952e+06
# DE0 0 3 solar-hsat    1.276919e+06
# DE0 0 4 solar-hsat    1.276776e+06
# DE0 0 5 solar-hsat    1.276750e+06
# DE0 0 6 solar-hsat    1.276904e+06
# DE0 0 7 solar-hsat    1.276751e+06
# DE0 0 8 solar-hsat    1.276018e+06
# DE0 0 9 solar-hsat    1.275939e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        1.499246
# DE0 0 1 onwind        0.782661
# DE0 0 2 onwind        1.328406
# DE0 0 3 onwind        2.120991
# DE0 0 4 onwind        2.863120
# DE0 0 5 onwind        3.033441
# DE0 0 6 onwind        9.953500
# DE0 0 7 onwind     6840.144731
# DE0 0 8 onwind    21592.126902
# DE0 0 9 onwind    16502.554603
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.811953
# DE0 0 1 offwind-ac    1404.073779
# DE0 0 2 offwind-ac    2709.686218
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.799429
# DE0 0 2 offwind-dc    13833.541716
# DE0 0 3 offwind-dc    27440.459037
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.101273
# DE0 0 1 offwind-float    0.127815
# DE0 0 2 offwind-float    0.174581
# DE0 0 3 offwind-float    0.134258
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar    10.754619
# DE0 0 1 solar    13.107276
# DE0 0 2 solar    14.077252
# DE0 0 3 solar    15.070913
# DE0 0 4 solar    13.807339
# DE0 0 5 solar    13.948843
# DE0 0 6 solar    15.784876
# DE0 0 7 solar    21.578672
# DE0 0 8 solar    26.682125
# DE0 0 9 solar    11.690067
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       70.775021
# DE0 0 1 solar-hsat       71.604773
# DE0 0 2 solar-hsat      381.885360
# DE0 0 3 solar-hsat     4791.485269
# DE0 0 4 solar-hsat      113.246173
# DE0 0 5 solar-hsat       53.827483
# DE0 0 6 solar-hsat    31714.775332
# DE0 0 7 solar-hsat    38550.693713
# DE0 0 8 solar-hsat    43243.861107
# DE0 0 9 solar-hsat    44825.526178
# Name: p_nom_opt, dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17575.862650
# DE0 0 H2             0.292218
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 936666550.4478021 MWh
# Total PHS output: 429268781.8007515 MWh
# Total H2 output: 4978.374622290549 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['pb'])

# %%
importlib.reload(af)
scenario = 'pb'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pb: 4355306.256694633
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pb: 5638387.012580933
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pb: 6613409.442161499
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pb: 6648710.209490956
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pb: 6621029.279026842
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pb: 6889426.655941096
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pb: 1417839.9069649912
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pb: 2250530.1505646543
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pb: 3140416.2058089823
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pb: 3428136.477805247
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario pb: 1058816.5949673115
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario pb: 1817991.3898508057
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario pb: 2011133.8134180722
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario pb: 2159343.510714373
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario pb: 2230506.15335845
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario pb: 2245899.907110388
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario pb: 2419076.8962767655
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario pb: 2535239.6665370422
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 8, scenario pb: 2781434.4270637026
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 9, scenario pb: 3734290.521761488
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 0, scenario pb: 1182924.2308437712
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 1, scenario pb: 1193604.2745028122
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 2, scenario pb: 1196749.9684832627
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 3, scenario pb: 1200119.3823106224
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 4, scenario pb: 1195811.8286920926
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 5, scenario pb: 1196219.6667545375
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 6, scenario pb: 1202708.1348056574
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 7, scenario pb: 1215729.0313922619
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 8, scenario pb: 1258611.1095624208
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 9, scenario pb: 1349331.87451623
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario pb: 1442005.2490358592
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario pb: 1441994.6353716683
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario pb: 1455823.7218004586
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario pb: 1459615.0380792043
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario pb: 1447658.442215647
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario pb: 1436885.725415106
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario pb: 1460097.1760732725
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario pb: 1459938.1125725193
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario pb: 1493718.1515153705
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario pb: 1607943.8181883714
# -----------------------------------

# %%
importlib.reload(af)
scenario = 'pb'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):  
        risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Relative revenue risk per MW of {carrier}, rc {rc}, scenario {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pb: 0.009736268264391938
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pb: 0.008331244715548301
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pb: 0.006510218821145972
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pb: 0.007349462480595351
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pb: 0.007559884999627808
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pb: 0.007074245729421994
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario pb: 0.015250366042894318
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario pb: 0.013487066714120213
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario pb: 0.011750188572261459
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario pb: 0.01143825784907351
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario pb: 0.022288855098187524
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario pb: 0.02491087930092627
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario pb: 0.022466188672602583
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario pb: 0.020820263669894302
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario pb: 0.01998381097955312
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario pb: 0.019311747374588274
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario pb: 0.017598948104798912
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario pb: 0.017195502271375306
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario pb: 0.015430347917220939
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario pb: 0.011672680293256202
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario pb: 0.008660801015542025
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario pb: 0.008639137585371095
# -----------------------------------
# Relative revenue risk per MW of solar, rc 2, scenario pb: 0.008482021608513806
# -----------------------------------
# Relative revenue risk per MW of solar, rc 3, scenario pb: 0.008511356854013406
# -----------------------------------
# Relative revenue risk per MW of solar, rc 4, scenario pb: 0.008542824714385108
# -----------------------------------
# Relative revenue risk per MW of solar, rc 5, scenario pb: 0.008340727617296194
# -----------------------------------
# Relative revenue risk per MW of solar, rc 6, scenario pb: 0.008541623920442566
# -----------------------------------
# Relative revenue risk per MW of solar, rc 7, scenario pb: 0.008292041725113544
# -----------------------------------
# Relative revenue risk per MW of solar, rc 8, scenario pb: 0.006871070842061624
# -----------------------------------
# Relative revenue risk per MW of solar, rc 9, scenario pb: 0.006276889159751464
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 0, scenario pb: 0.011236681038767123
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 1, scenario pb: 0.011197249049156487
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 2, scenario pb: 0.010817993331803014
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 3, scenario pb: 0.010595959236707898
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 4, scenario pb: 0.010493778223157165
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 5, scenario pb: 0.010443576340944487
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 6, scenario pb: 0.009839087136841987
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 7, scenario pb: 0.008961869104316752
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 8, scenario pb: 0.008150986094352067
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 9, scenario pb: 0.007407880804294267
# -----------------------------------

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='pb')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/revenue_violin_plot_onwind_rc8.png

# %%
importlib.reload(af)
scenario = 'pb'
af.calculate_annual_state_cfd_payments(run_name, n, scenario=scenario)
avg = af.average_state_cfd_payments(run_name, n, scenario=scenario)
print(f"Average state CfD payments for scenario {scenario}: {avg} €")
std = af.std_dev_state_cfd_payments(run_name, n, scenario=scenario)
print(f"Standard deviation of state CfD payments for scenario {scenario}: {std} €/year")
print('-----------------------------------')
# Out:
# Average state CfD payments for scenario pb: 1.4168875558035715e-06 €
# Standard deviation of state CfD payments for scenario pb: 5869668127.931083 €/year
# -----------------------------------

# %%
importlib.reload(af)
scenario = 'pb'
af.plot_annual_state_CfD_payments(run_name, scenario=scenario, cap=130, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/annual_state_CfD_payments_pb.png

# %%
importlib.reload(af)
scenario = 'pb'
af.plot_wind_vs_solar_cfd_payments(run_name, scenario=scenario, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/wind_vs_solar_cfd_payments_pb.png
