# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "1_Iteration_One" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.999980316915 €/MWh
# Price statistics: {'mean': 61.43250202677193, 'median': 64.29124722196013, 'std_dev': 155.652159624441, 'min': 0.018937418035870825, 'max': 3999.999980316915}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 3139.035195790273 MW
# Total installed offshore DC capacity: 41338.66810223278 MW
# Total installed offshore floating capacity: 0.5322749046622803 MW
# Total installed onshore wind capacity: 45524.874585948695 MW
# Total installed solar capacity: 161.69366758296994 MW
# Total installed solar HSAT capacity: 162849.76748411765 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 22414.83930242813 MW
# Total installed OCGT capacity: 53511.51757277716 MW
# Total installed battery capacity: 17506.316291341245 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 43536.49172610384 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 463839661.56819725 MWh
# Total offshore DC generation: 6388194015.939276 MWh
# Total offshore floating generation: 47720.941630361 MWh
# Total onshore wind generation: 4077187085.8447285 MWh
# Total solar generation: 5302332.2496358305 MWh
# Total solar HSAT generation: 7197075488.259207 MWh
# Total CCGT generation: 2446124655.0794163 MWh
# Total OCGT generation: 1220971079.038218 MWh
# Total battery discharge: -41120198.92480653 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1840466.628020262 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_max[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind    45743.748412
# DE0 0 1 onwind    54117.371817
# DE0 0 2 onwind    58251.682710
# DE0 0 3 onwind    52098.507213
# DE0 0 4 onwind    50581.054172
# DE0 0 5 onwind    48267.020574
# DE0 0 6 onwind    49078.275810
# DE0 0 7 onwind    53092.707911
# DE0 0 8 onwind    48638.074786
# DE0 0 9 onwind    27968.461352
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-ac    1665.263405
# DE0 0 1 offwind-ac    9208.864488
# DE0 0 2 offwind-ac    2709.720028
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.802769
# DE0 0 2 offwind-dc    13833.554458
# DE0 0 3 offwind-dc    50358.495144
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-float    144.467403
# DE0 0 1 offwind-float    182.920728
# DE0 0 2 offwind-float    108.231258
# DE0 0 3 offwind-float     74.667750
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar    130636.363632
# DE0 0 1 solar    135780.573709
# DE0 0 2 solar    107387.176322
# DE0 0 3 solar     97614.538268
# DE0 0 4 solar    107232.765509
# DE0 0 5 solar    116601.821274
# DE0 0 6 solar     98881.173592
# DE0 0 7 solar     90797.550823
# DE0 0 8 solar    110169.652048
# DE0 0 9 solar     91472.791259
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar-hsat    114839.067548
# DE0 0 1 solar-hsat    114362.398932
# DE0 0 2 solar-hsat     92308.346032
# DE0 0 3 solar-hsat     91502.827720
# DE0 0 4 solar-hsat     92271.688846
# DE0 0 5 solar-hsat    104925.084931
# DE0 0 6 solar-hsat     79683.267813
# DE0 0 7 solar-hsat     83005.381157
# DE0 0 8 solar-hsat     94514.277451
# DE0 0 9 solar-hsat     76416.016535
# Name: p_nom_max, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.127969e+06
# DE0 0 1 onwind    3.119084e+06
# DE0 0 2 onwind    3.118160e+06
# DE0 0 3 onwind    3.115482e+06
# DE0 0 4 onwind    3.114390e+06
# DE0 0 5 onwind    3.116298e+06
# DE0 0 6 onwind    3.116572e+06
# DE0 0 7 onwind    3.116883e+06
# DE0 0 8 onwind    3.120206e+06
# DE0 0 9 onwind    3.127324e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.651806e+06
# DE0 0 1 offwind-ac    6.693376e+06
# DE0 0 2 offwind-ac    6.958907e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.432106e+06
# DE0 0 2 offwind-dc    7.470627e+06
# DE0 0 3 offwind-dc    8.152775e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    9.760443e+06
# DE0 0 1 offwind-float    9.790234e+06
# DE0 0 2 offwind-float    1.012679e+07
# DE0 0 3 offwind-float    1.111375e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.121176e+06
# DE0 0 1 solar    1.120683e+06
# DE0 0 2 solar    1.120526e+06
# DE0 0 3 solar    1.120385e+06
# DE0 0 4 solar    1.120338e+06
# DE0 0 5 solar    1.120312e+06
# DE0 0 6 solar    1.120436e+06
# DE0 0 7 solar    1.119965e+06
# DE0 0 8 solar    1.119336e+06
# DE0 0 9 solar    1.119930e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.298826e+06
# DE0 0 1 solar-hsat    1.298313e+06
# DE0 0 2 solar-hsat    1.298127e+06
# DE0 0 3 solar-hsat    1.297932e+06
# DE0 0 4 solar-hsat    1.297770e+06
# DE0 0 5 solar-hsat    1.297888e+06
# DE0 0 6 solar-hsat    1.297648e+06
# DE0 0 7 solar-hsat    1.296987e+06
# DE0 0 8 solar-hsat    1.296403e+06
# DE0 0 9 solar-hsat    1.296883e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        1.411752
# DE0 0 1 onwind        0.834318
# DE0 0 2 onwind        1.329380
# DE0 0 3 onwind        2.208141
# DE0 0 4 onwind        2.963982
# DE0 0 5 onwind        3.132269
# DE0 0 6 onwind       10.094200
# DE0 0 7 onwind     7408.219296
# DE0 0 8 onwind    21592.126729
# DE0 0 9 onwind    16502.554519
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.809597
# DE0 0 1 offwind-ac     428.539725
# DE0 0 2 offwind-ac    2709.685873
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.799596
# DE0 0 2 offwind-dc    13833.535550
# DE0 0 3 offwind-dc    27501.332956
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.100289
# DE0 0 1 offwind-float    0.127001
# DE0 0 2 offwind-float    0.172661
# DE0 0 3 offwind-float    0.132324
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar    11.088660
# DE0 0 1 solar    13.581572
# DE0 0 2 solar    14.565895
# DE0 0 3 solar    15.669475
# DE0 0 4 solar    14.396485
# DE0 0 5 solar    14.471293
# DE0 0 6 solar    16.208565
# DE0 0 7 solar    22.148558
# DE0 0 8 solar    27.578267
# DE0 0 9 solar    11.984897
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       66.431447
# DE0 0 1 solar-hsat       70.241553
# DE0 0 2 solar-hsat      353.587958
# DE0 0 3 solar-hsat     3797.512237
# DE0 0 4 solar-hsat      112.050937
# DE0 0 5 solar-hsat       53.564069
# DE0 0 6 solar-hsat    31554.581087
# DE0 0 7 solar-hsat    38773.605503
# DE0 0 8 solar-hsat    43242.963779
# DE0 0 9 solar-hsat    44825.228914
# Name: p_nom_opt, dtype: float64

# %%
importlib.reload(af)
af.plot_resource_classes_map(run_name, carrier='solar', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='solar-hsat', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='onwind', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-ac', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-dc', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-float', save_to_file=True)
# Out:
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar-hsat.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_onwind.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-ac.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-dc.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-float.png

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    cap_pot = n.generators.p_nom_max[n.generators.carrier == carrier]
    print(f"Utilization of expansion potential for {carrier}:")
    print(cap_inst / cap_pot)
# Out:
# Utilization of expansion potential for onwind:
# Generator
# DE0 0 0 onwind    0.000031
# DE0 0 1 onwind    0.000015
# DE0 0 2 onwind    0.000023
# DE0 0 3 onwind    0.000042
# DE0 0 4 onwind    0.000059
# DE0 0 5 onwind    0.000065
# DE0 0 6 onwind    0.000206
# DE0 0 7 onwind    0.139534
# DE0 0 8 onwind    0.443935
# DE0 0 9 onwind    0.590042
# dtype: float64
# Utilization of expansion potential for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.000486
# DE0 0 1 offwind-ac    0.046536
# DE0 0 2 offwind-ac    0.999987
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Utilization of expansion potential for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.999166
# DE0 0 2 offwind-dc    0.999999
# DE0 0 3 offwind-dc    0.546111
# dtype: float64
# Utilization of expansion potential for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.000694
# DE0 0 1 offwind-float    0.000694
# DE0 0 2 offwind-float    0.001595
# DE0 0 3 offwind-float    0.001772
# dtype: float64
# Utilization of expansion potential for solar:
# Generator
# DE0 0 0 solar    0.000085
# DE0 0 1 solar    0.000100
# DE0 0 2 solar    0.000136
# DE0 0 3 solar    0.000161
# DE0 0 4 solar    0.000134
# DE0 0 5 solar    0.000124
# DE0 0 6 solar    0.000164
# DE0 0 7 solar    0.000244
# DE0 0 8 solar    0.000250
# DE0 0 9 solar    0.000131
# dtype: float64
# Utilization of expansion potential for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.000578
# DE0 0 1 solar-hsat    0.000614
# DE0 0 2 solar-hsat    0.003831
# DE0 0 3 solar-hsat    0.041502
# DE0 0 4 solar-hsat    0.001214
# DE0 0 5 solar-hsat    0.000510
# DE0 0 6 solar-hsat    0.396000
# DE0 0 7 solar-hsat    0.467122
# DE0 0 8 solar-hsat    0.457528
# DE0 0 9 solar-hsat    0.586595
# dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    generation = n.generators_t.p.loc[:, n.generators.carrier == carrier].sum()
    print(f"Average capacity factor for {carrier}:")
    print(generation / cap_inst / len(n.snapshots))
# Out:
# Average capacity factor for onwind:
# Generator
# DE0 0 0 onwind    0.059268
# DE0 0 1 onwind    0.121543
# DE0 0 2 onwind    0.143906
# DE0 0 3 onwind    0.168419
# DE0 0 4 onwind    0.192372
# DE0 0 5 onwind    0.205539
# DE0 0 6 onwind    0.224651
# DE0 0 7 onwind    0.235392
# DE0 0 8 onwind    0.266373
# DE0 0 9 onwind    0.351367
# dtype: float64
# Average capacity factor for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.347498
# DE0 0 1 offwind-ac    0.442401
# DE0 0 2 offwind-ac    0.488242
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Average capacity factor for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.411175
# DE0 0 2 offwind-dc    0.504784
# DE0 0 3 offwind-dc    0.503652
# dtype: float64
# Average capacity factor for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.177456
# DE0 0 1 offwind-float    0.261482
# DE0 0 2 offwind-float    0.326012
# DE0 0 3 offwind-float    0.365396
# dtype: float64
# Average capacity factor for solar:
# Generator
# DE0 0 0 solar    0.098827
# DE0 0 1 solar    0.100089
# DE0 0 2 solar    0.101097
# DE0 0 3 solar    0.102170
# DE0 0 4 solar    0.103546
# DE0 0 5 solar    0.104692
# DE0 0 6 solar    0.106263
# DE0 0 7 solar    0.109291
# DE0 0 8 solar    0.114582
# DE0 0 9 solar    0.121531
# dtype: float64
# Average capacity factor for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.116860
# DE0 0 1 solar-hsat    0.118251
# DE0 0 2 solar-hsat    0.118422
# DE0 0 3 solar-hsat    0.122933
# DE0 0 4 solar-hsat    0.121545
# DE0 0 5 solar-hsat    0.123870
# DE0 0 6 solar-hsat    0.138844
# DE0 0 7 solar-hsat    0.139576
# DE0 0 8 solar-hsat    0.145791
# DE0 0 9 solar-hsat    0.152398
# dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17506.316291
# DE0 0 H2             0.314826
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 936794882.7398388 MWh
# Total PHS output: 425473739.0114251 MWh
# Total H2 output: 5165.893751287589 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000)

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pb', 'pi', 'cb']:    
            avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario mb: 4426672.319485299
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pb: 4429606.979458118
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pi: 4431243.200351949
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario cb: 4430368.110577688
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario mb: 5731665.861098539
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pb: 5735492.055707655
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pi: 5736236.741965188
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario cb: 5735361.652190929
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario mb: 6711890.772186899
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pb: 6716580.259389608
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pi: 6716461.653053546
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario cb: 6715586.563279288
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario mb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pi: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario mb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pi: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario mb: 6745683.667307371
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pb: 6750079.2468349105
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pi: 6750774.075463585
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario cb: 6749895.258947459
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario mb: 6717656.658620646
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pb: 6722572.888325048
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pi: 6722747.0667768605
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario cb: 6721868.250260735
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario mb: 6986969.12867059
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pb: 6992142.686373727
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pi: 6992059.536826803
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario cb: 6991180.720310677
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario mb: 1439380.9801144346
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pb: 1440175.9635027214
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pi: 1440744.623536409
# Average lifetime revenue per MW of offwind-float, rc 0, scenario cb: 1441066.3892746884
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario mb: 2282418.810231053
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pb: 2283664.8222644534
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pi: 2283782.453653028
# Average lifetime revenue per MW of offwind-float, rc 1, scenario cb: 2284104.219391307
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario mb: 3179000.729491801
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pb: 3180621.525457527
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pi: 3180364.3729137755
# Average lifetime revenue per MW of offwind-float, rc 2, scenario cb: 3180686.138652054
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario mb: 3466379.6207223297
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pb: 3467949.5082039414
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pi: 3467743.2641443047
# Average lifetime revenue per MW of offwind-float, rc 3, scenario cb: 3468065.029882584
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario mb: 1065140.1366400311
# Average lifetime revenue per MW of onwind, rc 0, scenario pb: 1066077.9871852833
# Average lifetime revenue per MW of onwind, rc 0, scenario pi: 1067594.8602487245
# Average lifetime revenue per MW of onwind, rc 0, scenario cb: 1066814.3044376757
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario mb: 1834942.8822697857
# Average lifetime revenue per MW of onwind, rc 1, scenario pb: 1836728.2459632154
# Average lifetime revenue per MW of onwind, rc 1, scenario pi: 1837397.6058784798
# Average lifetime revenue per MW of onwind, rc 1, scenario cb: 1836617.0500674313
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario mb: 2030222.4203522461
# Average lifetime revenue per MW of onwind, rc 2, scenario pb: 2032345.3544853206
# Average lifetime revenue per MW of onwind, rc 2, scenario pi: 2032677.1439609395
# Average lifetime revenue per MW of onwind, rc 2, scenario cb: 2031896.588149891
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario mb: 2186163.7261415585
# Average lifetime revenue per MW of onwind, rc 3, scenario pb: 2188403.9707928947
# Average lifetime revenue per MW of onwind, rc 3, scenario pi: 2188618.449750252
# Average lifetime revenue per MW of onwind, rc 3, scenario cb: 2187837.893939203
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario mb: 2264069.2545567793
# Average lifetime revenue per MW of onwind, rc 4, scenario pb: 2266117.3648586157
# Average lifetime revenue per MW of onwind, rc 4, scenario pi: 2266523.9781654724
# Average lifetime revenue per MW of onwind, rc 4, scenario cb: 2265743.4223544234
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario mb: 2283557.4001161125
# Average lifetime revenue per MW of onwind, rc 5, scenario pb: 2285421.9607769083
# Average lifetime revenue per MW of onwind, rc 5, scenario pi: 2286012.123724806
# Average lifetime revenue per MW of onwind, rc 5, scenario cb: 2285231.567913757
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario mb: 2461505.5498598837
# Average lifetime revenue per MW of onwind, rc 6, scenario pb: 2463498.521909938
# Average lifetime revenue per MW of onwind, rc 6, scenario pi: 2463960.2734685782
# Average lifetime revenue per MW of onwind, rc 6, scenario cb: 2463179.7176575293
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario mb: 2583070.4078425844
# Average lifetime revenue per MW of onwind, rc 7, scenario pb: 2585213.0782879153
# Average lifetime revenue per MW of onwind, rc 7, scenario pi: 2585525.131451278
# Average lifetime revenue per MW of onwind, rc 7, scenario cb: 2584744.575640229
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario mb: 0.07901861814964818
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pb: 0.00701783920143132
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pi: 0.006875311064917314
# Relative revenue risk per MW of offwind-dc, rc 3, scenario cb: 0.0017096859397511706
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario mb: 0.11150411247252151
# Relative revenue risk per MW of offwind-float, rc 0, scenario pb: 0.015554235330836934
# Relative revenue risk per MW of offwind-float, rc 0, scenario pi: 0.08242347120420404
# Relative revenue risk per MW of offwind-float, rc 0, scenario cb: 0.08999608067862724
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario mb: 0.10802344332677113
# Relative revenue risk per MW of offwind-float, rc 1, scenario pb: 0.013714328636739121
# Relative revenue risk per MW of offwind-float, rc 1, scenario pi: 0.019036887235043293
# Relative revenue risk per MW of offwind-float, rc 1, scenario cb: 0.01972210480697605
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario mb: 0.10689411729972975
# Relative revenue risk per MW of offwind-float, rc 2, scenario pb: 0.011875349140657923
# Relative revenue risk per MW of offwind-float, rc 2, scenario pi: 0.022633584445772077
# Relative revenue risk per MW of offwind-float, rc 2, scenario cb: 0.01645817023300886
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario mb: 0.10503580366518156
# Relative revenue risk per MW of offwind-float, rc 3, scenario pb: 0.011587470429162765
# Relative revenue risk per MW of offwind-float, rc 3, scenario pi: 0.028000860756971387
# Relative revenue risk per MW of offwind-float, rc 3, scenario cb: 0.02288847201792652
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario mb: 0.08292697635598474
# Relative revenue risk per MW of onwind, rc 0, scenario pb: 0.022115989934762374
# Relative revenue risk per MW of onwind, rc 0, scenario pi: 0.17632636901844118
# Relative revenue risk per MW of onwind, rc 0, scenario cb: 0.15504925754495777
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario mb: 0.07320809246171077
# Relative revenue risk per MW of onwind, rc 1, scenario pb: 0.024842031716443176
# Relative revenue risk per MW of onwind, rc 1, scenario pi: 0.082415942746656
# Relative revenue risk per MW of onwind, rc 1, scenario cb: 0.07094889720471989
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario mb: 0.07264381457482405
# Relative revenue risk per MW of onwind, rc 2, scenario pb: 0.0223856947137798
# Relative revenue risk per MW of onwind, rc 2, scenario pi: 0.06896432063812255
# Relative revenue risk per MW of onwind, rc 2, scenario cb: 0.059482605012292224
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario mb: 0.07114118948305047
# Relative revenue risk per MW of onwind, rc 3, scenario pb: 0.02069682300712565
# Relative revenue risk per MW of onwind, rc 3, scenario pi: 0.059575770408591834
# Relative revenue risk per MW of onwind, rc 3, scenario cb: 0.05055411837563094
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario mb: 0.07066621027957053
# Relative revenue risk per MW of onwind, rc 4, scenario pb: 0.019828913997400572
# Relative revenue risk per MW of onwind, rc 4, scenario pi: 0.052508586820604886
# Relative revenue risk per MW of onwind, rc 4, scenario cb: 0.04175631879172825
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario mb: 0.0727922545059403
# Relative revenue risk per MW of onwind, rc 5, scenario pb: 0.019111177984873755
# Relative revenue risk per MW of onwind, rc 5, scenario pi: 0.048843478565877084
# Relative revenue risk per MW of onwind, rc 5, scenario cb: 0.03693959938570416
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario mb: 0.07271457295083418
# Relative revenue risk per MW of onwind, rc 6, scenario pb: 0.01734797111250219
# Relative revenue risk per MW of onwind, rc 6, scenario pi: 0.039186182423277795
# Relative revenue risk per MW of onwind, rc 6, scenario cb: 0.028111742636467284
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario mb: 0.07239958287094427
# Relative revenue risk per MW of onwind, rc 7, scenario pb: 0.01669785980283171
# Relative revenue risk per MW of onwind, rc 7, scenario pi: 0.034094454175559105
# Relative revenue risk per MW of onwind, rc 7, scenario cb: 0.023789661490572288
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario mb: 0.075675171178392
# Relative revenue risk per MW of onwind, rc 8, scenario pb: 0.01525990564332554
# Relative revenue risk per MW of onwind, rc 8, scenario pi: 0.02251311588931106
# Relative revenue risk per MW of onwind, rc 8, scenario cb: 0.011350489473474442
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario mb: 0.08250629862704217
# Relative revenue risk per MW of onwind, rc 9, scenario pb: 0.011727691600335138
# Relative revenue risk per MW of onwind, rc 9, scenario pi: 0.01686261563295859
# Relative revenue risk per MW of onwind, rc 9, scenario cb: 0.01826094220745765
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario mb: 0.06316592923051932
# Relative revenue risk per MW of solar, rc 0, scenario pb: 0.008650331561826768
# Relative revenue risk per MW of solar, rc 0, scenario pi: 0.00882099502144332
# Relative revenue risk per MW of solar, rc 0, scenario cb: 0.008014806720441539
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario mb: 0.061281529835218534
# Relative revenue risk per MW of solar, rc 1, scenario pb: 0.008611895389436592
# Relative revenue risk per MW of solar, rc 1, scenario pi: 0.0077644800340796434
# Relative revenue risk per MW of solar, rc 1, scenario cb: 0.006791630836374571
# -----------------------------------
# Relative revenue risk per MW of solar, rc 2, scenario mb: 0.06074790042607716
# Relative revenue risk per MW of solar, rc 2, scenario pb: 0.008460188118159684
# Relative revenue risk per MW of solar, rc 2, scenario pi: 0.007525070705855575
# Relative revenue risk per MW of solar, rc 2, scenario cb: 0.007040753636662497
# -----------------------------------
# Relative revenue risk per MW of solar, rc 3, scenario mb: 0.05998399759595504
# Relative revenue risk per MW of solar, rc 3, scenario pb: 0.0084832085271898
# Relative revenue risk per MW of solar, rc 3, scenario pi: 0.007190299350119271
# Relative revenue risk per MW of solar, rc 3, scenario cb: 0.0060636968942252775
# -----------------------------------
# Relative revenue risk per MW of solar, rc 4, scenario mb: 0.05935651771963301
# Relative revenue risk per MW of solar, rc 4, scenario pb: 0.008512566567021844
# Relative revenue risk per MW of solar, rc 4, scenario pi: 0.007637704569171688
# Relative revenue risk per MW of solar, rc 4, scenario cb: 0.005074511555949128
# -----------------------------------
# Relative revenue risk per MW of solar, rc 5, scenario mb: 0.06021264727398789
# Relative revenue risk per MW of solar, rc 5, scenario pb: 0.00831787677212799
# Relative revenue risk per MW of solar, rc 5, scenario pi: 0.007213165226360981
# Relative revenue risk per MW of solar, rc 5, scenario cb: 0.0035179394665574375
# -----------------------------------
# Relative revenue risk per MW of solar, rc 6, scenario mb: 0.061023407381311574
# Relative revenue risk per MW of solar, rc 6, scenario pb: 0.008508923505475358
# Relative revenue risk per MW of solar, rc 6, scenario pi: 0.008752692050251335
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario cb: 0.07
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1401: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario cb: 0.07
# -----------------------------------
# Updated WACC for offwind-dc, rc 1, scenario mb: 0.06050689719574086
# Updated WACC for offwind-dc, rc 1, scenario pb: 0.05777189051503034
# Updated WACC for offwind-dc, rc 1, scenario pi: 0.058012453775189494
# Updated WACC for offwind-dc, rc 1, scenario cb: 0.0580288858440148
# -----------------------------------
# Updated WACC for offwind-dc, rc 2, scenario mb: 0.060447176097233615
# Updated WACC for offwind-dc, rc 2, scenario pb: 0.0577750993592542
# Updated WACC for offwind-dc, rc 2, scenario pi: 0.05781992290466422
# Updated WACC for offwind-dc, rc 2, scenario cb: 0.057629860178314944
# -----------------------------------
# Updated WACC for offwind-dc, rc 3, scenario mb: 0.06047357807576019
# Updated WACC for offwind-dc, rc 3, scenario pb: 0.05775811558368434
# Updated WACC for offwind-dc, rc 3, scenario pi: 0.057752862022650946
# Updated WACC for offwind-dc, rc 3, scenario cb: 0.057562776788399286
# -----------------------------------
# Updated WACC for offwind-float, rc 0, scenario mb: 0.06310954198973796
# Updated WACC for offwind-float, rc 0, scenario pb: 0.05825970438970813
# Updated WACC for offwind-float, rc 0, scenario pi: 0.06160937722796148
# Updated WACC for offwind-float, rc 0, scenario cb: 0.061997441878833284
# -----------------------------------
# Updated WACC for offwind-float, rc 1, scenario mb: 0.06292857015638285
# Updated WACC for offwind-float, rc 1, scenario pb: 0.05816946223947866
# Updated WACC for offwind-float, rc 1, scenario pi: 0.05843079655662018
# Updated WACC for offwind-float, rc 1, scenario cb: 0.058464502126146504
# -----------------------------------
# Updated WACC for offwind-float, rc 2, scenario mb: 0.06286993590138683
# Updated WACC for offwind-float, rc 2, scenario pb: 0.0580793668907023
# Updated WACC for offwind-float, rc 2, scenario pi: 0.058607874162468515
# Updated WACC for offwind-float, rc 2, scenario cb: 0.058304076991179246
# -----------------------------------
# Updated WACC for offwind-float, rc 3, scenario mb: 0.06277354148091965
# Updated WACC for offwind-float, rc 3, scenario pb: 0.05806527228847641
# Updated WACC for offwind-float, rc 3, scenario pi: 0.05887284862704077
# Updated WACC for offwind-float, rc 3, scenario cb: 0.05862043792370187
# -----------------------------------
# Updated WACC for onwind, rc 0, scenario mb: 0.05593404422204032
# Updated WACC for onwind, rc 0, scenario pb: 0.053693808184709216
# Updated WACC for onwind, rc 0, scenario pi: 0.05954635052451736
# Updated WACC for onwind, rc 0, scenario cb: 0.05870456365604672
# -----------------------------------
# Updated WACC for onwind, rc 1, scenario mb: 0.05557024047180932
# Updated WACC for onwind, rc 1, scenario pb: 0.05379241605238808
# Updated WACC for onwind, rc 1, scenario pi: 0.05591485942963056
# Updated WACC for onwind, rc 1, scenario cb: 0.05548599072029329
# -----------------------------------
# Updated WACC for onwind, rc 2, scenario mb: 0.05554918625081349
# Updated WACC for onwind, rc 2, scenario pb: 0.05370355659714184
# Updated WACC for onwind, rc 2, scenario pi: 0.05541208065312511
# Updated WACC for onwind, rc 2, scenario cb: 0.05506022929477579
# -----------------------------------
# Updated WACC for onwind, rc 3, scenario mb: 0.05549315701388186
# Updated WACC for onwind, rc 3, scenario pb: 0.0536425398394608
# Updated WACC for onwind, rc 3, scenario pi: 0.05506367633315411
# Updated WACC for onwind, rc 3, scenario cb: 0.054730816512486485
# -----------------------------------
# Updated WACC for onwind, rc 4, scenario mb: 0.05547545719705975
# Updated WACC for onwind, rc 4, scenario pb: 0.05361120847493631
# Updated WACC for onwind, rc 4, scenario pi: 0.054802768121954525
# Updated WACC for onwind, rc 4, scenario cb: 0.054408024903922776
# -----------------------------------
# Updated WACC for onwind, rc 5, scenario mb: 0.05555472408734448
# Updated WACC for onwind, rc 5, scenario pb: 0.05358531117667114
# Updated WACC for onwind, rc 5, scenario pi: 0.0546679135337477
# Updated WACC for onwind, rc 5, scenario cb: 0.05423205190933745
# -----------------------------------
# Updated WACC for onwind, rc 6, scenario mb: 0.05555182596339314
# Updated WACC for onwind, rc 6, scenario pb: 0.05352174061675493
# Updated WACC for onwind, rc 6, scenario pi: 0.05431406200405189
# Updated WACC for onwind, rc 6, scenario cb: 0.05391091193135492
# -----------------------------------
# Updated WACC for onwind, rc 7, scenario mb: 0.0555400758426528
# Updated WACC for onwind, rc 7, scenario pb: 0.053498319224348515
# Updated WACC for onwind, rc 7, scenario pi: 0.05412835719061701
# Updated WACC for onwind, rc 7, scenario cb: 0.05375432920845257
# -----------------------------------
# Updated WACC for onwind, rc 8, scenario mb: 0.055662379360359775
# Updated WACC for onwind, rc 8, scenario pb: 0.053446548232231106
# Updated WACC for onwind, rc 8, scenario pi: 0.053708162776192274
# Updated WACC for onwind, rc 8, scenario cb: 0.05330603170541668
# -----------------------------------
# Updated WACC for onwind, rc 9, scenario mb: 0.0559182510449699
# Updated WACC for onwind, rc 9, scenario pb: 0.053319574553560366
# Updated WACC for onwind, rc 9, scenario pi: 0.053504253939307196
# Updated WACC for onwind, rc 9, scenario cb: 0.05355464807210642
# -----------------------------------
# Updated WACC for solar, rc 0, scenario mb: 0.05045629583098064
# Updated WACC for solar, rc 0, scenario pb: 0.04884979846112209
# Updated WACC for solar, rc 0, scenario pi: 0.04885474066904341
# Updated WACC for solar, rc 0, scenario cb: 0.04883139916944427
# -----------------------------------
# Updated WACC for solar, rc 1, scenario mb: 0.05039982274640476
# Updated WACC for solar, rc 1, scenario pb: 0.04884868547031671
# Updated WACC for solar, rc 1, scenario pi: 0.048824153929518305
# Updated WACC for solar, rc 1, scenario cb: 0.04879600762414481
# -----------------------------------
# Updated WACC for solar, rc 2, scenario mb: 0.05038384296428292
# Updated WACC for solar, rc 2, scenario pb: 0.048844292771273876
# Updated WACC for solar, rc 2, scenario pi: 0.04881722575657864
# Updated WACC for solar, rc 2, scenario cb: 0.0488032135352786
# -----------------------------------
# Updated WACC for solar, rc 3, scenario mb: 0.05036097707108632
# Updated WACC for solar, rc 3, scenario pb: 0.048844959302080465
# Updated WACC for solar, rc 3, scenario pi: 0.04880753971661944
# Updated WACC for solar, rc 3, scenario cb: 0.04877495860756799
# -----------------------------------
# Updated WACC for solar, rc 4, scenario mb: 0.05034220311825108
# Updated WACC for solar, rc 4, scenario pb: 0.04884580934629592
# Updated WACC for solar, rc 4, scenario pi: 0.04882048509185787
# Updated WACC for solar, rc 4, scenario cb: 0.048746370905965085
# -----------------------------------
# Updated WACC for solar, rc 5, scenario mb: 0.05036782006193825
# Updated WACC for solar, rc 5, scenario pb: 0.04884017251935715
# Updated WACC for solar, rc 5, scenario pi: 0.048808201235930215
# Updated WACC for solar, rc 5, scenario cb: 0.04870142215811906
# -----------------------------------
# Updated WACC for solar, rc 6, scenario mb: 0.05039209246463083
# Updated WACC for solar, rc 6, scenario pb: 0.04884570386279424
# Updated WACC for solar, rc 6, scenario pi: 0.048852762632682324
# Updated WACC for solar, rc 6, scenario cb: 0.048670330005452435
# -----------------------------------
# Updated WACC for solar, rc 7, scenario mb: 0.0503851893616115
# Updated WACC for solar, rc 7, scenario pb: 0.04883777634458265
# Updated WACC for solar, rc 7, scenario pi: 0.04896915005668175
# Updated WACC for solar, rc 7, scenario cb: 0.04881293351517866
# -----------------------------------
# Updated WACC for solar, rc 8, scenario mb: 0.05035537136603417
# Updated WACC for solar, rc 8, scenario pb: 0.04879628657618801
# Updated WACC for solar, rc 8, scenario pi: 0.04893654583048825
# Updated WACC for solar, rc 8, scenario cb: 0.048800747577651446
# -----------------------------------
# Updated WACC for solar, rc 9, scenario mb: 0.05044497454918984
# Updated WACC for solar, rc 9, scenario pb: 0.0487793922652894
# Updated WACC for solar, rc 9, scenario pi: 0.04903645282351794
# Updated WACC for solar, rc 9, scenario cb: 0.048915195378246484
# -----------------------------------
# Updated WACC for solar-hsat, rc 0, scenario mb: 0.05051229927251986
# Updated WACC for solar-hsat, rc 0, scenario pb: 0.048924614244274016
# Updated WACC for solar-hsat, rc 0, scenario pi: 0.048931591804541485
# Updated WACC for solar-hsat, rc 0, scenario cb: 0.048941981824179415
# -----------------------------------
# Updated WACC for solar-hsat, rc 1, scenario mb: 0.050457423944513524
# Updated WACC for solar-hsat, rc 1, scenario pb: 0.048923374903686125
# Updated WACC for solar-hsat, rc 1, scenario pi: 0.04890350440795521
# Updated WACC for solar-hsat, rc 1, scenario cb: 0.04892019223776355
# -----------------------------------
# Updated WACC for solar-hsat, rc 2, scenario mb: 0.05044714987850665
# Updated WACC for solar-hsat, rc 2, scenario pb: 0.04891358491844968
# Updated WACC for solar-hsat, rc 2, scenario pi: 0.048906530407245595
# Updated WACC for solar-hsat, rc 2, scenario cb: 0.048925177764090076
# -----------------------------------
# Updated WACC for solar-hsat, rc 3, scenario mb: 0.050429489841218145
# Updated WACC for solar-hsat, rc 3, scenario pb: 0.048908490927306716
# Updated WACC for solar-hsat, rc 3, scenario pi: 0.04889055658086181
# Updated WACC for solar-hsat, rc 3, scenario cb: 0.04890475664680619
# -----------------------------------
# Updated WACC for solar-hsat, rc 4, scenario mb: 0.05040688769570229
# Updated WACC for solar-hsat, rc 4, scenario pb: 0.04890342593660778
# Updated WACC for solar-hsat, rc 4, scenario pi: 0.04886080737452472
# Updated WACC for solar-hsat, rc 4, scenario cb: 0.04885744990637947
# -----------------------------------
# Updated WACC for solar-hsat, rc 5, scenario mb: 0.05042705125714961
# Updated WACC for solar-hsat, rc 5, scenario pb: 0.04890182052570106
# Updated WACC for solar-hsat, rc 5, scenario pi: 0.04883725564450599
# Updated WACC for solar-hsat, rc 5, scenario cb: 0.04881895963160267
# -----------------------------------
# Updated WACC for solar-hsat, rc 6, scenario mb: 0.050434824803186375
# Updated WACC for solar-hsat, rc 6, scenario pb: 0.04890059133831367
# Updated WACC for solar-hsat, rc 6, scenario pi: 0.04882642729440463
# Updated WACC for solar-hsat, rc 6, scenario cb: 0.04873386166928085
# -----------------------------------
# Updated WACC for solar-hsat, rc 7, scenario mb: 0.0504085272873291
# Updated WACC for solar-hsat, rc 7, scenario pb: 0.04887169819435351
# Updated WACC for solar-hsat, rc 7, scenario pi: 0.04888622120908157
# Updated WACC for solar-hsat, rc 7, scenario cb: 0.04873672440700371
# -----------------------------------
# Updated WACC for solar-hsat, rc 8, scenario mb: 0.050382881916581405
# Updated WACC for solar-hsat, rc 8, scenario pb: 0.04882294118495784
# Updated WACC for solar-hsat, rc 8, scenario pi: 0.048836156376018194
# Updated WACC for solar-hsat, rc 8, scenario cb: 0.04868828375133028
# -----------------------------------
# Updated WACC for solar-hsat, rc 9, scenario mb: 0.05045489171248164
# Updated WACC for solar-hsat, rc 9, scenario pb: 0.04879663607054753
# Updated WACC for solar-hsat, rc 9, scenario pi: 0.04893236917017626
# Updated WACC for solar-hsat, rc 9, scenario cb: 0.04877927765948007
# -----------------------------------

# %%
importlib.reload(af)

af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='offwind-dc', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='onwind', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar-hsat', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_offwind-dc_cb.png
# --- Goodness of Fit Results for Offshore Wind (DC) ---
# Normal:     KS Stat = 0.1528, p-value = 0.0000e+00
# Log-Normal: KS Stat = 0.1477, p-value = 0.0000e+00
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_onwind_cb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Normal:     KS Stat = 0.1114, p-value = 0.0000e+00
# Log-Normal: KS Stat = 0.1114, p-value = 0.0000e+00
# -> The Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_solar-hsat_cb.png
# --- Goodness of Fit Results for Rotating Solar PV ---
# Normal:     KS Stat = 0.0562, p-value = 4.9436e-275
# Log-Normal: KS Stat = 0.0529, p-value = 2.9866e-243
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_solar_cb.png
# --- Goodness of Fit Results for Ground-Mounted Solar PV ---
# Normal:     KS Stat = 0.0260, p-value = 3.5210e-59
# Log-Normal: KS Stat = 0.0256, p-value = 3.1450e-57
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
#        0         1         2         3         4         5         6     \
# 0  1.007800  0.997717  0.992723  0.989009  1.006537  0.997956  0.992339
# 1  1.002768  1.004985  0.999457  0.992727  1.002856  0.996990  0.995065
# 2  1.004462  1.006946  0.998426  0.991272  1.004070  0.998730  0.992587
# 3  1.004055  1.006942  1.001396  0.993219  1.002625  0.997737  0.993526
# 4  1.002313  1.005649  1.002583  0.996365  1.000165  0.997636  0.996591
# 5  1.003603  1.001697  0.999063  0.995395  1.001461  0.998976  0.996159
# 6  1.002859  0.999740  1.002503  1.001837  0.999372  0.996674  1.000520
# 7  0.990869  0.998450  1.005644  1.013281  0.998901  0.994638  1.010587
# 8  0.992837  0.999270  0.999611  1.007513  0.999386  1.003292  1.004555
# 9  1.005894  0.985452  0.993458  0.994853  0.991798  1.012771  1.000027
#
#        7         8         9     ...      9990      9991      9992      9993  \
# 0  0.995956  1.003562  1.002297  ...  0.993268  0.990342  1.001752  1.002791
# 1  0.996124  1.000668  1.003914  ...  0.991800  0.989384  0.998817  1.001142
# 2  0.997195  1.001662  1.004831  ...  0.990002  0.992428  0.996667  1.001276
# 3  1.000793  1.000574  1.005018  ...  0.990803  0.992521  0.996112  1.001833
# 4  1.004346  1.000848  1.003595  ...  0.993694  0.994358  0.997168  1.002501
# 5  1.005708  1.003072  1.002460  ...  0.997043  0.999325  0.997737  1.000559
# 6  1.008360  1.001768  1.001277  ...  1.002353  0.999262  0.999908  1.000240
# 7  0.997581  1.000837  0.998178  ...  1.009214  1.002631  1.004182  0.997022
# 8  0.994213  0.996915  0.995017  ...  1.004935  1.007792  1.002100  0.999970
# 9  1.003746  0.995830  0.994507  ...  1.006588  1.010883  0.999909  0.996924
#
#        9994      9995      9996      9997      9998      9999
# 0  1.001630  0.988652  1.005961  1.000597  1.010285  1.008607
# 1  0.998689  0.992003  1.000719  1.002965  1.005100  1.007878
# 2  1.000517  0.995223  1.001992  1.005829  1.006762  1.007976
# 3  0.999769  0.997147  1.001899  1.004505  1.004834  1.006655
# 4  0.998616  0.999355  1.002252  1.001692  1.003678  1.005690
# 5  1.000909  1.001204  1.003063  1.001829  1.005013  1.004003
# 6  1.000104  0.999536  1.002587  0.996558  0.998875  1.001157
# 7  0.996828  1.000173  0.997538  0.993947  0.990348  0.996392
# 8  0.998905  1.003246  0.995264  1.000296  0.995521  0.991947
# 9  1.006390  1.010401  0.998890  0.998287  0.998325  0.990497
#
# [10 rows x 10000 columns]

# %%
importlib.reload(af)
af.plot_roi_per_rc(run_name, carrier='offwind-ac', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-dc', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-float', N=10000)
af.plot_roi_per_rc(run_name, carrier='onwind', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar-hsat', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-ac.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-dc.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-float.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_onwind.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar-hsat.png

# %%
importlib.reload(af)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-ac', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-dc', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-float', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='onwind', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='solar', N=10000)
# af.plot_lifetime_risk_per_rc(run_name, carrier='solar-hsat', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-ac.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-dc.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-float.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_onwind.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_solar.png

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 9
t = 30
print(af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, N=10000))
print(af.annual_revenue_risk(costs, carrier, n, rc) * (t) ** (-1/2))
# Out:
# 0.0765013543433343
# 0.04652417971471111

# %%
import importlib
importlib.reload(af)
rc=0
print(af.avg_lifetime_revenues_mcs_per_MW(run_name, n, 'onwind', rc, T=20, N=1000))
af.expected_roi_mcs(run_name, n, 'offwind-float', rc, T=20, N=1000)

# investment costs for onwind should be 1.095.853,3 EUR/kW
# Out:
# 852825.5975128612
# Calculated Offshore costs for offwind-float rc 0: Dist 57.9km, Total Life Cost 3428978
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-float: 3428977.84969747 €/MW
# -0.005682683084719589

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-ac'
af.annual_revenue_per_MW(run_name, carrier, 2000, n, 2)
# Out:
# 188911.77180655298

# %%
import importlib
importlib.reload(af)

print(af.wacc_cagr_simplified(f_cagr=0.02, T=30, sigma=0.0))
print(af.wacc_cagr_simplified(f_cagr=0.02, T=30, sigma=0.1))

print(af.wacc_irr_simplified(f_irr=0.05, T=30, sigma=0.0))
print(af.wacc_irr_simplified(f_irr=0.05, T=30, sigma=0.1))
# Out:
# 0.02
# 0.021356483826980494
# 0.05000000000000002
# 0.05361088228911649

# %%
importlib.reload(af)

#Plot debt CAGR vs. sigma
af.plot_wacc_vs_volatility()
# Out:
# Plot saved to ../results/my_plots/wacc_vs_volatility.png

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'solar-hsat'
t = 40
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 0: 1748970.213923753 €/MW
# Expected ROI for solar-hsat, rc 0: 2.6900736466845165%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 1: 1747292.8817136388 €/MW
# Expected ROI for solar-hsat, rc 1: 2.6869258018119977%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 2: 1773351.9050013581 €/MW
# Expected ROI for solar-hsat, rc 2: 2.735388722086028%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 3: 1779852.0020296462 €/MW
# Expected ROI for solar-hsat, rc 3: 2.747332200793607%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 4 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 4: 1773669.7170508187 €/MW
# Expected ROI for solar-hsat, rc 4: 2.735974008349114%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 5 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 5: 1767959.5623151467 €/MW
# Expected ROI for solar-hsat, rc 5: 2.725437179912821%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 6 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 6: 1787068.8234304534 €/MW
# Expected ROI for solar-hsat, rc 6: 2.7605261090873774%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 7 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 7: 1812151.8988997932 €/MW
# Expected ROI for solar-hsat, rc 7: 2.8058492623598474%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 8 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 8: 1904299.2069967273 €/MW
# Expected ROI for solar-hsat, rc 8: 2.9656351676055173%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 9 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 9: 2077725.7236586795 €/MW
# Expected ROI for solar-hsat, rc 9: 3.241192504151501%

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 0: 1401563.3561692934 €/MW
# Expected ROI for onwind, rc 0: -0.2998953695875714%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 1: 2620431.276215778 €/MW
# Expected ROI for onwind, rc 1: 2.353897604844978%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 2: 3073611.140212139 €/MW
# Expected ROI for onwind, rc 2: 2.9729922799553212%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 3: 3453666.9311946714 €/MW
# Expected ROI for onwind, rc 3: 3.416035529854088%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 4 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 4: 3806015.2309607132 €/MW
# Expected ROI for onwind, rc 4: 3.780034947866396%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 5 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 5: 3998465.9334173235 €/MW
# Expected ROI for onwind, rc 5: 3.963250049142255%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 6 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 6: 4363534.899637499 €/MW
# Expected ROI for onwind, rc 6: 4.285345340010701%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 7 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 7: 4634495.673881591 €/MW
# Expected ROI for onwind, rc 7: 4.505771724891173%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 8 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 8: 5153013.644447655 €/MW
# Expected ROI for onwind, rc 8: 4.8908202780234555%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 9 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 9: 6962203.825857054 €/MW
# Expected ROI for onwind, rc 9: 5.965978535404768%

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'offwind-ac'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
    print('-----------------------------------')
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-ac: 119011749.97415066 €/MW
# Annualized investment + capital costs: 6085155.166275688 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 0: 7820230.507286922 €/MW
# Expected ROI for offwind-ac, rc 0: 4.581983374006039%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 offwind-ac: 119027162.5270976 €/MW
# Annualized investment + capital costs: 6124831.9404777 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 1: 9332441.63885774 €/MW
# Expected ROI for offwind-ac, rc 1: 5.2649561682754715%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 offwind-ac: 119115274.84593372 €/MW
# Annualized investment + capital costs: 6351660.850062896 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 2: 10748364.833075166 €/MW
# Expected ROI for offwind-ac, rc 2: 5.798168015095164%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 offwind-ac: 118982218.77799998 €/MW
# Annualized investment + capital costs: 6009132.549800642 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 3: nan €/MW
# Expected ROI for offwind-ac, rc 3: nan%
# -----------------------------------

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'offwind-dc'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
    print('-----------------------------------')
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-dc: 119145132.05299999 €/MW
# Annualized investment + capital costs: 6428522.721496519 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 0: nan €/MW
# Expected ROI for offwind-dc, rc 0: nan%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 offwind-dc: 119272830.98397441 €/MW
# Annualized investment + capital costs: 6757260.0609597415 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 1: 10242817.924019352 €/MW
# Expected ROI for offwind-dc, rc 1: 5.617421375044238%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 offwind-dc: 119285656.60601264 €/MW
# Annualized investment + capital costs: 6790277.258783089 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 2: 11008443.357717419 €/MW
# Expected ROI for offwind-dc, rc 2: 5.887470056087913%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 offwind-dc: 119512784.55491354 €/MW
# Annualized investment + capital costs: 7374976.261896734 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 3: 11325462.151123935 €/MW
# Expected ROI for offwind-dc, rc 3: 5.993184061756819%
# -----------------------------------

# %%
import importlib
importlib.reload(af)
carrier = 'onwind'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for onwind, rc 0: 79664.45767261281 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 0: 0.06395775560444539
# Standard deviation of lifetime revenues per MW for onwind, rc 1: 122900.85334593887 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 1: 0.0644767691952761
# Standard deviation of lifetime revenues per MW for onwind, rc 2: 143135.70445368916 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 2: 0.06903882604043635
# Standard deviation of lifetime revenues per MW for onwind, rc 3: 153069.23605189443 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 3: 0.06758303931385985
# Standard deviation of lifetime revenues per MW for onwind, rc 4: 172199.40357082617 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 4: 0.07007581828863237
# Standard deviation of lifetime revenues per MW for onwind, rc 5: 180702.8804769587 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 5: 0.07140525166704995
# Standard deviation of lifetime revenues per MW for onwind, rc 6: 198613.7958305833 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 6: 0.0710065081856664
# Standard deviation of lifetime revenues per MW for onwind, rc 7: 212009.027693664 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 7: 0.07116775348302773
# Standard deviation of lifetime revenues per MW for onwind, rc 8: 254835.35712389706 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 8: 0.07532431827611799
# Standard deviation of lifetime revenues per MW for onwind, rc 9: 392834.8012813255 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 9: 0.08093151293274856

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-ac'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 0: 447820.18118016835 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 0: 0.08004243071641366
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 1: 558924.3326763231 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 1: 0.07748310302003324
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 2: 655393.6868321103 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 2: 0.07661015085561583
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 3: nan €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 3: nan

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-dc'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for offwind-dc, rc 0: 682106.1663329814 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-dc, rc 0: 0.0760864367637472

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
for carrier in ['offwind-dc', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        strike_price = af.strike_price_per_MW(costs, carrier, n, rc)
        print(f"Strike price for {carrier}, rc {rc}: {strike_price} €/MW")
# Out:
# Strike price for offwind-dc, rc 0: 214284.09071655062 €/MW
# Strike price for offwind-dc, rc 1: 225242.0020319914 €/MW
# Strike price for offwind-dc, rc 2: 226342.57529276964 €/MW
# Strike price for offwind-dc, rc 3: 245832.54206322448 €/MW
# Strike price for onwind, rc 0: 101644.12332388277 €/MW
# Strike price for onwind, rc 1: 101644.12332388277 €/MW
# Strike price for onwind, rc 2: 101644.12332388277 €/MW
# Strike price for onwind, rc 3: 101644.12332388277 €/MW
# Strike price for onwind, rc 4: 101644.12332388277 €/MW
# Strike price for onwind, rc 5: 101644.12332388277 €/MW
# Strike price for onwind, rc 6: 101644.12332388277 €/MW
# Strike price for onwind, rc 7: 101644.12332388277 €/MW
# Strike price for onwind, rc 8: 101644.12332388277 €/MW
# Strike price for onwind, rc 9: 101644.12332388277 €/MW
# Strike price for solar, rc 0: 38283.380189337135 €/MW
# Strike price for solar, rc 1: 38283.380189337135 €/MW
# Strike price for solar, rc 2: 38283.380189337135 €/MW
# Strike price for solar, rc 3: 38283.380189337135 €/MW
# Strike price for solar, rc 4: 38283.380189337135 €/MW
# Strike price for solar, rc 5: 38283.380189337135 €/MW
# Strike price for solar, rc 6: 38283.380189337135 €/MW
# Strike price for solar, rc 7: 38283.380189337135 €/MW
# Strike price for solar, rc 8: 38283.380189337135 €/MW
# Strike price for solar, rc 9: 38283.380189337135 €/MW
# Strike price for solar-hsat, rc 0: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 1: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 2: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 3: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 4: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 5: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 6: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 7: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 8: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 9: 44489.52419183134 €/MW

# %%
import importlib
importlib.reload(af)

carrier = 'onwind'
year = 2000
years = n.generators_t.p.index.year.unique()
costs = af.get_costs(run_name)

for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    strike_price = af.strike_price_per_MWh(costs, carrier, n, rc)
    # rev = af.annual_revenue_per_MW(costs, carrier, year, n, rc)
    # print(f"Market-based Annual revenue for {carrier}, rc {rc} in {year}: {rev} €/MW")
    # rev_con_cfd = af.annual_revenue_con_cfd_per_MW(costs, carrier, year, n, rc, strike_price)
    # print(f"Conventional CfD revenue for {carrier}, rc {rc} in {year}: {rev_con_cfd} €/MW")
    # rev_fin_cfd = af.annual_revenue_fin_cfd_per_MW(costs, carrier, year, n, rc, strike_price)
    # print(f"Financial CfD revenue for {carrier}, rc {rc} in {year}: {rev_fin_cfd} €/MW")
    # print('.......................................')
    capital_cost = n.generators.capital_cost[f'DE0 0 {rc} {carrier}']
    print(f"Capital cost for {carrier}, rc {rc}: {capital_cost} €/MW")
    rev_tot = sum([af.annual_revenue_per_MW(costs, carrier, y, n, rc) for y in years])
    print(f"Total market-based revenue for {carrier}, rc {rc} over all years: {rev_tot} €/MW")
    rev_con_cfd_tot = sum([af.annual_revenue_con_cfd_per_MW(costs, carrier, y, n, rc, strike_price) for y in years])
    print(f"Total conventional CfD revenue for {carrier}, rc {rc} over all years: {rev_con_cfd_tot} €/MW")
    rev_fin_cfd_tot = sum([af.annual_revenue_fin_cfd_per_MW(costs, carrier, y, n, rc, strike_price) for y in years])
    print(f"Total financial CfD revenue for {carrier}, rc {rc} over all years: {rev_fin_cfd_tot} €/MW")
    print('-----------------------------------')
# Out:
# Capital cost for onwind, rc 0: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 0 over all years: 1232525.759111582 €/MW
# Total conventional CfD revenue for onwind, rc 0 over all years: 3533457.6058166362 €/MW
# Total financial CfD revenue for onwind, rc 0 over all years: 17712900.369935524 €/MW
# -----------------------------------
# Capital cost for onwind, rc 1: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 1 over all years: 2266878.98181007 €/MW
# Total conventional CfD revenue for onwind, rc 1 over all years: 3505450.6073090183 €/MW
# Total financial CfD revenue for onwind, rc 1 over all years: 9826556.325886596 €/MW
# -----------------------------------
# Capital cost for onwind, rc 2: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 2 over all years: 2528155.1353878947 €/MW
# Total conventional CfD revenue for onwind, rc 2 over all years: 3495349.2150755962 €/MW
# Total financial CfD revenue for onwind, rc 2 over all years: 8841784.451989355 €/MW
# -----------------------------------
# Capital cost for onwind, rc 3: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 3 over all years: 2796721.3973040585 €/MW
# Total conventional CfD revenue for onwind, rc 3 over all years: 3483888.7021149383 €/MW
# Total financial CfD revenue for onwind, rc 3 over all years: 8110495.7014073385 €/MW
# -----------------------------------
# Capital cost for onwind, rc 4: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 4 over all years: 3012929.772192646 €/MW
# Total conventional CfD revenue for onwind, rc 4 over all years: 3473633.4865072537 €/MW
# Total financial CfD revenue for onwind, rc 4 over all years: 7663547.729819507 €/MW
# -----------------------------------
# Capital cost for onwind, rc 5: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 5 over all years: 3134383.442622863 €/MW
# Total conventional CfD revenue for onwind, rc 5 over all years: 3469721.820976288 €/MW
# Total financial CfD revenue for onwind, rc 5 over all years: 7572856.336714567 €/MW
# -----------------------------------
# Capital cost for onwind, rc 6: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 6 over all years: 3463593.168670448 €/MW
# Total conventional CfD revenue for onwind, rc 6 over all years: 3462118.847652248 €/MW
# Total financial CfD revenue for onwind, rc 6 over all years: 7539482.2608936215 €/MW
# -----------------------------------
# Capital cost for onwind, rc 7: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 7 over all years: 3662811.156547265 €/MW
# Total conventional CfD revenue for onwind, rc 7 over all years: 3457212.194978234 €/MW
# Total financial CfD revenue for onwind, rc 7 over all years: 7533878.520404613 €/MW
# -----------------------------------
# Capital cost for onwind, rc 8: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 8 over all years: 4107421.2987086526 €/MW
# Total conventional CfD revenue for onwind, rc 8 over all years: 3448646.593365514 €/MW
# Total financial CfD revenue for onwind, rc 8 over all years: 7665164.35825542 €/MW
# -----------------------------------
# Capital cost for onwind, rc 9: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 9 over all years: 5764649.374134543 €/MW
# Total conventional CfD revenue for onwind, rc 9 over all years: 3408889.5850176574 €/MW
# Total financial CfD revenue for onwind, rc 9 over all years: 8340845.279825741 €/MW
# -----------------------------------

# %%
year = 2000
carrier = 'onwind'
rc = 9
hg = af.get_hourly_generation(carrier, n, rc)
print(hg)
print('____________________________')
hg_year = hg[hg.index.year == year]
print(hg_year)
print('____________________________')
print(hg_year.values)
print(hg_year.values.sum())
# Out:
# snapshot
# 1982-01-01 00:00:00     5025.617648
# 1982-01-01 01:00:00     4545.337912
# 1982-01-01 02:00:00     4288.858902
# 1982-01-01 03:00:00     4240.467835
# 1982-01-01 04:00:00     3764.344087
#                            ...
# 2016-12-31 19:00:00    15684.415558
# 2016-12-31 20:00:00    15774.134343
# 2016-12-31 21:00:00    15782.358007
# 2016-12-31 22:00:00    15306.479209
# 2016-12-31 23:00:00    15595.239057
# Name: DE0 0 9 onwind, Length: 306600, dtype: float64
# ____________________________
# snapshot
# 2000-01-01 00:00:00    3031.792815
# 2000-01-01 01:00:00    3414.255961
# 2000-01-01 02:00:00    3609.850793
# 2000-01-01 03:00:00    4003.407405
# 2000-01-01 04:00:00    4518.664515
#                           ...
# 2000-12-31 19:00:00    4546.545429
# 2000-12-31 20:00:00    4774.522363
# 2000-12-31 21:00:00    5129.732879
# 2000-12-31 22:00:00    6004.763968
# 2000-12-31 23:00:00    5624.841536
# Name: DE0 0 9 onwind, Length: 8760, dtype: float64
# ____________________________
# [3031.79281537 3414.25596081 3609.85079314 ... 5129.73287916 6004.7639679
#  5624.84153596]
# 51475537.516917855

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 7
year = 2014
rev_mb = af.annual_revenue_per_MW(costs, carrier, year, n, rc)
print(f"Market-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_mb} €/MW")
print('-----------------------------------')
strike_price_pb = af.strike_price_PB(costs, carrier, n, rc)
rev_pb = af.annual_revenue_PB_per_MW(costs, carrier, year, n, rc, strike_price_pb)
print(f"Production-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_pb} €/MW")
print('-----------------------------------')
strike_price_pi = af.strike_price_PI(costs, carrier, n, rc)
rev_pi = af.annual_revenue_PI_per_MW(costs, carrier, year, n, rc, strike_price_pi)
print(f"Production-independent Annual revenue for {carrier}, rc {rc} in {year}: {rev_pi} €/MW")
print('-----------------------------------')
strike_price_cb = af.strike_price_CB(costs, carrier, n, rc)
rev_cb = af.annual_revenue_CB_per_MW(costs, carrier, year, n, rc, strike_price_cb)
print(f"Capacity-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_cb} €/MW")
print('-----------------------------------')
# Out:
# Market-based Annual revenue for onwind, rc 7 in 2014: 148660.56465945707 €/MW
# -----------------------------------
# Production-based Annual revenue for onwind, rc 7 in 2014: 100973.11884594103 €/MW
# -----------------------------------
# Production-independent Annual revenue for onwind, rc 7 in 2014: 91446.8354910319 €/MW
# -----------------------------------
# Capacity-based Annual revenue for onwind, rc 7 in 2014: -26154.302745327954 €/MW
# -----------------------------------
