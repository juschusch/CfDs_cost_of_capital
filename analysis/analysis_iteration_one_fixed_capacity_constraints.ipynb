# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "1_Iteration_One_v2" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.999982501348 €/MWh
# Price statistics: {'mean': 61.44879050769329, 'median': 64.29153547592509, 'std_dev': 155.77773113487103, 'min': 0.018700825950200985, 'max': 3999.999982501348}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 3041.013424156643 MW
# Total installed offshore DC capacity: 41368.4601148902 MW
# Total installed offshore floating capacity: 0.43438308886439364 MW
# Total installed onshore wind capacity: 45553.42687150418 MW
# Total installed solar capacity: 178.90822795590037 MW
# Total installed solar HSAT capacity: 163029.40351737544 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 22415.159613986812 MW
# Total installed OCGT capacity: 53495.99659805744 MW
# Total installed battery capacity: 17522.200343311262 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 36542.13572564269 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 463839661.56819725 MWh
# Total offshore DC generation: 6388194015.939276 MWh
# Total offshore floating generation: 47720.941630361 MWh
# Total onshore wind generation: 4077187085.8447285 MWh
# Total solar generation: 5302332.2496358305 MWh
# Total solar HSAT generation: 7197075488.259207 MWh
# Total CCGT generation: 2446124655.0794163 MWh
# Total OCGT generation: 1220971079.038218 MWh
# Total battery discharge: -41120198.92480653 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1840466.628020262 MWh

# %%
importlib.reload(af)

# Print average market value per carrier
for carrier in ['onwind', 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'ror', 'biomass', 'geothermal', 'CCGT', 'OCGT']:
    avg_mv = af.average_market_value_for_carrier(n, carrier)
    print(f"Average market value for {carrier}: {avg_mv:.2f} €/MWh")
    print('____________________________________________________________')

# Aggregate wind market value (scalar)
price_t = af.get_hourly_marginal_price(n, bus="DE0 0")
wind_mask = n.generators.carrier.isin(['onwind', 'offwind-ac', 'offwind-dc', 'offwind-float'])
wind_gen_t = n.generators_t.p.loc[:, wind_mask]
total_rev_wind = wind_gen_t.mul(price_t, axis=0).sum().sum()
total_gen_wind = wind_gen_t.sum().sum()
total_avg_mv_wind = total_rev_wind / total_gen_wind if total_gen_wind != 0 else 0.0
print(f"Total average market value for all wind: {total_avg_mv_wind:.2f} €/MWh")
print('____________________________________________________________')

# Aggregate solar market value (scalar)
solar_mask = n.generators.carrier.isin(['solar', 'solar-hsat'])
solar_gen_t = n.generators_t.p.loc[:, solar_mask]
total_rev_solar = solar_gen_t.mul(price_t, axis=0).sum().sum()
total_gen_solar = solar_gen_t.sum().sum()
total_avg_mv_solar = total_rev_solar / total_gen_solar if total_gen_solar != 0 else 0.0
print(f"Total average market value for all solar: {total_avg_mv_solar:.2f} €/MWh")
# Out:
# Average market value for onwind: 43.50 €/MWh
# ____________________________________________________________
# Average market value for offwind-ac: 51.93 €/MWh
# ____________________________________________________________
# Average market value for offwind-dc: 50.77 €/MWh
# ____________________________________________________________
# Average market value for offwind-float: 53.40 €/MWh
# ____________________________________________________________
# Average market value for solar: 37.55 €/MWh
# ____________________________________________________________
# Average market value for solar-hsat: 30.66 €/MWh
# ____________________________________________________________
# Average market value for ror: 64.85 €/MWh
# ____________________________________________________________
# Average market value for biomass: 104.33 €/MWh
# ____________________________________________________________
# Average market value for geothermal: 96.92 €/MWh
# ____________________________________________________________
# Average market value for CCGT: 125.48 €/MWh
# ____________________________________________________________
# Average market value for OCGT: 193.41 €/MWh
# ____________________________________________________________
# Average market value for battery: 0.00 €/MWh
# ____________________________________________________________
# Average market value for hydrogen: 0.00 €/MWh
# ____________________________________________________________
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 10
#       8 total_gen_wind = n.generators_t.p.loc[:, n.generators.carrier.isin(['onwind', 'offwind-ac', 'offwind-dc', 'offwind-float'])].sum().sum()
#       9 total_avg_mv_wind = total_rev_wind / total_gen_wind if total_gen_wind != 0 else 0
# ---> 10 print(f"Total average market value for all wind: {total_avg_mv_wind:.2f} €/MWh")
#      11 print('____________________________________________________________')
#      12 total_rev_solar = sum(af.average_market_value_for_carrier(n, carrier) * n.generators_t.p.loc[:, f"DE0 0 0 {carrier}"] for carrier in ['solar', 'solar-hsat'])
#
# TypeError: unsupported format string passed to Series.__format__

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_max[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind    45743.748412
# DE0 0 1 onwind    54117.371817
# DE0 0 2 onwind    58251.682710
# DE0 0 3 onwind    52098.507213
# DE0 0 4 onwind    50581.054172
# DE0 0 5 onwind    48267.020574
# DE0 0 6 onwind    49078.275810
# DE0 0 7 onwind    53092.707911
# DE0 0 8 onwind    48638.074786
# DE0 0 9 onwind    27968.461352
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-ac    1665.263405
# DE0 0 1 offwind-ac    9208.864488
# DE0 0 2 offwind-ac    2709.720028
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.802769
# DE0 0 2 offwind-dc    13833.554458
# DE0 0 3 offwind-dc    50358.495144
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-float    144.467403
# DE0 0 1 offwind-float    182.920728
# DE0 0 2 offwind-float    108.231258
# DE0 0 3 offwind-float     74.667750
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar    130636.363632
# DE0 0 1 solar    135780.573709
# DE0 0 2 solar    107387.176322
# DE0 0 3 solar     97614.538268
# DE0 0 4 solar    107232.765509
# DE0 0 5 solar    116601.821274
# DE0 0 6 solar     98881.173592
# DE0 0 7 solar     90797.550823
# DE0 0 8 solar    110169.652048
# DE0 0 9 solar     91472.791259
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar-hsat    114839.067548
# DE0 0 1 solar-hsat    114362.398932
# DE0 0 2 solar-hsat     92308.346032
# DE0 0 3 solar-hsat     91502.827720
# DE0 0 4 solar-hsat     92271.688846
# DE0 0 5 solar-hsat    104925.084931
# DE0 0 6 solar-hsat     79683.267813
# DE0 0 7 solar-hsat     83005.381157
# DE0 0 8 solar-hsat     94514.277451
# DE0 0 9 solar-hsat     76416.016535
# Name: p_nom_max, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.127969e+06
# DE0 0 1 onwind    3.119084e+06
# DE0 0 2 onwind    3.118160e+06
# DE0 0 3 onwind    3.115482e+06
# DE0 0 4 onwind    3.114390e+06
# DE0 0 5 onwind    3.116298e+06
# DE0 0 6 onwind    3.116572e+06
# DE0 0 7 onwind    3.116883e+06
# DE0 0 8 onwind    3.120206e+06
# DE0 0 9 onwind    3.127324e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.651806e+06
# DE0 0 1 offwind-ac    6.693376e+06
# DE0 0 2 offwind-ac    6.958907e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.432106e+06
# DE0 0 2 offwind-dc    7.470627e+06
# DE0 0 3 offwind-dc    8.152775e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    9.760443e+06
# DE0 0 1 offwind-float    9.790234e+06
# DE0 0 2 offwind-float    1.012679e+07
# DE0 0 3 offwind-float    1.111375e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.121176e+06
# DE0 0 1 solar    1.120683e+06
# DE0 0 2 solar    1.120526e+06
# DE0 0 3 solar    1.120385e+06
# DE0 0 4 solar    1.120338e+06
# DE0 0 5 solar    1.120312e+06
# DE0 0 6 solar    1.120436e+06
# DE0 0 7 solar    1.119965e+06
# DE0 0 8 solar    1.119336e+06
# DE0 0 9 solar    1.119930e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.298826e+06
# DE0 0 1 solar-hsat    1.298313e+06
# DE0 0 2 solar-hsat    1.298127e+06
# DE0 0 3 solar-hsat    1.297932e+06
# DE0 0 4 solar-hsat    1.297770e+06
# DE0 0 5 solar-hsat    1.297888e+06
# DE0 0 6 solar-hsat    1.297648e+06
# DE0 0 7 solar-hsat    1.296987e+06
# DE0 0 8 solar-hsat    1.296403e+06
# DE0 0 9 solar-hsat    1.296883e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        1.411752
# DE0 0 1 onwind        0.834318
# DE0 0 2 onwind        1.329380
# DE0 0 3 onwind        2.208141
# DE0 0 4 onwind        2.963982
# DE0 0 5 onwind        3.132269
# DE0 0 6 onwind       10.094200
# DE0 0 7 onwind     7408.219296
# DE0 0 8 onwind    21592.126729
# DE0 0 9 onwind    16502.554519
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.809597
# DE0 0 1 offwind-ac     428.539725
# DE0 0 2 offwind-ac    2709.685873
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.799596
# DE0 0 2 offwind-dc    13833.535550
# DE0 0 3 offwind-dc    27501.332956
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.100289
# DE0 0 1 offwind-float    0.127001
# DE0 0 2 offwind-float    0.172661
# DE0 0 3 offwind-float    0.132324
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar    11.088660
# DE0 0 1 solar    13.581572
# DE0 0 2 solar    14.565895
# DE0 0 3 solar    15.669475
# DE0 0 4 solar    14.396485
# DE0 0 5 solar    14.471293
# DE0 0 6 solar    16.208565
# DE0 0 7 solar    22.148558
# DE0 0 8 solar    27.578267
# DE0 0 9 solar    11.984897
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       66.431447
# DE0 0 1 solar-hsat       70.241553
# DE0 0 2 solar-hsat      353.587958
# DE0 0 3 solar-hsat     3797.512237
# DE0 0 4 solar-hsat      112.050937
# DE0 0 5 solar-hsat       53.564069
# DE0 0 6 solar-hsat    31554.581087
# DE0 0 7 solar-hsat    38773.605503
# DE0 0 8 solar-hsat    43242.963779
# DE0 0 9 solar-hsat    44825.228914
# Name: p_nom_opt, dtype: float64

# %%
importlib.reload(af)
af.plot_resource_classes_map(run_name, carrier='solar', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='solar-hsat', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='onwind', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-ac', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-dc', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-float', save_to_file=True)
# Out:
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar-hsat.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_onwind.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-ac.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-dc.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-float.png

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    cap_pot = n.generators.p_nom_max[n.generators.carrier == carrier]
    print(f"Utilization of expansion potential for {carrier}:")
    print(cap_inst / cap_pot)
# Out:
# Utilization of expansion potential for onwind:
# Generator
# DE0 0 0 onwind    0.000026
# DE0 0 1 onwind    0.000016
# DE0 0 2 onwind    0.000022
# DE0 0 3 onwind    0.000037
# DE0 0 4 onwind    0.000050
# DE0 0 5 onwind    0.000059
# DE0 0 6 onwind    0.000196
# DE0 0 7 onwind    0.140103
# DE0 0 8 onwind    0.443935
# DE0 0 9 onwind    0.590042
# dtype: float64
# Utilization of expansion potential for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.000259
# DE0 0 1 offwind-ac    0.035929
# DE0 0 2 offwind-ac    0.999999
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Utilization of expansion potential for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.999990
# DE0 0 2 offwind-dc    1.000000
# DE0 0 3 offwind-dc    0.546702
# dtype: float64
# Utilization of expansion potential for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.000696
# DE0 0 1 offwind-float    0.000547
# DE0 0 2 offwind-float    0.000948
# DE0 0 3 offwind-float    0.001755
# dtype: float64
# Utilization of expansion potential for solar:
# Generator
# DE0 0 0 solar    0.000087
# DE0 0 1 solar    0.000105
# DE0 0 2 solar    0.000144
# DE0 0 3 solar    0.000173
# DE0 0 4 solar    0.000147
# DE0 0 5 solar    0.000136
# DE0 0 6 solar    0.000182
# DE0 0 7 solar    0.000273
# DE0 0 8 solar    0.000284
# DE0 0 9 solar    0.000169
# dtype: float64
# Utilization of expansion potential for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.000613
# DE0 0 1 solar-hsat    0.000671
# DE0 0 2 solar-hsat    0.004282
# DE0 0 3 solar-hsat    0.048772
# DE0 0 4 solar-hsat    0.001423
# DE0 0 5 solar-hsat    0.000582
# DE0 0 6 solar-hsat    0.384820
# DE0 0 7 solar-hsat    0.471139
# DE0 0 8 solar-hsat    0.457490
# DE0 0 9 solar-hsat    0.586550
# dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    generation = n.generators_t.p.loc[:, n.generators.carrier == carrier].sum()
    print(f"Average capacity factor for {carrier}:")
    print(generation / cap_inst / len(n.snapshots))
# Out:
# Average capacity factor for onwind:
# Generator
# DE0 0 0 onwind    0.059268
# DE0 0 1 onwind    0.121543
# DE0 0 2 onwind    0.143906
# DE0 0 3 onwind    0.168419
# DE0 0 4 onwind    0.192372
# DE0 0 5 onwind    0.205539
# DE0 0 6 onwind    0.224651
# DE0 0 7 onwind    0.235392
# DE0 0 8 onwind    0.266373
# DE0 0 9 onwind    0.351367
# dtype: float64
# Average capacity factor for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.347498
# DE0 0 1 offwind-ac    0.442401
# DE0 0 2 offwind-ac    0.488242
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Average capacity factor for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.411175
# DE0 0 2 offwind-dc    0.504784
# DE0 0 3 offwind-dc    0.503652
# dtype: float64
# Average capacity factor for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.177456
# DE0 0 1 offwind-float    0.261482
# DE0 0 2 offwind-float    0.326012
# DE0 0 3 offwind-float    0.365396
# dtype: float64
# Average capacity factor for solar:
# Generator
# DE0 0 0 solar    0.098827
# DE0 0 1 solar    0.100089
# DE0 0 2 solar    0.101097
# DE0 0 3 solar    0.102170
# DE0 0 4 solar    0.103546
# DE0 0 5 solar    0.104692
# DE0 0 6 solar    0.106263
# DE0 0 7 solar    0.109291
# DE0 0 8 solar    0.114582
# DE0 0 9 solar    0.121531
# dtype: float64
# Average capacity factor for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.116860
# DE0 0 1 solar-hsat    0.118251
# DE0 0 2 solar-hsat    0.118422
# DE0 0 3 solar-hsat    0.122933
# DE0 0 4 solar-hsat    0.121545
# DE0 0 5 solar-hsat    0.123870
# DE0 0 6 solar-hsat    0.138844
# DE0 0 7 solar-hsat    0.139576
# DE0 0 8 solar-hsat    0.145791
# DE0 0 9 solar-hsat    0.152398
# dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17506.316291
# DE0 0 H2             0.314826
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 936794882.7398388 MWh
# Total PHS output: 425473739.0114251 MWh
# Total H2 output: 5165.893751287589 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    # af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['pc'])

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pc', 'pb', 'pi', 'cb']:    
            avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Avg lifetime rev. per MW of {carrier}, rc {rc}, sc. {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Avg lifetime rev. per MW of offwind-ac, rc 0, sc. mb: 4401212.405106108
# Avg lifetime rev. per MW of offwind-ac, rc 0, sc. pc: 4219578.659885555
# Avg lifetime rev. per MW of offwind-ac, rc 0, sc. pb: 4403907.842092464
# Avg lifetime rev. per MW of offwind-ac, rc 0, sc. pi: 4405047.732497451
# Avg lifetime rev. per MW of offwind-ac, rc 0, sc. cb: 4405463.225914886
# -----------------------------------
# Avg lifetime rev. per MW of offwind-ac, rc 1, sc. mb: 5737420.813779981
# Avg lifetime rev. per MW of offwind-ac, rc 1, sc. pc: 5487695.669610968
# Avg lifetime rev. per MW of offwind-ac, rc 1, sc. pb: 5740596.284089888
# Avg lifetime rev. per MW of offwind-ac, rc 1, sc. pi: 5741256.141171326
# Avg lifetime rev. per MW of offwind-ac, rc 1, sc. cb: 5741671.634588762
# -----------------------------------
# Avg lifetime rev. per MW of offwind-ac, rc 2, sc. mb: 6717699.454374674
# Avg lifetime rev. per MW of offwind-ac, rc 2, sc. pc: 6427745.264101173
# Avg lifetime rev. per MW of offwind-ac, rc 2, sc. pb: 6721615.567457985
# Avg lifetime rev. per MW of offwind-ac, rc 2, sc. pi: 6721534.781766019
# Avg lifetime rev. per MW of offwind-ac, rc 2, sc. cb: 6721950.275183453
# -----------------------------------
# Avg lifetime rev. per MW of offwind-ac, rc 3, sc. mb: nan
# Avg lifetime rev. per MW of offwind-ac, rc 3, sc. pc: nan
# Avg lifetime rev. per MW of offwind-ac, rc 3, sc. pb: nan
# Avg lifetime rev. per MW of offwind-ac, rc 3, sc. pi: nan
# Avg lifetime rev. per MW of offwind-ac, rc 3, sc. cb: nan
# -----------------------------------
# Avg lifetime rev. per MW of offwind-dc, rc 0, sc. mb: nan
# Avg lifetime rev. per MW of offwind-dc, rc 0, sc. pc: nan
# Avg lifetime rev. per MW of offwind-dc, rc 0, sc. pb: nan
# Avg lifetime rev. per MW of offwind-dc, rc 0, sc. pi: nan
# Avg lifetime rev. per MW of offwind-dc, rc 0, sc. cb: nan
# -----------------------------------
# Avg lifetime rev. per MW of offwind-dc, rc 1, sc. mb: 6741948.728391983
# Avg lifetime rev. per MW of offwind-dc, rc 1, sc. pc: 6405684.105660195
# Avg lifetime rev. per MW of offwind-dc, rc 1, sc. pb: 6744799.337941713
# Avg lifetime rev. per MW of offwind-dc, rc 1, sc. pi: 6746450.288760746
# Avg lifetime rev. per MW of offwind-dc, rc 1, sc. cb: 6747184.733458206
# -----------------------------------
# Avg lifetime rev. per MW of offwind-dc, rc 2, sc. mb: 6722248.186996096
# Avg lifetime rev. per MW of offwind-dc, rc 2, sc. pc: 6467158.229793982
# Avg lifetime rev. per MW of offwind-dc, rc 2, sc. pb: 6726473.601046234
# Avg lifetime rev. per MW of offwind-dc, rc 2, sc. pi: 6726749.74736486
# Avg lifetime rev. per MW of offwind-dc, rc 2, sc. cb: 6727484.192062321
# -----------------------------------
# Avg lifetime rev. per MW of offwind-dc, rc 3, sc. mb: 6990862.16713553
# Avg lifetime rev. per MW of offwind-dc, rc 3, sc. pc: 6728469.100209446
# Avg lifetime rev. per MW of offwind-dc, rc 3, sc. pb: 6995502.399871602
# Avg lifetime rev. per MW of offwind-dc, rc 3, sc. pi: 6995363.727504295
# Avg lifetime rev. per MW of offwind-dc, rc 3, sc. cb: 6996098.172201756
# -----------------------------------
# Avg lifetime rev. per MW of offwind-float, rc 0, sc. mb: 1496363.148831818
# Avg lifetime rev. per MW of offwind-float, rc 0, sc. pc: 1436416.0932127007
# Avg lifetime rev. per MW of offwind-float, rc 0, sc. pb: 1496353.252829311
# Avg lifetime rev. per MW of offwind-float, rc 0, sc. pi: 1496218.9389127435
# Avg lifetime rev. per MW of offwind-float, rc 0, sc. cb: 1496557.3134911258
# -----------------------------------
# Avg lifetime rev. per MW of offwind-float, rc 1, sc. mb: 2299421.9731796915
# Avg lifetime rev. per MW of offwind-float, rc 1, sc. pc: 2202109.5512246266
# Avg lifetime rev. per MW of offwind-float, rc 1, sc. pb: 2299312.3433572603
# Avg lifetime rev. per MW of offwind-float, rc 1, sc. pi: 2299277.763260617
# Avg lifetime rev. per MW of offwind-float, rc 1, sc. cb: 2299616.1378389993
# -----------------------------------
# Avg lifetime rev. per MW of offwind-float, rc 2, sc. mb: 3130991.363830549
# Avg lifetime rev. per MW of offwind-float, rc 2, sc. pc: 2988040.020899601
# Avg lifetime rev. per MW of offwind-float, rc 2, sc. pb: 3130661.081778314
# Avg lifetime rev. per MW of offwind-float, rc 2, sc. pi: 3130847.1539114746
# Avg lifetime rev. per MW of offwind-float, rc 2, sc. cb: 3131185.5284898565
# -----------------------------------
# Avg lifetime rev. per MW of offwind-float, rc 3, sc. mb: 3488090.400813054
# Avg lifetime rev. per MW of offwind-float, rc 3, sc. pc: 3358243.913868215
# Avg lifetime rev. per MW of offwind-float, rc 3, sc. pb: 3487946.7406310495
# Avg lifetime rev. per MW of offwind-float, rc 3, sc. pi: 3487946.1908939797
# Avg lifetime rev. per MW of offwind-float, rc 3, sc. cb: 3488284.5654723616
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 0, sc. mb: 1078698.4563909252
# Avg lifetime rev. per MW of onwind, rc 0, sc. pc: 1017111.652374007
# Avg lifetime rev. per MW of onwind, rc 0, sc. pb: 1079357.076822474
# Avg lifetime rev. per MW of onwind, rc 0, sc. pi: 1080671.3512381937
# Avg lifetime rev. per MW of onwind, rc 0, sc. cb: 1080850.8037707037
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 1, sc. mb: 1832457.0408013351
# Avg lifetime rev. per MW of onwind, rc 1, sc. pc: 1733673.487349366
# Avg lifetime rev. per MW of onwind, rc 1, sc. pb: 1833324.6391410427
# Avg lifetime rev. per MW of onwind, rc 1, sc. pi: 1834429.9356486034
# Avg lifetime rev. per MW of onwind, rc 1, sc. cb: 1834609.3881811139
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 2, sc. mb: 2028156.175682275
# Avg lifetime rev. per MW of onwind, rc 2, sc. pc: 1919113.6052685112
# Avg lifetime rev. per MW of onwind, rc 2, sc. pb: 2028938.7145187492
# Avg lifetime rev. per MW of onwind, rc 2, sc. pi: 2030129.070529544
# Avg lifetime rev. per MW of onwind, rc 2, sc. cb: 2030308.5230620545
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 3, sc. mb: 2184666.9374110834
# Avg lifetime rev. per MW of onwind, rc 3, sc. pc: 2074648.8229067237
# Avg lifetime rev. per MW of onwind, rc 3, sc. pb: 2185528.889973939
# Avg lifetime rev. per MW of onwind, rc 3, sc. pi: 2186639.8322583516
# Avg lifetime rev. per MW of onwind, rc 3, sc. cb: 2186819.2847908614
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 4, sc. mb: 2261223.2565647285
# Avg lifetime rev. per MW of onwind, rc 4, sc. pc: 2161066.409128152
# Avg lifetime rev. per MW of onwind, rc 4, sc. pb: 2262460.668516544
# Avg lifetime rev. per MW of onwind, rc 4, sc. pi: 2263196.1514119976
# Avg lifetime rev. per MW of onwind, rc 4, sc. cb: 2263375.603944507
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 5, sc. mb: 2280770.516599855
# Avg lifetime rev. per MW of onwind, rc 5, sc. pc: 2186683.414541247
# Avg lifetime rev. per MW of onwind, rc 5, sc. pb: 2282220.9653124777
# Avg lifetime rev. per MW of onwind, rc 5, sc. pi: 2282743.411447123
# Avg lifetime rev. per MW of onwind, rc 5, sc. cb: 2282922.863979634
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 6, sc. mb: 2467874.6665651025
# Avg lifetime rev. per MW of onwind, rc 6, sc. pc: 2364753.5795956026
# Avg lifetime rev. per MW of onwind, rc 6, sc. pb: 2469372.4192563677
# Avg lifetime rev. per MW of onwind, rc 6, sc. pi: 2469847.5614123708
# Avg lifetime rev. per MW of onwind, rc 6, sc. cb: 2470027.0139448806
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 7, sc. mb: 2589141.7706131334
# Avg lifetime rev. per MW of onwind, rc 7, sc. pc: 2483420.2473828965
# Avg lifetime rev. per MW of onwind, rc 7, sc. pb: 2590644.857795842
# Avg lifetime rev. per MW of onwind, rc 7, sc. pi: 2591114.665460402
# Avg lifetime rev. per MW of onwind, rc 7, sc. cb: 2591294.117992912
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 8, sc. mb: 2840734.8034442747
# Avg lifetime rev. per MW of onwind, rc 8, sc. pc: 2729253.7368951826
# Avg lifetime rev. per MW of onwind, rc 8, sc. pb: 2842445.510723707
# Avg lifetime rev. per MW of onwind, rc 8, sc. pi: 2842707.6982915434
# Avg lifetime rev. per MW of onwind, rc 8, sc. cb: 2842887.1508240537
# -----------------------------------
# Avg lifetime rev. per MW of onwind, rc 9, sc. mb: 3811902.095966197
# Avg lifetime rev. per MW of onwind, rc 9, sc. pc: 3664822.960486087
# Avg lifetime rev. per MW of onwind, rc 9, sc. pb: 3814430.8716419493
# Avg lifetime rev. per MW of onwind, rc 9, sc. pi: 3813874.990813466
# Avg lifetime rev. per MW of onwind, rc 9, sc. cb: 3814054.443345976
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 0, sc. mb: 1199774.2387077475
# Avg lifetime rev. per MW of solar, rc 0, sc. pc: 1159200.4193072696
# Avg lifetime rev. per MW of solar, rc 0, sc. pb: 1199193.3404741662
# Avg lifetime rev. per MW of solar, rc 0, sc. pi: 1199215.7666708806
# Avg lifetime rev. per MW of solar, rc 0, sc. cb: 1199174.8918656842
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 1, sc. mb: 1211120.691984639
# Avg lifetime rev. per MW of solar, rc 1, sc. pc: 1171102.8347594498
# Avg lifetime rev. per MW of solar, rc 1, sc. pb: 1210558.7977989449
# Avg lifetime rev. per MW of solar, rc 1, sc. pi: 1210562.2199477716
# Avg lifetime rev. per MW of solar, rc 1, sc. cb: 1210521.3451425752
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 2, sc. mb: 1214483.3731549128
# Avg lifetime rev. per MW of solar, rc 2, sc. pc: 1174567.2475156286
# Avg lifetime rev. per MW of solar, rc 2, sc. pb: 1213927.078251654
# Avg lifetime rev. per MW of solar, rc 2, sc. pi: 1213924.9011180457
# Avg lifetime rev. per MW of solar, rc 2, sc. cb: 1213884.0263128493
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 3, sc. mb: 1218070.6760953313
# Avg lifetime rev. per MW of solar, rc 3, sc. pc: 1178308.6884924427
# Avg lifetime rev. per MW of solar, rc 3, sc. pb: 1217520.0151825228
# Avg lifetime rev. per MW of solar, rc 3, sc. pi: 1217512.2040584644
# Avg lifetime rev. per MW of solar, rc 3, sc. cb: 1217471.329253268
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 4, sc. mb: 1213794.1893791002
# Avg lifetime rev. per MW of solar, rc 4, sc. pc: 1175287.7681592235
# Avg lifetime rev. per MW of solar, rc 4, sc. pb: 1213226.0083191379
# Avg lifetime rev. per MW of solar, rc 4, sc. pi: 1213235.7173422328
# Avg lifetime rev. per MW of solar, rc 4, sc. cb: 1213194.8425370369
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 5, sc. mb: 1214293.5833509483
# Avg lifetime rev. per MW of solar, rc 5, sc. pc: 1175504.5923160578
# Avg lifetime rev. per MW of solar, rc 5, sc. pb: 1213726.8489793418
# Avg lifetime rev. per MW of solar, rc 5, sc. pi: 1213735.111314081
# Avg lifetime rev. per MW of solar, rc 5, sc. cb: 1213694.2365088847
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 6, sc. mb: 1220781.4153099186
# Avg lifetime rev. per MW of solar, rc 6, sc. pc: 1180975.5369807698
# Avg lifetime rev. per MW of solar, rc 6, sc. pb: 1220232.588141866
# Avg lifetime rev. per MW of solar, rc 6, sc. pi: 1220222.9432730514
# Avg lifetime rev. per MW of solar, rc 6, sc. cb: 1220182.068467855
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 7, sc. mb: 1233942.1003893705
# Avg lifetime rev. per MW of solar, rc 7, sc. pc: 1194907.7419310329
# Avg lifetime rev. per MW of solar, rc 7, sc. pb: 1233407.0580180879
# Avg lifetime rev. per MW of solar, rc 7, sc. pi: 1233383.6283525033
# Avg lifetime rev. per MW of solar, rc 7, sc. cb: 1233342.7535473069
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 8, sc. mb: 1277584.0493363182
# Avg lifetime rev. per MW of solar, rc 8, sc. pc: 1237206.952838758
# Avg lifetime rev. per MW of solar, rc 8, sc. pb: 1277045.9994215032
# Avg lifetime rev. per MW of solar, rc 8, sc. pi: 1277025.577299451
# Avg lifetime rev. per MW of solar, rc 8, sc. cb: 1276984.7024942546
# -----------------------------------
# Avg lifetime rev. per MW of solar, rc 9, sc. mb: 1369209.9233413802
# Avg lifetime rev. per MW of solar, rc 9, sc. pc: 1323265.1847881353
# Avg lifetime rev. per MW of solar, rc 9, sc. pb: 1368597.7537545192
# Avg lifetime rev. per MW of solar, rc 9, sc. pi: 1368651.4513045133
# Avg lifetime rev. per MW of solar, rc 9, sc. cb: 1368610.5764993168
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 0, sc. mb: 1464228.76947424
# Avg lifetime rev. per MW of solar-hsat, rc 0, sc. pc: 1417413.3479063925
# Avg lifetime rev. per MW of solar-hsat, rc 0, sc. pb: 1463515.5925471485
# Avg lifetime rev. per MW of solar-hsat, rc 0, sc. pi: 1463530.4310624525
# Avg lifetime rev. per MW of solar-hsat, rc 0, sc. cb: 1463508.0040767372
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 1, sc. mb: 1464517.2565683809
# Avg lifetime rev. per MW of solar-hsat, rc 1, sc. pc: 1419078.5000586684
# Avg lifetime rev. per MW of solar-hsat, rc 1, sc. pb: 1463831.2526602761
# Avg lifetime rev. per MW of solar-hsat, rc 1, sc. pi: 1463818.9181565933
# Avg lifetime rev. per MW of solar-hsat, rc 1, sc. cb: 1463796.4911708785
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 2, sc. mb: 1478751.70585147
# Avg lifetime rev. per MW of solar-hsat, rc 2, sc. pc: 1433016.0901048474
# Avg lifetime rev. per MW of solar-hsat, rc 2, sc. pb: 1478070.3355991836
# Avg lifetime rev. per MW of solar-hsat, rc 2, sc. pi: 1478053.3674396824
# Avg lifetime rev. per MW of solar-hsat, rc 2, sc. cb: 1478030.9404539673
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 3, sc. mb: 1482699.7421838145
# Avg lifetime rev. per MW of solar-hsat, rc 3, sc. pc: 1437048.212451375
# Avg lifetime rev. per MW of solar-hsat, rc 3, sc. pb: 1482011.7573494453
# Avg lifetime rev. per MW of solar-hsat, rc 3, sc. pi: 1482001.4037720265
# Avg lifetime rev. per MW of solar-hsat, rc 3, sc. cb: 1481978.9767863113
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 4, sc. mb: 1470551.6983774514
# Avg lifetime rev. per MW of solar-hsat, rc 4, sc. pc: 1426164.2963099284
# Avg lifetime rev. per MW of solar-hsat, rc 4, sc. pb: 1469866.665703309
# Avg lifetime rev. per MW of solar-hsat, rc 4, sc. pi: 1469853.3599656636
# Avg lifetime rev. per MW of solar-hsat, rc 4, sc. cb: 1469830.9329799484
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 5, sc. mb: 1459609.254507003
# Avg lifetime rev. per MW of solar-hsat, rc 5, sc. pc: 1415440.1842688976
# Avg lifetime rev. per MW of solar-hsat, rc 5, sc. pb: 1458923.070314986
# Avg lifetime rev. per MW of solar-hsat, rc 5, sc. pi: 1458910.9160952156
# Avg lifetime rev. per MW of solar-hsat, rc 5, sc. cb: 1458888.4891095003
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 6, sc. mb: 1483308.2239523358
# Avg lifetime rev. per MW of solar-hsat, rc 6, sc. pc: 1437226.3850959465
# Avg lifetime rev. per MW of solar-hsat, rc 6, sc. pb: 1482620.6433312867
# Avg lifetime rev. per MW of solar-hsat, rc 6, sc. pi: 1482609.885540548
# Avg lifetime rev. per MW of solar-hsat, rc 6, sc. cb: 1482587.4585548327
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 7, sc. mb: 1482954.5411469892
# Avg lifetime rev. per MW of solar-hsat, rc 7, sc. pc: 1438691.60850549
# Avg lifetime rev. per MW of solar-hsat, rc 7, sc. pb: 1482282.812597036
# Avg lifetime rev. per MW of solar-hsat, rc 7, sc. pi: 1482256.202735202
# Avg lifetime rev. per MW of solar-hsat, rc 7, sc. cb: 1482233.7757494869
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 8, sc. mb: 1517442.6017061768
# Avg lifetime rev. per MW of solar-hsat, rc 8, sc. pc: 1472166.8731156322
# Avg lifetime rev. per MW of solar-hsat, rc 8, sc. pb: 1516764.379135968
# Avg lifetime rev. per MW of solar-hsat, rc 8, sc. pi: 1516744.2632943892
# Avg lifetime rev. per MW of solar-hsat, rc 8, sc. cb: 1516721.8363086742
# -----------------------------------
# Avg lifetime rev. per MW of solar-hsat, rc 9, sc. mb: 1632879.9598186936
# Avg lifetime rev. per MW of solar-hsat, rc 9, sc. pc: 1580333.1578211864
# Avg lifetime rev. per MW of solar-hsat, rc 9, sc. pb: 1632133.1222554545
# Avg lifetime rev. per MW of solar-hsat, rc 9, sc. pi: 1632181.6214069058
# Avg lifetime rev. per MW of solar-hsat, rc 9, sc. cb: 1632159.1944211908
# -----------------------------------

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pc', 'pb', 'pi', 'cb']:    
            risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Rel. rev. risk per MW of {carrier}, rc {rc}, sc. {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Rel. rev. risk per MW of offwind-ac, rc 0, sc. mb: 0.08260905423483038
# Rel. rev. risk per MW of offwind-ac, rc 0, sc. pc: 0.06282519385315653
# Rel. rev. risk per MW of offwind-ac, rc 0, sc. pb: 0.009502941172035042
# Rel. rev. risk per MW of offwind-ac, rc 0, sc. pi: 0.03966430935964379
# Rel. rev. risk per MW of offwind-ac, rc 0, sc. cb: 0.03722000246974384
# -----------------------------------
# Rel. rev. risk per MW of offwind-ac, rc 1, sc. mb: 0.08012288672109436
# Rel. rev. risk per MW of offwind-ac, rc 1, sc. pc: 0.05911793570446826
# Rel. rev. risk per MW of offwind-ac, rc 1, sc. pb: 0.007970792855403612
# Rel. rev. risk per MW of offwind-ac, rc 1, sc. pi: 0.015108088177188356
# Rel. rev. risk per MW of offwind-ac, rc 1, sc. cb: 0.0121493624945163
# -----------------------------------
# Rel. rev. risk per MW of offwind-ac, rc 2, sc. mb: 0.07934045673640805
# Rel. rev. risk per MW of offwind-ac, rc 2, sc. pc: 0.05884930737318033
# Rel. rev. risk per MW of offwind-ac, rc 2, sc. pb: 0.006569339474651277
# Rel. rev. risk per MW of offwind-ac, rc 2, sc. pi: 0.006514110095605365
# Rel. rev. risk per MW of offwind-ac, rc 2, sc. cb: 0.001270899751785132
# -----------------------------------
# Rel. rev. risk per MW of offwind-ac, rc 3, sc. mb: nan
# Rel. rev. risk per MW of offwind-ac, rc 3, sc. pc: nan
# Rel. rev. risk per MW of offwind-ac, rc 3, sc. pb: nan
# Rel. rev. risk per MW of offwind-ac, rc 3, sc. pi: nan
# Rel. rev. risk per MW of offwind-ac, rc 3, sc. cb: nan
# -----------------------------------
# Rel. rev. risk per MW of offwind-dc, rc 0, sc. mb: nan
# Rel. rev. risk per MW of offwind-dc, rc 0, sc. pc: nan
# Rel. rev. risk per MW of offwind-dc, rc 0, sc. pb: nan
# Rel. rev. risk per MW of offwind-dc, rc 0, sc. pi: nan
# Rel. rev. risk per MW of offwind-dc, rc 0, sc. cb: nan
# -----------------------------------
# Rel. rev. risk per MW of offwind-dc, rc 1, sc. mb: 0.07972573983805417
# Rel. rev. risk per MW of offwind-dc, rc 1, sc. pc: 0.05586394117997963
# Rel. rev. risk per MW of offwind-dc, rc 1, sc. pb: 0.007346481547050702
# Rel. rev. risk per MW of offwind-dc, rc 1, sc. pi: 0.014076362187903367
# Rel. rev. risk per MW of offwind-dc, rc 1, sc. cb: 0.014432939662105215
# -----------------------------------
# Rel. rev. risk per MW of offwind-dc, rc 2, sc. mb: 0.0778099665319904
# Rel. rev. risk per MW of offwind-dc, rc 2, sc. pc: 0.06007337113013875
# Rel. rev. risk per MW of offwind-dc, rc 2, sc. pb: 0.00759780991756177
# Rel. rev. risk per MW of offwind-dc, rc 2, sc. pi: 0.008786318821411601
# Rel. rev. risk per MW of offwind-dc, rc 2, sc. cb: 0.003509010041641942
# -----------------------------------
# Rel. rev. risk per MW of offwind-dc, rc 3, sc. mb: 0.07849174504793752
# Rel. rev. risk per MW of offwind-dc, rc 3, sc. pc: 0.06099629939043983
# Rel. rev. risk per MW of offwind-dc, rc 3, sc. pb: 0.007026703676759854
# Rel. rev. risk per MW of offwind-dc, rc 3, sc. pi: 0.006906552055942388
# Rel. rev. risk per MW of offwind-dc, rc 3, sc. cb: 0.0016956688657894948
# -----------------------------------
# Rel. rev. risk per MW of offwind-float, rc 0, sc. mb: 0.10957102580845222
# Rel. rev. risk per MW of offwind-float, rc 0, sc. pc: 0.08659262811847991
# Rel. rev. risk per MW of offwind-float, rc 0, sc. pb: 0.015336329217698026
# Rel. rev. risk per MW of offwind-float, rc 0, sc. pi: 0.07458767231796441
# Rel. rev. risk per MW of offwind-float, rc 0, sc. cb: 0.08135833685878785
# -----------------------------------
# Rel. rev. risk per MW of offwind-float, rc 1, sc. mb: 0.10777591104963408
# Rel. rev. risk per MW of offwind-float, rc 1, sc. pc: 0.08343273106160107
# Rel. rev. risk per MW of offwind-float, rc 1, sc. pb: 0.013628955279379497
# Rel. rev. risk per MW of offwind-float, rc 1, sc. pi: 0.017574096449334116
# Rel. rev. risk per MW of offwind-float, rc 1, sc. cb: 0.017443891762599355
# -----------------------------------
# Rel. rev. risk per MW of offwind-float, rc 2, sc. mb: 0.10793666658077643
# Rel. rev. risk per MW of offwind-float, rc 2, sc. pc: 0.08191928991137017
# Rel. rev. risk per MW of offwind-float, rc 2, sc. pb: 0.01214554110832746
# Rel. rev. risk per MW of offwind-float, rc 2, sc. pi: 0.023623351885396555
# Rel. rev. risk per MW of offwind-float, rc 2, sc. cb: 0.017804485932863757
# -----------------------------------
# Rel. rev. risk per MW of offwind-float, rc 3, sc. mb: 0.10486385938631514
# Rel. rev. risk per MW of offwind-float, rc 3, sc. pc: 0.08431880874910397
# Rel. rev. risk per MW of offwind-float, rc 3, sc. pb: 0.011611216569466622
# Rel. rev. risk per MW of offwind-float, rc 3, sc. pi: 0.029150169127834937
# Rel. rev. risk per MW of offwind-float, rc 3, sc. cb: 0.024212922104168953
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 0, sc. mb: 0.08186533878903511
# Rel. rev. risk per MW of onwind, rc 0, sc. pc: 0.05713567544617076
# Rel. rev. risk per MW of onwind, rc 0, sc. pb: 0.023237632778027262
# Rel. rev. risk per MW of onwind, rc 0, sc. pi: 0.17390947804020693
# Rel. rev. risk per MW of onwind, rc 0, sc. cb: 0.15220433808319195
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 1, sc. mb: 0.07370481753769444
# Rel. rev. risk per MW of onwind, rc 1, sc. pc: 0.050942734246816626
# Rel. rev. risk per MW of onwind, rc 1, sc. pb: 0.024215330393795198
# Rel. rev. risk per MW of onwind, rc 1, sc. pi: 0.08192298867499069
# Rel. rev. risk per MW of onwind, rc 1, sc. cb: 0.07025561996360029
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 2, sc. mb: 0.07316287530113055
# Rel. rev. risk per MW of onwind, rc 2, sc. pc: 0.05076483807747546
# Rel. rev. risk per MW of onwind, rc 2, sc. pb: 0.021908478072936492
# Rel. rev. risk per MW of onwind, rc 2, sc. pi: 0.06859938392868253
# Rel. rev. risk per MW of onwind, rc 2, sc. cb: 0.059035606446823374
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 3, sc. mb: 0.07144324473948155
# Rel. rev. risk per MW of onwind, rc 3, sc. pc: 0.049750503833116175
# Rel. rev. risk per MW of onwind, rc 3, sc. pb: 0.020491018804528402
# Rel. rev. risk per MW of onwind, rc 3, sc. pi: 0.05932473459859454
# Rel. rev. risk per MW of onwind, rc 3, sc. cb: 0.050228119884267966
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 4, sc. mb: 0.07070892748700383
# Rel. rev. risk per MW of onwind, rc 4, sc. pc: 0.04977928506119591
# Rel. rev. risk per MW of onwind, rc 4, sc. pb: 0.019763203703783577
# Rel. rev. risk per MW of onwind, rc 4, sc. pi: 0.052345260243687665
# Rel. rev. risk per MW of onwind, rc 4, sc. cb: 0.04134603477535576
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 5, sc. mb: 0.07270499542307166
# Rel. rev. risk per MW of onwind, rc 5, sc. pc: 0.05276552948637588
# Rel. rev. risk per MW of onwind, rc 5, sc. pb: 0.01891809342936834
# Rel. rev. risk per MW of onwind, rc 5, sc. pi: 0.04882108757257541
# Rel. rev. risk per MW of onwind, rc 5, sc. cb: 0.03656985521749469
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 6, sc. mb: 0.07219595079540919
# Rel. rev. risk per MW of onwind, rc 6, sc. pc: 0.05205961249924356
# Rel. rev. risk per MW of onwind, rc 6, sc. pb: 0.017328180598772364
# Rel. rev. risk per MW of onwind, rc 6, sc. pi: 0.039099434441637736
# Rel. rev. risk per MW of onwind, rc 6, sc. cb: 0.027790105940960493
# -----------------------------------
# Rel. rev. risk per MW of onwind, rc 7, sc. mb: 0.07180603971060409
# Rel. rev. risk per MW of onwind, rc 7, sc. pc: 0.05236407532685784
# Rel. rev. risk per MW of onwind, rc 7, sc. pb: 0.016988182498123172
RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario cb: 0.07
# -----------------------------------
# Updated WACC for offwind-dc, rc 1, scenario mb: 0.060500866561455535
# Updated WACC for offwind-dc, rc 1, scenario pc: 0.06799779989495612
# Updated WACC for offwind-dc, rc 1, scenario pb: 0.05777023108297139
# Updated WACC for offwind-dc, rc 1, scenario pi: 0.0580188841013144
# Updated WACC for offwind-dc, rc 1, scenario cb: 0.05803208830604986
# -----------------------------------
# Updated WACC for offwind-dc, rc 2, scenario mb: 0.06042696348289029
# Updated WACC for offwind-dc, rc 2, scenario pc: 0.06610029797430018
# Updated WACC for offwind-dc, rc 2, scenario pb: 0.05777949807633893
# Updated WACC for offwind-dc, rc 2, scenario pi: 0.057823340773957774
# Updated WACC for offwind-dc, rc 2, scenario cb: 0.05762891815655913
# -----------------------------------
# Updated WACC for offwind-dc, rc 3, scenario mb: 0.060453253527030675
# Updated WACC for offwind-dc, rc 3, scenario pc: 0.06650506497491457
# Updated WACC for offwind-dc, rc 3, scenario pb: 0.05775844234224414
# Updated WACC for offwind-dc, rc 3, scenario pi: 0.057754013519395915
# Updated WACC for offwind-dc, rc 3, scenario cb: 0.05756226182954436
# -----------------------------------
# Updated WACC for offwind-float, rc 0, scenario mb: 0.06300898636951313
# Updated WACC for offwind-float, rc 0, scenario pc: 0.07116821733561861
# Updated WACC for offwind-float, rc 0, scenario pb: 0.05824901142171439
# Updated WACC for offwind-float, rc 0, scenario pi: 0.061209720597515324
# Updated WACC for offwind-float, rc 0, scenario cb: 0.06155493819202706
# -----------------------------------
# Updated WACC for offwind-float, rc 1, scenario mb: 0.06291571487058255
# Updated WACC for offwind-float, rc 1, scenario pc: 0.07157075450969674
# Updated WACC for offwind-float, rc 1, scenario pb: 0.05816527738368039
# Updated WACC for offwind-float, rc 1, scenario pi: 0.05835888970254981
# Updated WACC for offwind-float, rc 1, scenario cb: 0.05835249230647697
# -----------------------------------
# Updated WACC for offwind-float, rc 2, scenario mb: 0.06292406328938437
# Updated WACC for offwind-float, rc 2, scenario pc: 0.07260397220467707
# Updated WACC for offwind-float, rc 2, scenario pb: 0.05809259780172777
# Updated WACC for offwind-float, rc 2, scenario pi: 0.05865667213246757
# Updated WACC for offwind-float, rc 2, scenario cb: 0.05837021076363272
# -----------------------------------
# Updated WACC for offwind-float, rc 3, scenario mb: 0.06276462795909193
# Updated WACC for offwind-float, rc 3, scenario pc: 0.07132961591008707
# Updated WACC for offwind-float, rc 3, scenario pb: 0.05806643481068831
# Updated WACC for offwind-float, rc 3, scenario pi: 0.058929701432392005
# Updated WACC for offwind-float, rc 3, scenario cb: 0.058685753433230424
# -----------------------------------
# Updated WACC for onwind, rc 0, scenario mb: 0.0558941960221809
# Updated WACC for onwind, rc 0, scenario pc: 0.0619859024090185
# Updated WACC for onwind, rc 0, scenario pb: 0.05373436049512942
# Updated WACC for onwind, rc 0, scenario pi: 0.05945015764241678
# Updated WACC for onwind, rc 0, scenario cb: 0.05859286859997331
# -----------------------------------
# Updated WACC for onwind, rc 1, scenario mb: 0.05558878035725698
# Updated WACC for onwind, rc 1, scenario pc: 0.06133466955206371
# Updated WACC for onwind, rc 1, scenario pb: 0.053769731778422196
# Updated WACC for onwind, rc 1, scenario pi: 0.05589635920746961
# Updated WACC for onwind, rc 1, scenario cb: 0.05546016105051233
# -----------------------------------
# Updated WACC for onwind, rc 2, scenario mb: 0.05556855306313924
# Updated WACC for onwind, rc 2, scenario pc: 0.06130816997672734
# Updated WACC for onwind, rc 2, scenario pb: 0.05368630883953714
# Updated WACC for onwind, rc 2, scenario pi: 0.05539849962373661
# Updated WACC for onwind, rc 2, scenario cb: 0.0550436935415658
# -----------------------------------
# Updated WACC for onwind, rc 3, scenario mb: 0.055504415671445866
# Updated WACC for onwind, rc 3, scenario pc: 0.06083442922208621
# Updated WACC for onwind, rc 3, scenario pb: 0.05363510880477148
# Updated WACC for onwind, rc 3, scenario pi: 0.05505438868743112
# Updated WACC for onwind, rc 3, scenario cb: 0.05471882381746656
# -----------------------------------
# Updated WACC for onwind, rc 4, scenario mb: 0.05547704881213009
# Updated WACC for onwind, rc 4, scenario pc: 0.06006773704726025
# Updated WACC for onwind, rc 4, scenario pb: 0.05360883703738609
# Updated WACC for onwind, rc 4, scenario pi: 0.0547967520548562
# Updated WACC for onwind, rc 4, scenario cb: 0.05439301497211333
# -----------------------------------
# Updated WACC for onwind, rc 5, scenario mb: 0.055551468657190746
# Updated WACC for onwind, rc 5, scenario pc: 0.05979768413611552
# Updated WACC for onwind, rc 5, scenario pb: 0.05357834629829132
# Updated WACC for onwind, rc 5, scenario pi: 0.05466709062826679
# Updated WACC for onwind, rc 5, scenario cb: 0.054218565690727395
# -----------------------------------
# Updated WACC for onwind, rc 6, scenario mb: 0.05553248096366492
# Updated WACC for onwind, rc 6, scenario pc: 0.059838243884842546
# Updated WACC for onwind, rc 6, scenario pb: 0.053521027488481775
# Updated WACC for onwind, rc 6, scenario pi: 0.054310893180628025
# Updated WACC for onwind, rc 6, scenario cb: 0.05389924490695932
# -----------------------------------
# Updated WACC for onwind, rc 7, scenario mb: 0.05551794113634413
# Updated WACC for onwind, rc 7, scenario pc: 0.05973067810728621
# Updated WACC for onwind, rc 7, scenario pb: 0.05350877742844333
# Updated WACC for onwind, rc 7, scenario pi: 0.05412846875986114
# Updated WACC for onwind, rc 7, scenario cb: 0.05374810388810609
# -----------------------------------
# Updated WACC for onwind, rc 8, scenario mb: 0.05564117617408556
# Updated WACC for onwind, rc 8, scenario pc: 0.05967681266762427
# Updated WACC for onwind, rc 8, scenario pb: 0.053453701431544196
# Updated WACC for onwind, rc 8, scenario pi: 0.05371145966391586
# Updated WACC for onwind, rc 8, scenario cb: 0.053300533547653274
# -----------------------------------
# Updated WACC for onwind, rc 9, scenario mb: 0.05589194049093064
# Updated WACC for onwind, rc 9, scenario pc: 0.059870789990157776
# Updated WACC for onwind, rc 9, scenario pb: 0.05332510745556048
# Updated WACC for onwind, rc 9, scenario pi: 0.05350048989815262
# Updated WACC for onwind, rc 9, scenario cb: 0.05354844537301488
# -----------------------------------
# Updated WACC for solar, rc 0, scenario mb: 0.05044612867762204
# Updated WACC for solar-hsat, rc 7, scenario pi: 0.04888764034008518
# Updated WACC for solar-hsat, rc 7, scenario cb: 0.048738236947089945
# -----------------------------------
# Updated WACC for solar-hsat, rc 8, scenario mb: 0.05036511648120414
# Updated WACC for solar-hsat, rc 8, scenario pc: 0.05295829461479486
# Updated WACC for solar-hsat, rc 8, scenario pb: 0.048815690383109435
# Updated WACC for solar-hsat, rc 8, scenario pi: 0.048836021807900955
# Updated WACC for solar-hsat, rc 8, scenario cb: 0.04868701872080055
# -----------------------------------
# Updated WACC for solar-hsat, rc 9, scenario mb: 0.050435445699070755
# Updated WACC for solar-hsat, rc 9, scenario pc: 0.05322895653763159
# Updated WACC for solar-hsat, rc 9, scenario pb: 0.04880945598025915
# Updated WACC for solar-hsat, rc 9, scenario pi: 0.04892906440515315
# Updated WACC for solar-hsat, rc 9, scenario cb: 0.0487787147166012
# -----------------------------------

# %%
importlib.reload(af)

af.lifetime_revenue_mcs_dist_plot(run_name, scenario='mb', carrier='offwind-dc', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario='mb', carrier='onwind', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario='mb', carrier='solar-hsat', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario='mb', carrier='solar', N=10000)

# scenarios = ['mb', 'pc', 'pb', 'pi', 'cb']
# carrier = 'onwind'
# for scenario in scenarios:
#     af.lifetime_revenue_mcs_dist_plot(run_name, scenario=scenario, carrier=carrier, N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/norm_revenue_dist_MCS_offwind-dc_mb.png
# --- Goodness of Fit Results for Offshore Wind (DC) ---
# Log-Normal:  KS Stat = 0.0072, p-value = 8.9269e-02
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/norm_revenue_dist_MCS_onwind_mb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Log-Normal:  KS Stat = 0.0046, p-value = 3.0010e-02
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/norm_revenue_dist_MCS_solar-hsat_mb.png
# --- Goodness of Fit Results for Rotating Solar PV ---
# Log-Normal:  KS Stat = 0.0055, p-value = 5.2135e-03
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/norm_revenue_dist_MCS_solar_mb.png
# --- Goodness of Fit Results for Ground-Mounted Solar PV ---
# Log-Normal:  KS Stat = 0.0055, p-value = 4.2663e-03
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
#        0         1         2         3         4         5         6     \
# 0  0.980556  0.980043  0.974733  1.022957  0.985081  1.070542  1.041072
# 1  0.980476  0.989020  0.972847  1.022836  0.986102  1.071820  1.040512
# 2  0.980734  0.989488  0.972532  1.020431  0.986022  1.067663  1.044161
# 3  0.981837  0.994771  0.969928  1.021470  0.987737  1.067670  1.045827
# 4  0.983528  1.000361  0.966568  1.023195  0.992071  1.070214  1.048744
# 5  0.984353  0.998611  0.965445  1.023574  0.993265  1.066974  1.051197
# 6  0.989515  1.006058  0.960149  1.030621  0.994373  1.069677  1.048752
# 7  0.995933  1.017688  0.952230  1.040745  0.999480  1.075262  1.041544
# 8  0.998789  1.013377  0.946722  1.031775  1.002441  1.063989  1.048692
# 9  0.992431  1.007619  0.953102  1.035087  1.006511  1.060084  1.059576
#
#        7         8         9     ...      9990      9991      9992      9993  \
# 0  0.837240  1.027503  1.031591  ...  1.037356  0.909122  0.935763  0.982014
# 1  0.838829  1.024347  1.035165  ...  1.033935  0.907738  0.939993  0.991552
# 2  0.840500  1.020729  1.035576  ...  1.032093  0.907285  0.936369  0.989760
# 3  0.842653  1.020817  1.039511  ...  1.032294  0.908900  0.939361  0.992831
# 4  0.846862  1.025177  1.041051  ...  1.036243  0.914427  0.941587  0.996049
# 5  0.848585  1.026232  1.041662  ...  1.038671  0.917468  0.938266  0.986637
# 6  0.850879  1.030160  1.045824  ...  1.044040  0.918347  0.947831  0.988084
# 7  0.859392  1.038356  1.049627  ...  1.047171  0.921821  0.964202  0.990291
# 8  0.861403  1.034449  1.049611  ...  1.045526  0.927729  0.955504  0.981087
# 9  0.855895  1.029884  1.046436  ...  1.046029  0.932712  0.941049  0.974280
#
#        9994      9995      9996      9997      9998      9999
# 0  1.089814  1.072605  0.955909  0.960432  1.026965  1.099978
# 1  1.082256  1.072489  0.954963  0.960482  1.025859  1.093174
# 2  1.082565  1.070063  0.958131  0.958082  1.025540  1.093716
# 3  1.078081  1.071600  0.956884  0.958913  1.024796  1.091017
# 4  1.074602  1.074820  0.955646  0.958455  1.024756  1.091878
# 5  1.075681  1.076881  0.957355  0.955420  1.026589  1.096109
# 6  1.074131  1.084907  0.952591  0.960065  1.027104  1.094520
# 7  1.071432  1.093833  0.946686  0.964372  1.027737  1.088755
# 8  1.066573  1.093529  0.952920  0.952554  1.032352  1.091259
# 9  1.073484  1.093206  0.950326  0.947424  1.033975  1.097744
#
# [10 rows x 10000 columns]

# %%
importlib.reload(af)
af.plot_roi_per_rc(run_name, carrier='offwind-ac', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-dc', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-float', N=10000)
af.plot_roi_per_rc(run_name, carrier='onwind', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar-hsat', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-ac.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-dc.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-float.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_onwind.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar-hsat.png

# %%
importlib.reload(af)
af.plot_lifetime_risk_per_rc(run_name, carrier='onwind', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-ac', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-dc', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-float', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
af.plot_lifetime_risk_per_rc(run_name, carrier='solar', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
af.plot_lifetime_risk_per_rc(run_name, carrier='solar-hsat', N=10000, scenarios=['mb', 'pb', 'pi', 'cb'])
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_onwind_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_offwind-ac_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_offwind-dc_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_offwind-float_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_solar_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lifetime_risk_per_resource_class_solar-hsat_scenarios.png

# %%
importlib.reload(af)
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    af.plot_effective_wacc_per_rc(run_name, carrier)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_offwind-ac_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_offwind-dc_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_offwind-float_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_onwind_scenarios.png
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_solar_scenarios.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/effective_wacc_per_resource_class_solar-hsat_scenarios.png

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 9
t = 30
print(af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, N=10000))
print(af.annual_revenue_risk(costs, carrier, n, rc) * (t) ** (-1/2))
# Out:
# 0.0765013543433343
# 0.04652417971471111

# %%
importlib.reload(af)

#Plot debt CAGR vs. sigma
af.plot_wacc_vs_volatility()
# Out:
# Plot saved to ../results/my_plots/wacc_vs_volatility.png

# %%
importlib.reload(af)
carrier = 'solar'
rc = 9
for scenario in ['mb']:#, 'pb', 'pi', 'cb']:
    af.plot_annual_revenue_per_MW(run_name, scenario, carrier, rc, bus="DE0 0", save_to_file=True)
# scenario = 'mb'
# af.plot_annual_revenue_per_MW(run_name, scenario, 'offwind-dc', 3, bus="DE0 0", save_to_file=True)
# af.plot_annual_revenue_per_MW(run_name, scenario, 'offwind-ac', 2, bus="DE0 0", save_to_file=True)
# af.plot_annual_revenue_per_MW(run_name, scenario, 'solar-hsat', 8, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/annual_revenue_per_MW_solar_9_mb.png

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 9
cap = 100
years_capped = range(2010, 2017)
rev = [af.annual_revenue_per_MW(costs, carrier, year, n, rc) for year in years_capped]
rev_cap = [af.annual_revenue_per_MW_with_price_cap(costs, carrier, year, n, rc, cap=cap) for year in years_capped]
print(f"Annual revenues per MW for {carrier}, rc {rc} with price cap in years {years_capped}: {rev_cap}")
lost_rev = [rev[i] - rev_cap[i] for i in range(len(years_capped))]
print(f"Lost revenues due to price cap for {carrier}, rc {rc} in years {years_capped}: {lost_rev}")
lost_rev_perc = [lost_rev[i] / rev[i] * 100 for i in range(len(years_capped))]
print(f"Percentage of lost revenues due to price cap for {carrier}, rc {rc} in years {years_capped}: {lost_rev_perc}")
print('------------------------------------')
years = n.generators_t.p.index.year.unique()
rev_all = sum([af.annual_revenue_per_MW(costs, carrier, year, n, rc) for year in years])
rev_cap_all = sum([af.annual_revenue_per_MW_with_price_cap(costs, carrier, year, n, rc, cap=cap) for year in years])
lost_rev_pct = (rev_all - rev_cap_all) / rev_all * 100
print(f"Total lost revenues due to price cap for {carrier}, rc {rc} over all years: {lost_rev_pct} %")
# Out:
# Annual revenues per MW for onwind, rc 9 with price cap in years range(2010, 2017): [153585.51126429354, 124313.87765260573, 125962.79003512343, 130271.1132463714, 134621.60670584778, 122814.27203422225, 130263.66920981988]
# Lost revenues due to price cap for onwind, rc 9 in years range(2010, 2017): [75245.39235553888, 47505.37383814494, 62333.07859278079, 81718.62142925269, 52140.70703773259, 46337.98413676793, 60022.82877373799]
# Percentage of lost revenues due to price cap for onwind, rc 9 in years range(2010, 2017): [32.88253079686632, 27.648458147719396, 33.103795132095335, 38.54838610666425, 27.91821647129537, 27.394245389151926, 31.543398722343607]
# ------------------------------------
# Total lost revenues due to price cap for onwind, rc 9 over all years: 9.55612268748787 %

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'solar-hsat'
rc = 9
af.plot_lost_revenue_due_to_price_cap(run_name, carrier, n, rc)
# af.plot_effective_risk_premium_due_to_price_cap(run_name, carrier, n, rc)
# Out:
# Plot saved to ../results/1_Iteration_One_v2/my_plots/lost_revenue_due_to_price_cap_solar-hsat_9_80_200.png

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='mb')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/revenue_violin_plot_onwind_rc8.png

# %%
importlib.reload(af)
scenarios = ['mb', 'pc', 'pb', 'pi', 'cb']
for scenario in scenarios:
    af.calculate_annual_state_cfd_payments(run_name, n, scenario=scenario)
    avg = af.average_state_cfd_payments(run_name, n, scenario=scenario)
    print(f"Average state CfD payments for scenario {scenario}: {avg} €")
    std = af.std_dev_state_cfd_payments(run_name, n, scenario=scenario)
    print(f"Standard deviation of state CfD payments for scenario {scenario}: {std} €/year")
    print('-----------------------------------')
# Out:
# Average state CfD payments for scenario mb: 0.0 €
# Standard deviation of state CfD payments for scenario mb: 0.0 €/year
# -----------------------------------
# Average state CfD payments for scenario pc: -770738928.3747858 €
# Standard deviation of state CfD payments for scenario pc: 1696238658.5519636 €/year
# -----------------------------------
# Average state CfD payments for scenario pb: 1.0899135044642857e-07 €
# Standard deviation of state CfD payments for scenario pb: 5854325502.018628 €/year
# -----------------------------------
# Average state CfD payments for scenario pi: -3.1607491629464288e-06 €
# Standard deviation of state CfD payments for scenario pi: 5855072317.434799 €/year
# -----------------------------------
# Average state CfD payments for scenario cb: -2.3433140345982144e-06 €
# Standard deviation of state CfD payments for scenario cb: 5672383639.746483 €/year
# -----------------------------------

# %%
importlib.reload(af)
for scenario in ['pb', 'pi', 'cb']:
    af.plot_annual_state_CfD_payments(run_name, scenario=scenario, cap=130, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/annual_state_CfD_payments_pb.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/annual_state_CfD_payments_pi.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/annual_state_CfD_payments_cb.png

# %%
importlib.reload(af)
for scenario in ['pb', 'pi', 'cb']:
    af.plot_wind_vs_solar_cfd_payments(run_name, scenario=scenario, bus="DE0 0", save_to_file=True)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/wind_vs_solar_cfd_payments_pb.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_v2/my_plots/wind_vs_solar_cfd_payments_pi.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/wind_vs_solar_cfd_payments_cb.png

# %%
importlib.reload(af)
run_names = ['1_Iteration_One_v2', '2_Iteration_Two_PC', '2_Iteration_Two_PB', '2_Iteration_Two_PI', '2_Iteration_Two_CB']
af.plot_compare_annualized_system_costs(run_names)
af.plot_compare_avg_prices(run_names)
af.plot_compare_CO2_emissions(run_names)
af.plot_compare_capacities(run_names)

run_names_short = ['2_Iteration_Two_PB', '2_Iteration_Two_PI', '2_Iteration_Two_CB']
# af.plot_compare_avg_state_cfd_payments(run_names_short) # Plot kinda unnecessary with given strike prices
af.plot_compare_std_dev_state_cfd_payments(run_names_short)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/my_plots/compare_system_costs.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/my_plots/compare_avg_prices.png
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/my_plots/compare_CO2_emissions.png
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/my_plots/compare_capacities.png
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/my_plots/compare_std_dev_state_cfd_payments.png

# %%
importlib.reload(af)
for scenario in ['pb', 'pi', 'cb']:
    pfe_abs = af.portfolio_effect_abs(run_name, n, scenario=scenario)
    print(f"Absolute portfolio effect for scenario {scenario}: {pfe_abs} €")
    pfe_rel = af.portfolio_effect_pct(run_name, n, scenario=scenario)
    print(f"Relative portfolio effect for scenario {scenario}: {pfe_rel:.2f} %")
    print('-----------------------------------')
# Out:
# Absolute portfolio effect for scenario pb: -168399998.52854538 €
# Relative portfolio effect for scenario pb: -2.96 %
# -----------------------------------
# Absolute portfolio effect for scenario pi: -169146813.94471645 €
# Relative portfolio effect for scenario pi: -2.97 %
# -----------------------------------
# Absolute portfolio effect for scenario cb: 13541863.743599892 €
# Relative portfolio effect for scenario cb: 0.24 %
# -----------------------------------

# %%
importlib.reload(af)
for scenario in ['mb', 'pb', 'pi', 'cb']:
    std_dev = af.aggregated_revenue_std_dev(run_name, n, scenario=scenario, bus="DE0 0")
    print(f"Aggregated revenue standard deviation across all VRE carriers for scenario {scenario}: {std_dev} €/MW/year")
    state_std_dev = af.std_dev_state_cfd_payments(run_name, n, scenario=scenario)
    print(f"Standard deviation of state CfD payments for scenario {scenario}: {state_std_dev} €/year")
    print('-----------------------------------')
# Out:
# Aggregated revenue standard deviation across all VRE carriers for scenario mb: 5685925503.490083 €/MW/year
# Standard deviation of state CfD payments for scenario mb: 0.0 €/year
# -----------------------------------
# Aggregated revenue standard deviation across all VRE carriers for scenario pb: 1026234368.5989892 €/MW/year
# Standard deviation of state CfD payments for scenario pb: 5854325502.018628 €/year
# -----------------------------------
# Aggregated revenue standard deviation across all VRE carriers for scenario pi: 1171410430.6832485 €/MW/year
# Standard deviation of state CfD payments for scenario pi: 5855072317.434799 €/year
# -----------------------------------
# Aggregated revenue standard deviation across all VRE carriers for scenario cb: 533089569.03923297 €/MW/year
# Standard deviation of state CfD payments for scenario cb: 5672383639.746483 €/year
# -----------------------------------

# %%
importlib.reload(af)
af.plot_avg_price_with_levy(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_v2/my_plots/avg_price_with_levy.png
