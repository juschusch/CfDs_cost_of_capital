# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "2_Iteration_Two_PC" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.9999949295297 €/MWh
# Price statistics: {'mean': 62.59765634806913, 'median': 64.29310821983181, 'std_dev': 155.8049142330467, 'min': 0.019052918771659343, 'max': 3999.9999949295297}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PB/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 2740.709350727125 MW
# Total installed offshore DC capacity: 40122.96211139125 MW
# Total installed offshore floating capacity: 0.4960897561773365 MW
# Total installed onshore wind capacity: 46148.17543040156 MW
# Total installed solar capacity: 148.6186989189568 MW
# Total installed solar HSAT capacity: 162363.53577254523 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 23107.297529404044 MW
# Total installed OCGT capacity: 53128.85370115721 MW
# Total installed battery capacity: 17389.56346538968 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 31509.58823078644 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 402041812.81159025 MWh
# Total offshore DC generation: 6384924810.40913 MWh
# Total offshore floating generation: 44877.34845859454 MWh
# Total onshore wind generation: 4028233791.1475034 MWh
# Total solar generation: 4896695.594416903 MWh
# Total solar HSAT generation: 7170890069.109884 MWh
# Total CCGT generation: 2564195698.7110734 MWh
# Total OCGT generation: 1210440418.8732672 MWh
# Total battery discharge: -41012901.027468905 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1799652.3660501633 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.312569e+06
# DE0 0 1 onwind    3.293012e+06
# DE0 0 2 onwind    3.292218e+06
# DE0 0 3 onwind    3.278027e+06
# DE0 0 4 onwind    3.255123e+06
# DE0 0 5 onwind    3.247073e+06
# DE0 0 6 onwind    3.248282e+06
# DE0 0 7 onwind    3.245078e+06
# DE0 0 8 onwind    3.243474e+06
# DE0 0 9 onwind    3.249252e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.920710e+06
# DE0 0 1 offwind-ac    6.978753e+06
# DE0 0 2 offwind-ac    7.248914e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.788405e+06
# DE0 0 2 offwind-dc    7.737508e+06
# DE0 0 3 offwind-dc    8.438675e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    1.027469e+07
# DE0 0 1 offwind-float    1.033121e+07
# DE0 0 2 offwind-float    1.073151e+07
# DE0 0 3 offwind-float    1.163621e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.147861e+06
# DE0 0 1 solar    1.146628e+06
# DE0 0 2 solar    1.146259e+06
# DE0 0 3 solar    1.145835e+06
# DE0 0 4 solar    1.144896e+06
# DE0 0 5 solar    1.145269e+06
# DE0 0 6 solar    1.146152e+06
# DE0 0 7 solar    1.145445e+06
# DE0 0 8 solar    1.144967e+06
# DE0 0 9 solar    1.147446e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.332959e+06
# DE0 0 1 solar-hsat    1.331156e+06
# DE0 0 2 solar-hsat    1.330875e+06
# DE0 0 3 solar-hsat    1.330489e+06
# DE0 0 4 solar-hsat    1.329498e+06
# DE0 0 5 solar-hsat    1.329795e+06
# DE0 0 6 solar-hsat    1.330870e+06
# DE0 0 7 solar-hsat    1.329309e+06
# DE0 0 8 solar-hsat    1.328847e+06
# DE0 0 9 solar-hsat    1.332338e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        1.069025
# DE0 0 1 onwind        0.538724
# DE0 0 2 onwind        0.928079
# DE0 0 3 onwind        1.406815
# DE0 0 4 onwind        2.063303
# DE0 0 5 onwind        2.336124
# DE0 0 6 onwind        7.957911
# DE0 0 7 onwind     8037.194846
# DE0 0 8 onwind    21592.125596
# DE0 0 9 onwind    16502.555007
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.693665
# DE0 0 1 offwind-ac      30.328099
# DE0 0 2 offwind-ac    2709.687587
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.798085
# DE0 0 2 offwind-dc    13833.535766
# DE0 0 3 offwind-dc    26285.628260
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.100094
# DE0 0 1 offwind-float    0.111268
# DE0 0 2 offwind-float    0.156153
# DE0 0 3 offwind-float    0.128575
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar     9.434162
# DE0 0 1 solar    11.987420
# DE0 0 2 solar    12.996067
# DE0 0 3 solar    14.189653
# DE0 0 4 solar    13.376529
# DE0 0 5 solar    13.370570
# DE0 0 6 solar    14.908933
# DE0 0 7 solar    20.692055
# DE0 0 8 solar    26.203182
# DE0 0 9 solar    11.460129
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       55.959669
# DE0 0 1 solar-hsat       64.618964
# DE0 0 2 solar-hsat      326.126842
# DE0 0 3 solar-hsat     4900.627750
# DE0 0 4 solar-hsat      129.539213
# DE0 0 5 solar-hsat       55.873223
# DE0 0 6 solar-hsat    27274.973517
# DE0 0 7 solar-hsat    41485.727079
# DE0 0 8 solar-hsat    43244.336025
# DE0 0 9 solar-hsat    44825.753490
# Name: p_nom_opt, dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17389.563465
# DE0 0 H2             0.213392
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 939206918.7140948 MWh
# Total PHS output: 424933178.22026956 MWh
# Total H2 output: 3507.5606844747945 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    # af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['pc'])

# %%
importlib.reload(af)
scenario = 'pc'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pc: 4427676.5835059
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pc: 5674464.077427203
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pc: 6643535.387712098
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pc: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pc: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pc: 6600424.55056436
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pc: 6695828.415772899
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pc: 6966359.708448687
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pc: 1470569.2521359085
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pc: 2285376.9092415567
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pc: 3154497.5633050255
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pc: 3485330.118829363
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario pc: 1036596.5759004967
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario pc: 1789271.413315879
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario pc: 1986613.6327850078
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario pc: 2148709.469238987
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario pc: 2251332.9910844993
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario pc: 2285803.633894578
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario pc: 2461613.725468375
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario pc: 2583624.4310516445
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 8, scenario pc: 2845803.9906322984
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 9, scenario pc: 3827212.113901248
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 0, scenario pc: 1191480.1014900713
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 1, scenario pc: 1203159.5879349767
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 2, scenario pc: 1206686.6979741238
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 3, scenario pc: 1210332.6091999905
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 4, scenario pc: 1207766.6579919863
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 5, scenario pc: 1208409.9079747822
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 6, scenario pc: 1213491.112154651
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 7, scenario pc: 1227213.5261533647
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 8, scenario pc: 1271021.9811068294
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 9, scenario pc: 1360310.8677326564
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario pc: 1454324.980355306
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario pc: 1456024.2979336316
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario pc: 1469992.3268142047
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario pc: 1474022.6601518681
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario pc: 1463741.416191435
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario pc: 1453652.4387039396
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario pc: 1474412.784442281
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario pc: 1476013.3577841069
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario pc: 1510988.3095517058
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario pc: 1621933.387959504
# -----------------------------------

# %%
importlib.reload(af)
scenario = 'pc'
for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):  
        risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
        print(f"Relative revenue risk per MW of {carrier}, rc {rc}, scenario {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pc: 0.06388730787555325
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pc: 0.060902655358759626
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pc: 0.0605948194856623
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pc: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pc: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pc: 0.05746892763186368
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pc: 0.06171104516840816
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pc: 0.06258271960000494
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario pc: 0.08761174376403859
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario pc: 0.08368098387886566
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario pc: 0.08124058581893273
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario pc: 0.08408292587882822
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario pc: 0.05804557464687717
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario pc: 0.05068235443364421
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario pc: 0.05043121155580156
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario pc: 0.04979459385571286
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario pc: 0.050151356696633925
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario pc: 0.05326179397265177
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario pc: 0.053151047005121535
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario pc: 0.053701371609828435
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario pc: 0.05759852738474924
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario pc: 0.06517777862236616
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario pc: 0.04975191374616228
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario pc: 0.04830771616245872
# -----------------------------------
# Relative revenue risk per MW of solar, rc 2, scenario pc: 0.047635037725387394
# -----------------------------------
# Relative revenue risk per MW of solar, rc 3, scenario pc: 0.047063704798405485
# -----------------------------------
# Relative revenue risk per MW of solar, rc 4, scenario pc: 0.04701926534837244
# -----------------------------------
# Relative revenue risk per MW of solar, rc 5, scenario pc: 0.04746326578539197
# -----------------------------------
# Relative revenue risk per MW of solar, rc 6, scenario pc: 0.048291655927103515
# -----------------------------------
# Relative revenue risk per MW of solar, rc 7, scenario pc: 0.04911616534900766
# -----------------------------------
# Relative revenue risk per MW of solar, rc 8, scenario pc: 0.0474941341134528
# -----------------------------------
# Relative revenue risk per MW of solar, rc 9, scenario pc: 0.04915630791712178
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 0, scenario pc: 0.0525373411434532
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 1, scenario pc: 0.051061103283332666
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 2, scenario pc: 0.05063476244826137
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 3, scenario pc: 0.05014840017960543
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 4, scenario pc: 0.04970513605030257
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 5, scenario pc: 0.050154196024378796
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 6, scenario pc: 0.05027212572431293
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 7, scenario pc: 0.05040513995242136
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 8, scenario pc: 0.04899441188369507
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 9, scenario pc: 0.050078019911983414
# -----------------------------------

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='mb')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PC/my_plots/revenue_violin_plot_onwind_rc8.png
