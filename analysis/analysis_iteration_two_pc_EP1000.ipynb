# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "2_Iteration_Two_PC_EP1000" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PC_EP1000/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.9983836354836 €/MWh
# Price statistics: {'mean': 97.50862881003118, 'median': 0.02994077580422101, 'std_dev': 234.0737298978723, 'min': 0.01844936122720168, 'max': 3999.9983836354836}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/2_Iteration_Two_PC_EP1000/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/2_Iteration_Two_PC_EP1000/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 7772.826843482795 MW
# Total installed offshore DC capacity: 63588.7336293525 MW
# Total installed offshore floating capacity: 0.6827960785969154 MW
# Total installed onshore wind capacity: 38223.159491364946 MW
# Total installed solar capacity: 260387.58575375812 MW
# Total installed solar HSAT capacity: 46684.38443357132 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 30705.81601959393 MW
# Total installed OCGT capacity: 24949.9758064117 MW
# Total installed battery capacity: 68408.33008198321 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 15295.363224648821 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 972803295.9360921 MWh
# Total offshore DC generation: 8597579266.04545 MWh
# Total offshore floating generation: 51694.6129578909 MWh
# Total onshore wind generation: 2818810744.048918 MWh
# Total solar generation: 7927948932.648467 MWh
# Total solar HSAT generation: 1661250224.5621142 MWh
# Total CCGT generation: 974909761.6056398 MWh
# Total OCGT generation: 143656164.4364934 MWh
# Total battery discharge: -103993007.57586151 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1422122.8847564007 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.835733e+06
# DE0 0 1 onwind    3.822972e+06
# DE0 0 2 onwind    3.826032e+06
# DE0 0 3 onwind    3.826684e+06
# DE0 0 4 onwind    3.816553e+06
# DE0 0 5 onwind    3.816021e+06
# DE0 0 6 onwind    3.825358e+06
# DE0 0 7 onwind    3.826074e+06
# DE0 0 8 onwind    3.822076e+06
# DE0 0 9 onwind    3.846622e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    8.044774e+06
# DE0 0 1 offwind-ac    8.090654e+06
# DE0 0 2 offwind-ac    8.408719e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    8.906788e+06
# DE0 0 2 offwind-dc    9.010634e+06
# DE0 0 3 offwind-dc    9.818313e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    1.258222e+07
# DE0 0 1 offwind-float    1.259916e+07
# DE0 0 2 offwind-float    1.302480e+07
# DE0 0 3 offwind-float    1.429241e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.295622e+06
# DE0 0 1 solar    1.294572e+06
# DE0 0 2 solar    1.293431e+06
# DE0 0 3 solar    1.292438e+06
# DE0 0 4 solar    1.291027e+06
# DE0 0 5 solar    1.291549e+06
# DE0 0 6 solar    1.291717e+06
# DE0 0 7 solar    1.288507e+06
# DE0 0 8 solar    1.285541e+06
# DE0 0 9 solar    1.289316e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.534603e+06
# DE0 0 1 solar-hsat    1.531976e+06
# DE0 0 2 solar-hsat    1.530152e+06
# DE0 0 3 solar-hsat    1.529408e+06
# DE0 0 4 solar-hsat    1.526886e+06
# DE0 0 5 solar-hsat    1.528416e+06
# DE0 0 6 solar-hsat    1.528623e+06
# DE0 0 7 solar-hsat    1.523488e+06
# DE0 0 8 solar-hsat    1.520453e+06
# DE0 0 9 solar-hsat    1.525417e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        4.112483
# DE0 0 1 onwind        8.590802
# DE0 0 2 onwind       19.759330
# DE0 0 3 onwind       29.993638
# DE0 0 4 onwind       18.222568
# DE0 0 5 onwind       10.638493
# DE0 0 6 onwind       15.947222
# DE0 0 7 onwind       21.775946
# DE0 0 8 onwind    21591.577864
# DE0 0 9 onwind    16502.541145
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       1.480018
# DE0 0 1 offwind-ac    5061.699618
# DE0 0 2 offwind-ac    2709.647207
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.800039
# DE0 0 2 offwind-dc    13833.435251
# DE0 0 3 offwind-dc    49751.498339
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.135005
# DE0 0 1 offwind-float    0.185205
# DE0 0 2 offwind-float    0.208049
# DE0 0 3 offwind-float    0.154537
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar       86.917944
# DE0 0 1 solar     1116.511737
# DE0 0 2 solar    18631.286186
# DE0 0 3 solar    38448.128011
# DE0 0 4 solar    39012.005332
# DE0 0 5 solar    39526.302762
# DE0 0 6 solar    40078.357360
# DE0 0 7 solar    41089.457421
# DE0 0 8 solar    42345.925250
# DE0 0 9 solar       52.693752
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       34.665163
# DE0 0 1 solar-hsat       42.955159
# DE0 0 2 solar-hsat       58.568210
# DE0 0 3 solar-hsat       55.461454
# DE0 0 4 solar-hsat       62.670031
# DE0 0 5 solar-hsat       55.308499
# DE0 0 6 solar-hsat      172.399396
# DE0 0 7 solar-hsat      493.365769
# DE0 0 8 solar-hsat      924.525088
# DE0 0 9 solar-hsat    44784.465665
# Name: p_nom_opt, dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    68408.330082
# DE0 0 H2          3533.010678
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 2385042858.667835 MWh
# Total PHS output: 289569733.44591564 MWh
# Total H2 output: 156906422.79788658 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000, scenarios=['mb'])

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb']#, 'pc', 'pb', 'pi', 'cb']:    
            avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
#   Cell In[13], line 5
#     for scenario in ['mb']#, 'pc', 'pb', 'pi', 'cb']:
#                           ^
# SyntaxError: expected ':'

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb']#, 'pc', 'pb', 'pi', 'cb']:    
            risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Relative revenue risk per MW of {carrier}, rc {rc}, scenario {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Relative revenue risk per MW of offwind-ac, rc 0, scenario mb: 0.06304902270431789
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pc: 0.10199591212763653
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pb: 0.009150373080592012
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pi: 0.028047685887175506
# Relative revenue risk per MW of offwind-ac, rc 0, scenario cb: 0.023362102113405968
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 1, scenario mb: 0.06021159322617082
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pc: 0.10070502788521538
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pb: 0.006623915780821454
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pi: 0.008116548932477015
# Relative revenue risk per MW of offwind-ac, rc 1, scenario cb: 0.0030142933726817027
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario mb: 0.058374329062277394
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pc: 0.09862242404724131
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pb: 0.005290588154713631
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pi: 0.008204486364575431
# Relative revenue risk per MW of offwind-ac, rc 2, scenario cb: 0.008519403089456352
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario mb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pc: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pi: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario mb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pc: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pi: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario mb: 0.05436928828842182
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pc: 0.10097395215742722
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pb: 0.006314213736043057
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pi: 0.023928299537800245
# Relative revenue risk per MW of offwind-dc, rc 1, scenario cb: 0.024436908225773834
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario mb: 0.060090968032484336
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pc: 0.09862967939237209
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pb: 0.006282190754942901
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pi: 0.008728838594345253
# Relative revenue risk per MW of offwind-dc, rc 2, scenario cb: 0.006839081447693547
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario mb: 0.058597730654005586
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pc: 0.0965361566547833
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pb: 0.005926533101126208
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pi: 0.006250292191407885
# Relative revenue risk per MW of offwind-dc, rc 3, scenario cb: 0.0017917419742704169
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario mb: 0.08458802176697308
# Relative revenue risk per MW of offwind-float, rc 0, scenario pc: 0.12715619040183349
# Relative revenue risk per MW of offwind-float, rc 0, scenario pb: 0.01407286807652373
# Relative revenue risk per MW of offwind-float, rc 0, scenario pi: 0.08165009800274617
# Relative revenue risk per MW of offwind-float, rc 0, scenario cb: 0.074030957576165
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario mb: 0.0803133774107355
# Relative revenue risk per MW of offwind-float, rc 1, scenario pc: 0.12519828131036254
# Relative revenue risk per MW of offwind-float, rc 1, scenario pb: 0.011773125059650459
# Relative revenue risk per MW of offwind-float, rc 1, scenario pi: 0.02153803762163714
# Relative revenue risk per MW of offwind-float, rc 1, scenario cb: 0.015730686826153667
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario mb: 0.07519617549041194
# Relative revenue risk per MW of offwind-float, rc 2, scenario pc: 0.12221851489132263
# Relative revenue risk per MW of offwind-float, rc 2, scenario pb: 0.008843239882232696
# Relative revenue risk per MW of offwind-float, rc 2, scenario pi: 0.014610222493148278
# Relative revenue risk per MW of offwind-float, rc 2, scenario cb: 0.015189124615340652
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario mb: 0.07612833113251018
# Relative revenue risk per MW of offwind-float, rc 3, scenario pc: 0.11859667344079318
# Relative revenue risk per MW of offwind-float, rc 3, scenario pb: 0.007453249529943329
# Relative revenue risk per MW of offwind-float, rc 3, scenario pi: 0.021007078441204773
# Relative revenue risk per MW of offwind-float, rc 3, scenario cb: 0.020981460809227883
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario mb: 0.0604114728629585
# Relative revenue risk per MW of onwind, rc 0, scenario pc: 0.10056236966207051
# Relative revenue risk per MW of onwind, rc 0, scenario pb: 0.020447192828545954
# Relative revenue risk per MW of onwind, rc 0, scenario pi: 0.09095980408595988
# Relative revenue risk per MW of onwind, rc 0, scenario cb: 0.08109606529767847
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario mb: 0.0584697738705516
# Relative revenue risk per MW of onwind, rc 1, scenario pc: 0.10215442348279734
# Relative revenue risk per MW of onwind, rc 1, scenario pb: 0.024771895351801163
# Relative revenue risk per MW of onwind, rc 1, scenario pi: 0.04703481734259556
# Relative revenue risk per MW of onwind, rc 1, scenario cb: 0.042551208927688974
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario mb: 0.05966342018102541
# Relative revenue risk per MW of onwind, rc 2, scenario pc: 0.10452134042461952
# Relative revenue risk per MW of onwind, rc 2, scenario pb: 0.02239530383526999
# Relative revenue risk per MW of onwind, rc 2, scenario pi: 0.03790961471114818
# Relative revenue risk per MW of onwind, rc 2, scenario cb: 0.033831853286146275
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario mb: 0.0604384554915558
# Relative revenue risk per MW of onwind, rc 3, scenario pc: 0.10512538689277359
# Relative revenue risk per MW of onwind, rc 3, scenario pb: 0.02045997285586427
# Relative revenue risk per MW of onwind, rc 3, scenario pi: 0.035502665810655164
# Relative revenue risk per MW of onwind, rc 3, scenario cb: 0.030934650286145938
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario mb: 0.056202645160614934
# Relative revenue risk per MW of onwind, rc 4, scenario pc: 0.1023678981158575
# Relative revenue risk per MW of onwind, rc 4, scenario pb: 0.02034641669556594
# Relative revenue risk per MW of onwind, rc 4, scenario pi: 0.034771127058832424
# Relative revenue risk per MW of onwind, rc 4, scenario cb: 0.027602494542680128
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario mb: 0.05530503747499634
# Relative revenue risk per MW of onwind, rc 5, scenario pc: 0.10203160189936254
# Relative revenue risk per MW of onwind, rc 5, scenario pb: 0.01984163567257589
# Relative revenue risk per MW of onwind, rc 5, scenario pi: 0.036550882748295994
# Relative revenue risk per MW of onwind, rc 5, scenario cb: 0.02798491543708618
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario mb: 0.05795952654591604
# Relative revenue risk per MW of onwind, rc 6, scenario pc: 0.10530022640564553
# Relative revenue risk per MW of onwind, rc 6, scenario pb: 0.017897423922068296
# Relative revenue risk per MW of onwind, rc 6, scenario pi: 0.02886473054241632
# Relative revenue risk per MW of onwind, rc 6, scenario cb: 0.020409522588190555
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario mb: 0.060918830132295015
# Relative revenue risk per MW of onwind, rc 7, scenario pc: 0.10830179484983878
# Relative revenue risk per MW of onwind, rc 7, scenario pb: 0.01655721170220911
# Relative revenue risk per MW of onwind, rc 7, scenario pi: 0.026712149859916236
# Relative revenue risk per MW of onwind, rc 7, scenario cb: 0.019415838884067067
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario mb: 0.06067636451237201
# Relative revenue risk per MW of onwind, rc 8, scenario pc: 0.10548353935129003
# Relative revenue risk per MW of onwind, rc 8, scenario pb: 0.00922988094753922
# Relative revenue risk per MW of onwind, rc 8, scenario pi: 0.017880855188920044
# Relative revenue risk per MW of onwind, rc 8, scenario cb: 0.009373079529034005
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario mb: 0.06675042059419703
# Relative revenue risk per MW of onwind, rc 9, scenario pc: 0.1053813962841772
# Relative revenue risk per MW of onwind, rc 9, scenario pb: 0.009358746412938101
# Relative revenue risk per MW of onwind, rc 9, scenario pi: 0.011831442449885307
# Relative revenue risk per MW of onwind, rc 9, scenario cb: 0.014432501847275556
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario mb: 0.04269178744935388
# Relative revenue risk per MW of solar, rc 0, scenario pc: 0.08378818432690924
# Relative revenue risk per MW of solar, rc 0, scenario pb: 0.008850903224210126
# Relative revenue risk per MW of solar, rc 0, scenario pi: 0.014893250178313656
# Relative revenue risk per MW of solar, rc 0, scenario cb: 0.014999466209328688
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario mb: 0.0418861245631064
# Updated WACC for offwind-ac, rc 0, scenario pb: 0.05783677689445973
# Updated WACC for offwind-ac, rc 0, scenario pi: 0.05853848091620251
# Updated WACC for offwind-ac, rc 0, scenario cb: 0.05836371104701595
# -----------------------------------
# Updated WACC for offwind-ac, rc 1, scenario mb: 0.05975227954380711
# Updated WACC for offwind-ac, rc 1, scenario pc: 0.08918982466927336
# Updated WACC for offwind-ac, rc 1, scenario pb: 0.057743596791085254
# Updated WACC for offwind-ac, rc 1, scenario pi: 0.05779862970172141
# Updated WACC for offwind-ac, rc 1, scenario cb: 0.05761072537301321
# -----------------------------------
# Updated WACC for offwind-ac, rc 2, scenario mb: 0.05968227646586822
# Updated WACC for offwind-ac, rc 2, scenario pc: 0.09024209238792716
# Updated WACC for offwind-ac, rc 2, scenario pb: 0.0576944812741764
# Updated WACC for offwind-ac, rc 2, scenario pi: 0.05780187354558893
# Updated WACC for offwind-ac, rc 2, scenario cb: 0.05781349170003836
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1260: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pc: 0.029209199130192015
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario cb: 0.07
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1260: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pc: 0.01859681309784364
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1288: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario cb: 0.07
# -----------------------------------
# Updated WACC for offwind-dc, rc 1, scenario mb: 0.059529959753447416
# Updated WACC for offwind-dc, rc 1, scenario pc: 0.09073086377838271
# Updated WACC for offwind-dc, rc 1, scenario pb: 0.05773218467250571
# Updated WACC for offwind-dc, rc 1, scenario pi: 0.05838480241337123
# Updated WACC for offwind-dc, rc 1, scenario cb: 0.05840375498853233
# -----------------------------------
# Updated WACC for offwind-dc, rc 2, scenario mb: 0.059747681002314444
# Updated WACC for offwind-dc, rc 2, scenario pc: 0.09201168340159105
# Updated WACC for offwind-dc, rc 2, scenario pb: 0.05773100479452058
# Updated WACC for offwind-dc, rc 2, scenario pi: 0.057821219638387066
# Updated WACC for offwind-dc, rc 2, scenario cb: 0.05775152668097031
# -----------------------------------
# Updated WACC for offwind-dc, rc 3, scenario mb: 0.05969078411100582
# Updated WACC for offwind-dc, rc 3, scenario pc: 0.09446098044441253
# Updated WACC for offwind-dc, rc 3, scenario pb: 0.0577179022895119
# Updated WACC for offwind-dc, rc 3, scenario pi: 0.05772982952438918
# Updated WACC for offwind-dc, rc 3, scenario cb: 0.05756579145202297
# -----------------------------------
# Updated WACC for offwind-float, rc 0, scenario mb: 0.061720117225715916
# Updated WACC for offwind-float, rc 0, scenario pc: 0.10722845577202522
# Updated WACC for offwind-float, rc 0, scenario pb: 0.05818703961279519
# Updated WACC for offwind-float, rc 0, scenario pi: 0.06156984656855828
# Updated WACC for offwind-float, rc 0, scenario cb: 0.06118139902788889
# -----------------------------------
# Updated WACC for offwind-float, rc 1, scenario mb: 0.06150156488644615
# Updated WACC for offwind-float, rc 1, scenario pc: 0.10700221832266842
# Updated WACC for offwind-float, rc 1, scenario pb: 0.0580743616943501
# Updated WACC for offwind-float, rc 1, scenario pi: 0.05855389543134685
# Updated WACC for offwind-float, rc 1, scenario cb: 0.05826836416313791
# -----------------------------------
# Updated WACC for offwind-float, rc 2, scenario mb: 0.06124068785461398
# Updated WACC for offwind-float, rc 2, scenario pc: 0.10831387003127131
# Updated WACC for offwind-float, rc 2, scenario pb: 0.05793103855581593
# Updated WACC for offwind-float, rc 2, scenario pi: 0.058213390591157516
# Updated WACC for offwind-float, rc 2, scenario cb: 0.058241788684916355
# -----------------------------------
# Updated WACC for offwind-float, rc 3, scenario mb: 0.06128814850358386
# Updated WACC for offwind-float, rc 3, scenario pc: 0.11253684012337736
# Updated WACC for offwind-float, rc 3, scenario pb: 0.057863133140060745
# Updated WACC for offwind-float, rc 3, scenario pi: 0.058527747525238524
# Updated WACC for offwind-float, rc 3, scenario cb: 0.058526486159956
# -----------------------------------
# Updated WACC for onwind, rc 0, scenario mb: 0.055094605611607575
# Updated WACC for onwind, rc 0, scenario pc: 0.07881885093817206
# Updated WACC for onwind, rc 0, scenario pb: 0.053633526490537785
# Updated WACC for onwind, rc 0, scenario pi: 0.05623641796390535
# Updated WACC for onwind, rc 0, scenario cb: 0.05586533823129686
# -----------------------------------
# Updated WACC for onwind, rc 1, scenario mb: 0.05502276843191471
# Updated WACC for onwind, rc 1, scenario pc: 0.07842010989624174
# Updated WACC for onwind, rc 1, scenario pb: 0.05378987693280994
# Updated WACC for onwind, rc 1, scenario pi: 0.05460147950355484
# Updated WACC for onwind, rc 1, scenario cb: 0.05443711634625749
# -----------------------------------
# Updated WACC for onwind, rc 2, scenario mb: 0.05506691948231894
# Updated WACC for onwind, rc 2, scenario pc: 0.07851576510115
# Updated WACC for onwind, rc 2, scenario pb: 0.05370390394680799
# Updated WACC for onwind, rc 2, scenario pi: 0.05426744754579893
# Updated WACC for onwind, rc 2, scenario cb: 0.05411879569923747
# -----------------------------------
# Updated WACC for onwind, rc 3, scenario mb: 0.055095604506898536
# Updated WACC for onwind, rc 3, scenario pc: 0.0785361394996792
# Updated WACC for onwind, rc 3, scenario pb: 0.05363398790234449
# Updated WACC for onwind, rc 3, scenario pi: 0.054179658049057236
# Updated WACC for onwind, rc 3, scenario cb: 0.05401341071710754
# -----------------------------------
# Updated WACC for onwind, rc 4, scenario mb: 0.05493900202512554
# Updated WACC for onwind, rc 4, scenario pc: 0.07821932833606107
# Updated WACC for onwind, rc 4, scenario pb: 0.05362988818485659
# Updated WACC for onwind, rc 4, scenario pi: 0.05415300259609994
# Updated WACC for onwind, rc 4, scenario cb: 0.05389244059037147
# -----------------------------------
# Updated WACC for onwind, rc 5, scenario mb: 0.054905869926046444
# Updated WACC for onwind, rc 5, scenario pc: 0.07820265928926405
# Updated WACC for onwind, rc 5, scenario pb: 0.053611667602367435
# Updated WACC for onwind, rc 5, scenario pi: 0.05421787376442685
# Updated WACC for onwind, rc 5, scenario cb: 0.053906311130905535
# -----------------------------------
# Updated WACC for onwind, rc 6, scenario mb: 0.05500390529754499
# Updated WACC for onwind, rc 6, scenario pc: 0.07849470257790073
# Updated WACC for onwind, rc 6, scenario pb: 0.05354154303809313
# Updated WACC for onwind, rc 6, scenario pi: 0.053938234944928345
# Updated WACC for onwind, rc 6, scenario cb: 0.05363216646063002
# -----------------------------------
# Updated WACC for onwind, rc 7, scenario mb: 0.05511339077982344
# Updated WACC for onwind, rc 7, scenario pc: 0.07851708212134247
# Updated WACC for onwind, rc 7, scenario pb: 0.05349325338432786
# Updated WACC for onwind, rc 7, scenario pi: 0.053860160336200925
# Updated WACC for onwind, rc 7, scenario cb: 0.05359630250873381
# -----------------------------------
# Updated WACC for onwind, rc 8, scenario mb: 0.0551044126169525
# Updated WACC for onwind, rc 8, scenario pc: 0.07839207748850946
# Updated WACC for onwind, rc 8, scenario pb: 0.05322995400540735
# Updated WACC for onwind, rc 8, scenario pi: 0.05354094579715111
# Updated WACC for onwind, rc 8, scenario cb: 0.05323508813909876
# -----------------------------------
# Updated WACC for onwind, rc 9, scenario mb: 0.05532973874324136
# Updated WACC for onwind, rc 9, scenario pc: 0.07915870935511277
# Updated WACC for onwind, rc 9, scenario pb: 0.053234574229694555
# Updated WACC for onwind, rc 9, scenario pi: 0.05332330012437222
# Updated WACC for onwind, rc 9, scenario cb: 0.05341678011683997
# -----------------------------------
# Updated WACC for solar, rc 0, scenario mb: 0.04984635903093726
# Updated WACC for solar, rc 0, scenario pc: 0.06618699891744768
# Updated WACC for solar, rc 0, scenario pb: 0.04885560683003895
# Updated WACC for solar, rc 0, scenario pi: 0.049030937236984914
# Updated WACC for solar, rc 0, scenario cb: 0.04903402536397173
# -----------------------------------
# Updated WACC for solar, rc 1, scenario mb: 0.04982252136716143
# Updated WACC for solar, rc 1, scenario pc: 0.06609600591690884
# Updated WACC for solar, rc 1, scenario pb: 0.04884469451177347
# Updated WACC for solar, rc 1, scenario pi: 0.048910040250997745
# Updated WACC for solar, rc 1, scenario cb: 0.048897342659150314
# -----------------------------------
# Updated WACC for solar, rc 2, scenario mb: 0.04981457101410628
# Updated WACC for solar, rc 2, scenario pc: 0.06599705520303915
# Updated WACC for solar, rc 2, scenario pb: 0.04881289553386807
# Updated WACC for solar, rc 2, scenario pi: 0.048870307340098056
# Updated WACC for solar, rc 2, scenario cb: 0.048864385101847645
# -----------------------------------
# Updated WACC for solar, rc 3, scenario mb: 0.049811728912407746
# Updated WACC for solar, rc 3, scenario pc: 0.0659108623152995
# Updated WACC for solar, rc 3, scenario pb: 0.04878776542712042
# Updated WACC for solar, rc 3, scenario pi: 0.04881645798664253
# Updated WACC for solar, rc 3, scenario cb: 0.04876896546177659
# -----------------------------------
# Updated WACC for solar, rc 4, scenario mb: 0.04979691248182846
# Updated WACC for solar, rc 4, scenario pc: 0.06578843005524271
# Updated WACC for solar, rc 4, scenario pb: 0.04878057473828937
# Updated WACC for solar, rc 4, scenario pi: 0.04882027526221502
# Updated WACC for solar, rc 4, scenario cb: 0.048709706056746564
# -----------------------------------
# Updated WACC for solar, rc 5, scenario mb: 0.049806067027930785
# Updated WACC for solar, rc 5, scenario pc: 0.0658337396610574
# Updated WACC for solar, rc 5, scenario pb: 0.04878057492327721
# Updated WACC for solar, rc 5, scenario pi: 0.048793483485837896
# Updated WACC for solar, rc 5, scenario cb: 0.0486906483639564
# -----------------------------------
# Updated WACC for solar, rc 6, scenario mb: 0.04984243539974889
# -----------------------------------
# Updated WACC for solar-hsat, rc 5, scenario mb: 0.0497344274409674
# Updated WACC for solar-hsat, rc 5, scenario pc: 0.06791934411063207
# Updated WACC for solar-hsat, rc 5, scenario pb: 0.04891666290549283
# Updated WACC for solar-hsat, rc 5, scenario pi: 0.049036586347715024
# Updated WACC for solar-hsat, rc 5, scenario cb: 0.04905265767015817
# -----------------------------------
# Updated WACC for solar-hsat, rc 6, scenario mb: 0.049767904690519206
# Updated WACC for solar-hsat, rc 6, scenario pc: 0.06793439264342538
# Updated WACC for solar-hsat, rc 6, scenario pb: 0.04890750519580216
# Updated WACC for solar-hsat, rc 6, scenario pi: 0.04897478108411609
# Updated WACC for solar-hsat, rc 6, scenario cb: 0.0489425155547145
# -----------------------------------
# Updated WACC for solar-hsat, rc 7, scenario mb: 0.049785003920332686
# Updated WACC for solar-hsat, rc 7, scenario pc: 0.06756073707011426
# Updated WACC for solar-hsat, rc 7, scenario pb: 0.0488683624894093
# Updated WACC for solar-hsat, rc 7, scenario pi: 0.04895782647246488
# Updated WACC for solar-hsat, rc 7, scenario cb: 0.048875493035134505
# -----------------------------------
# Updated WACC for solar-hsat, rc 8, scenario mb: 0.04972438002434249
# Updated WACC for solar-hsat, rc 8, scenario pc: 0.06733965218529014
# Updated WACC for solar-hsat, rc 8, scenario pb: 0.048773197909324044
# Updated WACC for solar-hsat, rc 8, scenario pi: 0.0487999057622054
# Updated WACC for solar-hsat, rc 8, scenario cb: 0.04871303374095546
# -----------------------------------
# Updated WACC for solar-hsat, rc 9, scenario mb: 0.04971907694693201
# Updated WACC for solar-hsat, rc 9, scenario pc: 0.06770114114426043
# Updated WACC for solar-hsat, rc 9, scenario pb: 0.048791508187187395
# Updated WACC for solar-hsat, rc 9, scenario pi: 0.048841292751933225
# Updated WACC for solar-hsat, rc 9, scenario cb: 0.04873775460257395
# -----------------------------------

# %%
importlib.reload(af)
for scenario in ['mb']#, 'pc', 'cb']:
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='offwind-dc', N=10000)
    af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='onwind', N=10000)
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar-hsat', N=10000)
    # af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_EP1000/my_plots/norm_revenue_dist_MCS_onwind_mb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Log-Normal:  KS Stat = 0.0036, p-value = 1.4044e-01
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One_EP1000/my_plots/norm_revenue_dist_MCS_onwind_pc.png
# --- Goodness of Fit Results for Onshore Wind ---
# Log-Normal:  KS Stat = 0.0172, p-value = 5.0621e-26
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_EP1000/my_plots/norm_revenue_dist_MCS_onwind_cb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Student's t: KS Stat = 0.0090, p-value = 1.7103e-07 (df = 2.7)
# -> The Student's t distribution fits the data best (lowest KS statistic).

# %%
importlib.reload(af)
carrier = 'onwind'
rc = 8
af.plot_revenue_violin(run_name, carrier, rc, scenario='mb')
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One_EP1000/my_plots/revenue_violin_plot_onwind_rc8.png
