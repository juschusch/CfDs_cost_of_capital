# %%
# Necessary imports
import importlib
import analysis_functions as af
importlib.reload(af)
run_name = "0_Iteration_Zero_EP500" # Replace with correct run name
n = af.get_network(run_name)
scenario = 'no_cfd'   # Replace with correct scenario name if needed ('cap','no_cfd')
nyears = len(n.snapshots) / 8760
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units

# %%
af.plot_price_duration_curve(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/price_duration_curve.png

# %%
prices_t = af.get_hourly_marginal_price(n)
max_price = prices_t.max()
print(f'Maximum marginal price: {max_price} €/MWh')
stats = af.price_statistics(n)
print(f"Price statistics: {stats}")
# Out:
# Maximum marginal price: 3999.9994889349678 €/MWh
# Price statistics: {'mean': 83.68650777456081, 'median': 0.033769170152992876, 'std_dev': 189.8927064704714, 'min': 0.018487319821991754, 'max': 3999.9994889349678}

# %%
importlib.reload(af)
af.plot_avg_annual_generation(run_name)
af.plot_installed_capacities(run_name)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/average_annual_generation_all_carriers.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/installed_capacities_all_carriers.png

# %%
offshore_ac_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-ac'].sum()
print(f"Total installed offshore AC capacity: {offshore_ac_cap} MW")
offshore_dc_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-dc'].sum()
print(f"Total installed offshore DC capacity: {offshore_dc_cap} MW")
offshore_float_cap = n.generators.p_nom_opt[n.generators.carrier == 'offwind-float'].sum()
print(f"Total installed offshore floating capacity: {offshore_float_cap} MW")
onshore_wind_cap = n.generators.p_nom_opt[n.generators.carrier == 'onwind'].sum()
print(f"Total installed onshore wind capacity: {onshore_wind_cap} MW")
solar_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar'].sum()
print(f"Total installed solar capacity: {solar_cap} MW")
solar_hsat_cap = n.generators.p_nom_opt[n.generators.carrier == 'solar-hsat'].sum()
print(f"Total installed solar HSAT capacity: {solar_hsat_cap} MW")
hydro_cap = n.generators.p_nom_opt[n.generators.carrier == 'ror'].sum()
print(f"Total installed hydro generation capacity: {hydro_cap} MW")
bio_cap = n.generators.p_nom_opt[n.generators.carrier == 'biomass'].sum()
print(f"Total installed bioenergy capacity: {bio_cap} MW")
geothermal_cap = n.generators.p_nom_opt[n.generators.carrier == 'geothermal'].sum()
print(f"Total installed geothermal capacity: {geothermal_cap} MW")
ccgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'CCGT'].sum()
print(f"Total installed CCGT capacity: {ccgt_cap} MW")
ocgt_cap = n.generators.p_nom_opt[n.generators.carrier == 'OCGT'].sum()
print(f"Total installed OCGT capacity: {ocgt_cap} MW")
battery_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'battery'].sum()
print(f"Total installed battery capacity: {battery_cap} MW")
hydrogen_cap = n.storage_units.p_nom_opt[n.storage_units.carrier == 'hydrogen'].sum()
print(f"Total installed hydrogen capacity: {hydrogen_cap} MW")
load_cap = n.generators.p_nom_opt[n.generators.carrier == 'load'].sum()
print(f"Total load shedding capacity: {load_cap} MW")
# Out:
# Total installed offshore AC capacity: 11919.040657910258 MW
# Total installed offshore DC capacity: 62290.98417121933 MW
# Total installed offshore floating capacity: 0.7694875657739828 MW
# Total installed onshore wind capacity: 24278.099694453813 MW
# Total installed solar capacity: 58273.240824538414 MW
# Total installed solar HSAT capacity: 162603.36888558467 MW
# Total installed hydro generation capacity: 3617.2588089999995 MW
# Total installed bioenergy capacity: 7730.271833000001 MW
# Total installed geothermal capacity: 23.9 MW
# Total installed CCGT capacity: 27999.234186173984 MW
# Total installed OCGT capacity: 37723.22802174326 MW
# Total installed battery capacity: 43295.13696433989 MW
# Total installed hydrogen capacity: 0.0 MW
# Total load shedding capacity: 34803.75245650634 MW

# %%
offshore_ac_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-ac'].sum().sum()
print(f"Total offshore AC generation: {offshore_ac_gen} MWh")
offshore_dc_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-dc'].sum().sum()
print(f"Total offshore DC generation: {offshore_dc_gen} MWh")
offshore_float_gen = n.generators_t.p.loc[:, n.generators.carrier == 'offwind-float'].sum().sum()
print(f"Total offshore floating generation: {offshore_float_gen} MWh")
onshore_wind_gen = n.generators_t.p.loc[:, n.generators.carrier == 'onwind'].sum().sum()
print(f"Total onshore wind generation: {onshore_wind_gen} MWh")
solar_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar'].sum().sum()
print(f"Total solar generation: {solar_gen} MWh")
solar_hsat_gen = n.generators_t.p.loc[:, n.generators.carrier == 'solar-hsat'].sum().sum()
print(f"Total solar HSAT generation: {solar_hsat_gen} MWh")
ccgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'CCGT'].sum().sum()
print(f"Total CCGT generation: {ccgt_gen} MWh")
ocgt_gen = n.generators_t.p.loc[:, n.generators.carrier == 'OCGT'].sum().sum()
print(f"Total OCGT generation: {ocgt_gen} MWh")
battery_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].sum().sum()
print(f"Total battery discharge: {battery_gen} MWh")
hydrogen_gen = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'hydrogen'].sum().sum()
print(f"Total hydrogen discharge: {hydrogen_gen} MWh")
load_gen = n.generators_t.p.loc[:, n.generators.carrier == 'load'].sum().sum()
print(f"Total load shedding: {load_gen} MWh")
# Out:
# Total offshore AC generation: 463839661.56819725 MWh
# Total offshore DC generation: 6388194015.939276 MWh
# Total offshore floating generation: 47720.941630361 MWh
# Total onshore wind generation: 4077187085.8447285 MWh
# Total solar generation: 5302332.2496358305 MWh
# Total solar HSAT generation: 7197075488.259207 MWh
# Total CCGT generation: 2446124655.0794163 MWh
# Total OCGT generation: 1220971079.038218 MWh
# Total battery discharge: -41120198.92480653 MWh
# Total hydrogen discharge: 0.0 MWh
# Total load shedding: 1840466.628020262 MWh

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_max[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind    45743.748412
# DE0 0 1 onwind    54117.371817
# DE0 0 2 onwind    58251.682710
# DE0 0 3 onwind    52098.507213
# DE0 0 4 onwind    50581.054172
# DE0 0 5 onwind    48267.020574
# DE0 0 6 onwind    49078.275810
# DE0 0 7 onwind    53092.707911
# DE0 0 8 onwind    48638.074786
# DE0 0 9 onwind    27968.461352
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-ac    1665.263405
# DE0 0 1 offwind-ac    9208.864488
# DE0 0 2 offwind-ac    2709.720028
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.802769
# DE0 0 2 offwind-dc    13833.554458
# DE0 0 3 offwind-dc    50358.495144
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 offwind-float    144.467403
# DE0 0 1 offwind-float    182.920728
# DE0 0 2 offwind-float    108.231258
# DE0 0 3 offwind-float     74.667750
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar    130636.363632
# DE0 0 1 solar    135780.573709
# DE0 0 2 solar    107387.176322
# DE0 0 3 solar     97614.538268
# DE0 0 4 solar    107232.765509
# DE0 0 5 solar    116601.821274
# DE0 0 6 solar     98881.173592
# DE0 0 7 solar     90797.550823
# DE0 0 8 solar    110169.652048
# DE0 0 9 solar     91472.791259
# Name: p_nom_max, dtype: float64
# Generator
# DE0 0 0 solar-hsat    114839.067548
# DE0 0 1 solar-hsat    114362.398932
# DE0 0 2 solar-hsat     92308.346032
# DE0 0 3 solar-hsat     91502.827720
# DE0 0 4 solar-hsat     92271.688846
# DE0 0 5 solar-hsat    104925.084931
# DE0 0 6 solar-hsat     79683.267813
# DE0 0 7 solar-hsat     83005.381157
# DE0 0 8 solar-hsat     94514.277451
# DE0 0 9 solar-hsat     76416.016535
# Name: p_nom_max, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat', 'CCGT']
for carrier in carriers:
    print(n.generators.capital_cost[n.generators.carrier == carrier]*35/nyears)
# Out:
# Generator
# DE0 0 0 onwind    3.127969e+06
# DE0 0 1 onwind    3.119084e+06
# DE0 0 2 onwind    3.118160e+06
# DE0 0 3 onwind    3.115482e+06
# DE0 0 4 onwind    3.114390e+06
# DE0 0 5 onwind    3.116298e+06
# DE0 0 6 onwind    3.116572e+06
# DE0 0 7 onwind    3.116883e+06
# DE0 0 8 onwind    3.120206e+06
# DE0 0 9 onwind    3.127324e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-ac    6.651806e+06
# DE0 0 1 offwind-ac    6.693376e+06
# DE0 0 2 offwind-ac    6.958907e+06
# DE0 0 3 offwind-ac    7.010655e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-dc    7.499943e+06
# DE0 0 1 offwind-dc    7.432106e+06
# DE0 0 2 offwind-dc    7.470627e+06
# DE0 0 3 offwind-dc    8.152775e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 offwind-float    9.760443e+06
# DE0 0 1 offwind-float    9.790234e+06
# DE0 0 2 offwind-float    1.012679e+07
# DE0 0 3 offwind-float    1.111375e+07
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar    1.121176e+06
# DE0 0 1 solar    1.120683e+06
# DE0 0 2 solar    1.120526e+06
# DE0 0 3 solar    1.120385e+06
# DE0 0 4 solar    1.120338e+06
# DE0 0 5 solar    1.120312e+06
# DE0 0 6 solar    1.120436e+06
# DE0 0 7 solar    1.119965e+06
# DE0 0 8 solar    1.119336e+06
# DE0 0 9 solar    1.119930e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 0 solar-hsat    1.298826e+06
# DE0 0 1 solar-hsat    1.298313e+06
# DE0 0 2 solar-hsat    1.298127e+06
# DE0 0 3 solar-hsat    1.297932e+06
# DE0 0 4 solar-hsat    1.297770e+06
# DE0 0 5 solar-hsat    1.297888e+06
# DE0 0 6 solar-hsat    1.297648e+06
# DE0 0 7 solar-hsat    1.296987e+06
# DE0 0 8 solar-hsat    1.296403e+06
# DE0 0 9 solar-hsat    1.296883e+06
# Name: capital_cost, dtype: float64
# Generator
# DE0 0 CCGT    3.667581e+06
# Name: capital_cost, dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    print(n.generators.p_nom_opt[n.generators.carrier == carrier])
# Out:
# Generator
# DE0 0 0 onwind        1.411752
# DE0 0 1 onwind        0.834318
# DE0 0 2 onwind        1.329380
# DE0 0 3 onwind        2.208141
# DE0 0 4 onwind        2.963982
# DE0 0 5 onwind        3.132269
# DE0 0 6 onwind       10.094200
# DE0 0 7 onwind     7408.219296
# DE0 0 8 onwind    21592.126729
# DE0 0 9 onwind    16502.554519
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-ac       0.809597
# DE0 0 1 offwind-ac     428.539725
# DE0 0 2 offwind-ac    2709.685873
# DE0 0 3 offwind-ac       0.000000
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-dc        0.000000
# DE0 0 1 offwind-dc        3.799596
# DE0 0 2 offwind-dc    13833.535550
# DE0 0 3 offwind-dc    27501.332956
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 offwind-float    0.100289
# DE0 0 1 offwind-float    0.127001
# DE0 0 2 offwind-float    0.172661
# DE0 0 3 offwind-float    0.132324
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar    11.088660
# DE0 0 1 solar    13.581572
# DE0 0 2 solar    14.565895
# DE0 0 3 solar    15.669475
# DE0 0 4 solar    14.396485
# DE0 0 5 solar    14.471293
# DE0 0 6 solar    16.208565
# DE0 0 7 solar    22.148558
# DE0 0 8 solar    27.578267
# DE0 0 9 solar    11.984897
# Name: p_nom_opt, dtype: float64
# Generator
# DE0 0 0 solar-hsat       66.431447
# DE0 0 1 solar-hsat       70.241553
# DE0 0 2 solar-hsat      353.587958
# DE0 0 3 solar-hsat     3797.512237
# DE0 0 4 solar-hsat      112.050937
# DE0 0 5 solar-hsat       53.564069
# DE0 0 6 solar-hsat    31554.581087
# DE0 0 7 solar-hsat    38773.605503
# DE0 0 8 solar-hsat    43242.963779
# DE0 0 9 solar-hsat    44825.228914
# Name: p_nom_opt, dtype: float64

# %%
importlib.reload(af)
af.plot_resource_classes_map(run_name, carrier='solar', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='solar-hsat', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='onwind', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-ac', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-dc', save_to_file=True)
af.plot_resource_classes_map(run_name, carrier='offwind-float', save_to_file=True)
# Out:
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_solar-hsat.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_onwind.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-ac.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-dc.png
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/map_regions_by_class_1_offwind-float.png

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    cap_pot = n.generators.p_nom_max[n.generators.carrier == carrier]
    print(f"Utilization of expansion potential for {carrier}:")
    print(cap_inst / cap_pot)
# Out:
# Utilization of expansion potential for onwind:
# Generator
# DE0 0 0 onwind    0.000031
# DE0 0 1 onwind    0.000015
# DE0 0 2 onwind    0.000023
# DE0 0 3 onwind    0.000042
# DE0 0 4 onwind    0.000059
# DE0 0 5 onwind    0.000065
# DE0 0 6 onwind    0.000206
# DE0 0 7 onwind    0.139534
# DE0 0 8 onwind    0.443935
# DE0 0 9 onwind    0.590042
# dtype: float64
# Utilization of expansion potential for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.000486
# DE0 0 1 offwind-ac    0.046536
# DE0 0 2 offwind-ac    0.999987
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Utilization of expansion potential for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.999166
# DE0 0 2 offwind-dc    0.999999
# DE0 0 3 offwind-dc    0.546111
# dtype: float64
# Utilization of expansion potential for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.000694
# DE0 0 1 offwind-float    0.000694
# DE0 0 2 offwind-float    0.001595
# DE0 0 3 offwind-float    0.001772
# dtype: float64
# Utilization of expansion potential for solar:
# Generator
# DE0 0 0 solar    0.000085
# DE0 0 1 solar    0.000100
# DE0 0 2 solar    0.000136
# DE0 0 3 solar    0.000161
# DE0 0 4 solar    0.000134
# DE0 0 5 solar    0.000124
# DE0 0 6 solar    0.000164
# DE0 0 7 solar    0.000244
# DE0 0 8 solar    0.000250
# DE0 0 9 solar    0.000131
# dtype: float64
# Utilization of expansion potential for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.000578
# DE0 0 1 solar-hsat    0.000614
# DE0 0 2 solar-hsat    0.003831
# DE0 0 3 solar-hsat    0.041502
# DE0 0 4 solar-hsat    0.001214
# DE0 0 5 solar-hsat    0.000510
# DE0 0 6 solar-hsat    0.396000
# DE0 0 7 solar-hsat    0.467122
# DE0 0 8 solar-hsat    0.457528
# DE0 0 9 solar-hsat    0.586595
# dtype: float64

# %%
carriers = ['onwind' , 'offwind-ac', 'offwind-dc', 'offwind-float', 'solar', 'solar-hsat']
for carrier in carriers:
    cap_inst = n.generators.p_nom_opt[n.generators.carrier == carrier]
    generation = n.generators_t.p.loc[:, n.generators.carrier == carrier].sum()
    print(f"Average capacity factor for {carrier}:")
    print(generation / cap_inst / len(n.snapshots))
# Out:
# Average capacity factor for onwind:
# Generator
# DE0 0 0 onwind    0.059268
# DE0 0 1 onwind    0.121543
# DE0 0 2 onwind    0.143906
# DE0 0 3 onwind    0.168419
# DE0 0 4 onwind    0.192372
# DE0 0 5 onwind    0.205539
# DE0 0 6 onwind    0.224651
# DE0 0 7 onwind    0.235392
# DE0 0 8 onwind    0.266373
# DE0 0 9 onwind    0.351367
# dtype: float64
# Average capacity factor for offwind-ac:
# Generator
# DE0 0 0 offwind-ac    0.347498
# DE0 0 1 offwind-ac    0.442401
# DE0 0 2 offwind-ac    0.488242
# DE0 0 3 offwind-ac         NaN
# dtype: float64
# Average capacity factor for offwind-dc:
# Generator
# DE0 0 0 offwind-dc         NaN
# DE0 0 1 offwind-dc    0.411175
# DE0 0 2 offwind-dc    0.504784
# DE0 0 3 offwind-dc    0.503652
# dtype: float64
# Average capacity factor for offwind-float:
# Generator
# DE0 0 0 offwind-float    0.177456
# DE0 0 1 offwind-float    0.261482
# DE0 0 2 offwind-float    0.326012
# DE0 0 3 offwind-float    0.365396
# dtype: float64
# Average capacity factor for solar:
# Generator
# DE0 0 0 solar    0.098827
# DE0 0 1 solar    0.100089
# DE0 0 2 solar    0.101097
# DE0 0 3 solar    0.102170
# DE0 0 4 solar    0.103546
# DE0 0 5 solar    0.104692
# DE0 0 6 solar    0.106263
# DE0 0 7 solar    0.109291
# DE0 0 8 solar    0.114582
# DE0 0 9 solar    0.121531
# dtype: float64
# Average capacity factor for solar-hsat:
# Generator
# DE0 0 0 solar-hsat    0.116860
# DE0 0 1 solar-hsat    0.118251
# DE0 0 2 solar-hsat    0.118422
# DE0 0 3 solar-hsat    0.122933
# DE0 0 4 solar-hsat    0.121545
# DE0 0 5 solar-hsat    0.123870
# DE0 0 6 solar-hsat    0.138844
# DE0 0 7 solar-hsat    0.139576
# DE0 0 8 solar-hsat    0.145791
# DE0 0 9 solar-hsat    0.152398
# dtype: float64

# %%
print(n.storage_units.p_nom_opt)
# Out:
# StorageUnit
# DE0 0 PHS         7828.920000
# DE0 0 hydro        330.195150
# DE0 0 battery    17506.316291
# DE0 0 H2             0.314826
# Name: p_nom_opt, dtype: float64

# %%
output_bat = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'battery'].clip(lower=0).sum().sum()
print(f'Total battery output: {output_bat} MWh')
output_phs = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'PHS'].clip(lower=0).sum().sum()
print(f'Total PHS output: {output_phs} MWh')
output_h2 = n.storage_units_t.p.loc[:, n.storage_units.carrier == 'H2'].clip(lower=0).sum().sum()
print(f'Total H2 output: {output_h2} MWh')
# Out:
# Total battery output: 936794882.7398388 MWh
# Total PHS output: 425473739.0114251 MWh
# Total H2 output: 5165.893751287589 MWh

# %%
importlib.reload(af)

costs = af.get_costs(run_name)
for t in [20, 30, 40]:
    af.years_mcs(run_name, n, T=t, N=10000)
    af.revenue_mcs(costs, run_name, n, T=t, N=10000)

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pb', 'pi', 'cb']:    
            avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Average lifetime revenue per MW of {carrier}, rc {rc}, scenario {scenario}: {avg_rev}")
        print('-----------------------------------')
# Out:
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario mb: 4597806.266770418
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pb: 4596758.83879423
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario pi: 4596399.229168918
# Average lifetime revenue per MW of offwind-ac, rc 0, scenario cb: 4596648.658154199
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario mb: 6168752.630486359
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pb: 6167399.6364007685
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario pi: 6167345.592884859
# Average lifetime revenue per MW of offwind-ac, rc 1, scenario cb: 6167595.02187014
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario mb: 7311441.151329456
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pb: 7309839.014872606
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario pi: 7310034.113727954
# Average lifetime revenue per MW of offwind-ac, rc 2, scenario cb: 7310283.542713237
# -----------------------------------
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario mb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pb: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario pi: nan
# Average lifetime revenue per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario mb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pb: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario pi: nan
# Average lifetime revenue per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario mb: 7809524.825145401
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pb: 7808639.299832081
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario pi: 7807217.236943524
# Average lifetime revenue per MW of offwind-dc, rc 1, scenario cb: 7807939.926761006
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario mb: 7134904.737091246
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pb: 7133293.139860515
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario pi: 7132597.1488893675
# Average lifetime revenue per MW of offwind-dc, rc 2, scenario cb: 7133319.83870685
# -----------------------------------
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario mb: 7379688.539283171
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pb: 7377183.494384534
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario pi: 7377380.951081293
# Average lifetime revenue per MW of offwind-dc, rc 3, scenario cb: 7378103.640898776
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 0, scenario mb: 1412129.4055861866
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pb: 1410420.3185949929
# Average lifetime revenue per MW of offwind-float, rc 0, scenario pi: 1409325.4175966582
# Average lifetime revenue per MW of offwind-float, rc 0, scenario cb: 1409452.8415293705
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 1, scenario mb: 2358961.902971749
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pb: 2356397.7297684243
# Average lifetime revenue per MW of offwind-float, rc 1, scenario pi: 2356157.9149822206
# Average lifetime revenue per MW of offwind-float, rc 1, scenario cb: 2356285.338914933
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 2, scenario mb: 3410667.0844442137
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pb: 3407486.721838773
# Average lifetime revenue per MW of offwind-float, rc 2, scenario pi: 3407863.0964546846
# Average lifetime revenue per MW of offwind-float, rc 2, scenario cb: 3407990.5203873967
# -----------------------------------
# Average lifetime revenue per MW of offwind-float, rc 3, scenario mb: 3508331.973786213
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pb: 3504920.315077735
# Average lifetime revenue per MW of offwind-float, rc 3, scenario pi: 3505527.9857966844
# Average lifetime revenue per MW of offwind-float, rc 3, scenario cb: 3505655.409729396
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 0, scenario mb: 1499889.3595575772
# Average lifetime revenue per MW of onwind, rc 0, scenario pb: 1500206.3391515284
# Average lifetime revenue per MW of onwind, rc 0, scenario pi: 1499020.153560328
# Average lifetime revenue per MW of onwind, rc 0, scenario cb: 1499160.9428105983
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 1, scenario mb: 2500967.1784426835
# Average lifetime revenue per MW of onwind, rc 1, scenario pb: 2501742.183736304
# Average lifetime revenue per MW of onwind, rc 1, scenario pi: 2500097.9724454335
# Average lifetime revenue per MW of onwind, rc 1, scenario cb: 2500238.7616957035
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 2, scenario mb: 2682246.6386930193
# Average lifetime revenue per MW of onwind, rc 2, scenario pb: 2683011.825865805
# Average lifetime revenue per MW of onwind, rc 2, scenario pi: 2681377.4326957697
# Average lifetime revenue per MW of onwind, rc 2, scenario cb: 2681518.2219460392
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 3, scenario mb: 2746828.123178213
# Average lifetime revenue per MW of onwind, rc 3, scenario pb: 2747351.0514468406
# Average lifetime revenue per MW of onwind, rc 3, scenario pi: 2745958.9171809633
# Average lifetime revenue per MW of onwind, rc 3, scenario cb: 2746099.7064312333
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 4, scenario mb: 2676719.277732051
# Average lifetime revenue per MW of onwind, rc 4, scenario pb: 2677030.219469872
# Average lifetime revenue per MW of onwind, rc 4, scenario pi: 2675850.0717348023
# Average lifetime revenue per MW of onwind, rc 4, scenario cb: 2675990.860985073
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 5, scenario mb: 2574027.632598542
# Average lifetime revenue per MW of onwind, rc 5, scenario pb: 2574088.5918289656
# Average lifetime revenue per MW of onwind, rc 5, scenario pi: 2573158.426601293
# Average lifetime revenue per MW of onwind, rc 5, scenario cb: 2573299.2158515626
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 6, scenario mb: 2696739.8184187505
# Average lifetime revenue per MW of onwind, rc 6, scenario pb: 2696678.037528434
# Average lifetime revenue per MW of onwind, rc 6, scenario pi: 2695870.612421502
# Average lifetime revenue per MW of onwind, rc 6, scenario cb: 2696011.401671772
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 7, scenario mb: 2767189.977121975
# Average lifetime revenue per MW of onwind, rc 7, scenario pb: 2767019.024507051
# Average lifetime revenue per MW of onwind, rc 7, scenario pi: 2766320.7711247257
# Average lifetime revenue per MW of onwind, rc 7, scenario cb: 2766461.5603749957
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 8, scenario mb: 2962857.258880884
# Average lifetime revenue per MW of onwind, rc 8, scenario pb: 2962420.5481161387
# Average lifetime revenue per MW of onwind, rc 8, scenario pi: 2961988.0528836343
# Average lifetime revenue per MW of onwind, rc 8, scenario cb: 2962128.8421339043
# -----------------------------------
# Average lifetime revenue per MW of onwind, rc 9, scenario mb: 3784107.051822365
# Average lifetime revenue per MW of onwind, rc 9, scenario pb: 3783031.3816109197
# Average lifetime revenue per MW of onwind, rc 9, scenario pi: 3783237.8458251166
# Average lifetime revenue per MW of onwind, rc 9, scenario cb: 3783378.635075386
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 0, scenario mb: 1485796.6306921528
# Average lifetime revenue per MW of solar, rc 0, scenario pb: 1485527.3388039174
# Average lifetime revenue per MW of solar, rc 0, scenario pi: 1485382.9216182705
# Average lifetime revenue per MW of solar, rc 0, scenario cb: 1485278.4176085945
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 1, scenario mb: 1504050.9117315563
# Average lifetime revenue per MW of solar, rc 1, scenario pb: 1503797.6335304303
# Average lifetime revenue per MW of solar, rc 1, scenario pi: 1503637.2026576737
# Average lifetime revenue per MW of solar, rc 1, scenario cb: 1503532.698647998
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 2, scenario mb: 1505247.3162024661
# Average lifetime revenue per MW of solar, rc 2, scenario pb: 1504977.6688037293
# Average lifetime revenue per MW of solar, rc 2, scenario pi: 1504833.6071285843
# Average lifetime revenue per MW of solar, rc 2, scenario cb: 1504729.1031189081
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 3, scenario mb: 1521196.2427351133
# Average lifetime revenue per MW of solar, rc 3, scenario pb: 1520909.1101873482
# Average lifetime revenue per MW of solar, rc 3, scenario pi: 1520782.533661231
# Average lifetime revenue per MW of solar, rc 3, scenario cb: 1520678.029651555
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 4, scenario mb: 1525157.276121217
# Average lifetime revenue per MW of solar, rc 4, scenario pb: 1524839.391311516
# Average lifetime revenue per MW of solar, rc 4, scenario pi: 1524743.567047335
# Average lifetime revenue per MW of solar, rc 4, scenario cb: 1524639.0630376593
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 5, scenario mb: 1532669.7874918059
# Average lifetime revenue per MW of solar, rc 5, scenario pb: 1532303.5950105619
# Average lifetime revenue per MW of solar, rc 5, scenario pi: 1532256.0784179238
# Average lifetime revenue per MW of solar, rc 5, scenario cb: 1532151.5744082478
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 6, scenario mb: 1570865.8570622823
# Average lifetime revenue per MW of solar, rc 6, scenario pb: 1570481.8904714433
# Average lifetime revenue per MW of solar, rc 6, scenario pi: 1570452.1479883995
# Average lifetime revenue per MW of solar, rc 6, scenario cb: 1570347.643978724
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 7, scenario mb: 1618368.186590222
# Average lifetime revenue per MW of solar, rc 7, scenario pb: 1617962.9334868968
# Average lifetime revenue per MW of solar, rc 7, scenario pi: 1617954.4775163394
# Average lifetime revenue per MW of solar, rc 7, scenario cb: 1617849.973506664
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 8, scenario mb: 1708361.1491352904
# Average lifetime revenue per MW of solar, rc 8, scenario pb: 1707840.7996977104
# Average lifetime revenue per MW of solar, rc 8, scenario pi: 1707947.4400614079
# Average lifetime revenue per MW of solar, rc 8, scenario cb: 1707842.9360517322
# -----------------------------------
# Average lifetime revenue per MW of solar, rc 9, scenario mb: 1868607.0590204427
# Average lifetime revenue per MW of solar, rc 9, scenario pb: 1867894.614322127
# Average lifetime revenue per MW of solar, rc 9, scenario pi: 1868193.3499465599
# Average lifetime revenue per MW of solar, rc 9, scenario cb: 1868088.8459368844
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario mb: 1749257.0863395347
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario pb: 1749093.5930027238
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario pi: 1748791.1009185158
# Average lifetime revenue per MW of solar-hsat, rc 0, scenario cb: 1748669.6532644443
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario mb: 1752212.5512673438
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario pb: 1752047.2739891289
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario pi: 1751746.5658463254
# Average lifetime revenue per MW of solar-hsat, rc 1, scenario cb: 1751625.1181922532
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario mb: 1768465.703734797
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario pb: 1768262.5558194749
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario pi: 1767999.7183137788
# Average lifetime revenue per MW of solar-hsat, rc 2, scenario cb: 1767878.270659706
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario mb: 1780668.3456409539
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario pb: 1780452.072559046
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario pi: 1780202.3602199352
# Average lifetime revenue per MW of solar-hsat, rc 3, scenario cb: 1780080.9125658628
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario mb: 1779319.1165163887
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario pb: 1779056.9096728251
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario pi: 1778853.1310953698
# Average lifetime revenue per MW of solar-hsat, rc 4, scenario cb: 1778731.6834412976
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario mb: 1774416.4861391333
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario pb: 1774100.9238499799
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario pi: 1773950.5007181144
# Average lifetime revenue per MW of solar-hsat, rc 5, scenario cb: 1773829.0530640427
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario mb: 1840858.3977501015
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario pb: 1840534.6716196036
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario pi: 1840392.4123290824
# Average lifetime revenue per MW of solar-hsat, rc 6, scenario cb: 1840270.9646750106
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario mb: 1875148.8188348045
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario pb: 1874756.0776232064
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario pi: 1874682.833413786
# Average lifetime revenue per MW of solar-hsat, rc 7, scenario cb: 1874561.3857597134
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario mb: 1956826.7918419072
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario pb: 1956342.7386410339
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario pi: 1956360.8064208885
# Average lifetime revenue per MW of solar-hsat, rc 8, scenario cb: 1956239.3587668159
# -----------------------------------
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario mb: 2150183.882412075
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario pb: 2149458.2749900636
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario pi: 2149717.8969910564
# Average lifetime revenue per MW of solar-hsat, rc 9, scenario cb: 2149596.449336984
# -----------------------------------

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pb', 'pi', 'cb']:    
            risk = af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, scenario=scenario)
            print(f"Relative revenue risk per MW of {carrier}, rc {rc}, scenario {scenario}: {risk}")
        print('-----------------------------------')
# Out:
# Relative revenue risk per MW of offwind-ac, rc 0, scenario mb: 0.051044936667903086
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pb: 0.00875942190738713
# Relative revenue risk per MW of offwind-ac, rc 0, scenario pi: 0.024202836282218518
# Relative revenue risk per MW of offwind-ac, rc 0, scenario cb: 0.01746119304973101
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 1, scenario mb: 0.048368155751364675
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pb: 0.008114044436883653
# Relative revenue risk per MW of offwind-ac, rc 1, scenario pi: 0.009064532444975218
# Relative revenue risk per MW of offwind-ac, rc 1, scenario cb: 0.002137916737297668
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 2, scenario mb: 0.046675663279245286
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pb: 0.0057916371630589445
# Relative revenue risk per MW of offwind-ac, rc 2, scenario pi: 0.006257327250940111
# Relative revenue risk per MW of offwind-ac, rc 2, scenario cb: 0.006134046775899433
# -----------------------------------
# Relative revenue risk per MW of offwind-ac, rc 3, scenario mb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pb: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario pi: nan
# Relative revenue risk per MW of offwind-ac, rc 3, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 0, scenario mb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pb: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario pi: nan
# Relative revenue risk per MW of offwind-dc, rc 0, scenario cb: nan
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 1, scenario mb: 0.04614097119713521
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pb: 0.006575667649925051
# Relative revenue risk per MW of offwind-dc, rc 1, scenario pi: 0.01699654555939976
# Relative revenue risk per MW of offwind-dc, rc 1, scenario cb: 0.01753139984322858
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 2, scenario mb: 0.04657371855384898
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pb: 0.007050002468995343
# Relative revenue risk per MW of offwind-dc, rc 2, scenario pi: 0.008835603184191968
# Relative revenue risk per MW of offwind-dc, rc 2, scenario cb: 0.00511637433842248
# -----------------------------------
# Relative revenue risk per MW of offwind-dc, rc 3, scenario mb: 0.04671347941665074
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pb: 0.006762477791999144
# Relative revenue risk per MW of offwind-dc, rc 3, scenario pi: 0.006748503120514305
# Relative revenue risk per MW of offwind-dc, rc 3, scenario cb: 0.0014124853686102426
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 0, scenario mb: 0.07200117379243394
# Relative revenue risk per MW of offwind-float, rc 0, scenario pb: 0.013843194544198344
# Relative revenue risk per MW of offwind-float, rc 0, scenario pi: 0.06323462355577185
# Relative revenue risk per MW of offwind-float, rc 0, scenario cb: 0.056583503627192215
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 1, scenario mb: 0.06686722242934655
# Relative revenue risk per MW of offwind-float, rc 1, scenario pb: 0.011654474660326252
# Relative revenue risk per MW of offwind-float, rc 1, scenario pi: 0.018248603101720925
# Relative revenue risk per MW of offwind-float, rc 1, scenario cb: 0.011555504671301384
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 2, scenario mb: 0.06266431435301971
# Relative revenue risk per MW of offwind-float, rc 2, scenario pb: 0.008868516472925893
# Relative revenue risk per MW of offwind-float, rc 2, scenario pi: 0.01297584839601069
# Relative revenue risk per MW of offwind-float, rc 2, scenario cb: 0.012332559551234091
# -----------------------------------
# Relative revenue risk per MW of offwind-float, rc 3, scenario mb: 0.06311605422541236
# Relative revenue risk per MW of offwind-float, rc 3, scenario pb: 0.007770852594083809
# Relative revenue risk per MW of offwind-float, rc 3, scenario pi: 0.015725265623325758
# Relative revenue risk per MW of offwind-float, rc 3, scenario cb: 0.01609796684276822
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 0, scenario mb: 0.05281341813711844
# Relative revenue risk per MW of onwind, rc 0, scenario pb: 0.02240937363307387
# Relative revenue risk per MW of onwind, rc 0, scenario pi: 0.11168350135186059
# Relative revenue risk per MW of onwind, rc 0, scenario cb: 0.09220882890380427
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 1, scenario mb: 0.05139232848053696
# Relative revenue risk per MW of onwind, rc 1, scenario pb: 0.025017291646003786
# Relative revenue risk per MW of onwind, rc 1, scenario pi: 0.05973431694268576
# Relative revenue risk per MW of onwind, rc 1, scenario cb: 0.05062897272912835
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 2, scenario mb: 0.05214329013327258
# Relative revenue risk per MW of onwind, rc 2, scenario pb: 0.02273726144130175
# Relative revenue risk per MW of onwind, rc 2, scenario pi: 0.04998277571582906
# Relative revenue risk per MW of onwind, rc 2, scenario cb: 0.04216674061078289
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 3, scenario mb: 0.05141186096759523
# Relative revenue risk per MW of onwind, rc 3, scenario pb: 0.020729096160298003
# Relative revenue risk per MW of onwind, rc 3, scenario pi: 0.044733717465045376
# Relative revenue risk per MW of onwind, rc 3, scenario cb: 0.0365896369481349
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 4, scenario mb: 0.047809439663864785
# Relative revenue risk per MW of onwind, rc 4, scenario pb: 0.01989002474757755
# Relative revenue risk per MW of onwind, rc 4, scenario pi: 0.043982722249853674
# Relative revenue risk per MW of onwind, rc 4, scenario cb: 0.033404463886752465
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 5, scenario mb: 0.04598023057075892
# Relative revenue risk per MW of onwind, rc 5, scenario pb: 0.01923705155291041
# Relative revenue risk per MW of onwind, rc 5, scenario pi: 0.04500850172215693
# Relative revenue risk per MW of onwind, rc 5, scenario cb: 0.032612407234189324
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 6, scenario mb: 0.04637459320211034
# Relative revenue risk per MW of onwind, rc 6, scenario pb: 0.017085917948363134
# Relative revenue risk per MW of onwind, rc 6, scenario pi: 0.03735807745552629
# Relative revenue risk per MW of onwind, rc 6, scenario cb: 0.0254459605145058
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 7, scenario mb: 0.04759350360255486
# Relative revenue risk per MW of onwind, rc 7, scenario pb: 0.015665039886797114
# Relative revenue risk per MW of onwind, rc 7, scenario pi: 0.03425538372502342
# Relative revenue risk per MW of onwind, rc 7, scenario cb: 0.0234955893566153
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 8, scenario mb: 0.0485968745299517
# Relative revenue risk per MW of onwind, rc 8, scenario pb: 0.013823015241948474
# Relative revenue risk per MW of onwind, rc 8, scenario pi: 0.025934270473768818
# Relative revenue risk per MW of onwind, rc 8, scenario cb: 0.014655610073655968
# -----------------------------------
# Relative revenue risk per MW of onwind, rc 9, scenario mb: 0.05304169414719765
# Relative revenue risk per MW of onwind, rc 9, scenario pb: 0.011663168815839578
# Relative revenue risk per MW of onwind, rc 9, scenario pi: 0.009066630018404138
# Relative revenue risk per MW of onwind, rc 9, scenario cb: 0.005446633430361447
# -----------------------------------
# Relative revenue risk per MW of solar, rc 0, scenario mb: 0.037265329743391064
# Relative revenue risk per MW of solar, rc 0, scenario pb: 0.008345979308043022
# Relative revenue risk per MW of solar, rc 0, scenario pi: 0.0122194839091011
# Relative revenue risk per MW of solar, rc 0, scenario cb: 0.011558571252007238
# -----------------------------------
# Relative revenue risk per MW of solar, rc 1, scenario mb: 0.0372086677415085
# Relative revenue risk per MW of solar, rc 1, scenario pb: 0.00828254524299038
# Relative revenue risk per MW of solar, rc 1, scenario pi: 0.010511875633333168
# Relative revenue risk per MW of solar, rc 1, scenario cb: 0.00905362965260908
# -----------------------------------
# Relative revenue risk per MW of solar, rc 2, scenario mb: 0.03673788369243535
# Relative revenue risk per MW of solar, rc 2, scenario pb: 0.008142013504793523
# Relative revenue risk per MW of solar, rc 2, scenario pi: 0.009283151925729344
# Relative revenue risk per MW of solar, rc 2, scenario cb: 0.008449012195918787
# -----------------------------------
# Relative revenue risk per MW of solar, rc 3, scenario mb: 0.037154086833501875
# Relative revenue risk per MW of solar, rc 3, scenario pb: 0.008115506776618257
# Relative revenue risk per MW of solar, rc 3, scenario pi: 0.008308349153694246
# Relative revenue risk per MW of solar, rc 3, scenario cb: 0.0062752354559178335
# -----------------------------------
# Relative revenue risk per MW of solar, rc 4, scenario mb: 0.03760016774311499
# Relative revenue risk per MW of solar, rc 4, scenario pb: 0.008102172894830487
# Relative revenue risk per MW of solar, rc 4, scenario pi: 0.008237092019681985
# Relative revenue risk per MW of solar, rc 4, scenario cb: 0.004136336364361937
# -----------------------------------
# Relative revenue risk per MW of solar, rc 5, scenario mb: 0.03751401464436367
# Relative revenue risk per MW of solar, rc 5, scenario pb: 0.007846361886215548
# Relative revenue risk per MW of solar, rc 5, scenario pi: 0.007131098192938501
# Relative revenue risk per MW of solar, rc 5, scenario cb: 0.003490085504175206
# -----------------------------------
# Relative revenue risk per MW of solar, rc 6, scenario mb: 0.039273535968594384
# Relative revenue risk per MW of solar, rc 6, scenario pb: 0.008343879138553752
# Relative revenue risk per MW of solar, rc 6, scenario pi: 0.0089252829985703
# Relative revenue risk per MW of solar, rc 6, scenario cb: 0.0032737633320085347
# -----------------------------------
# Relative revenue risk per MW of solar, rc 7, scenario mb: 0.0398544724391857
# Relative revenue risk per MW of solar, rc 7, scenario pb: 0.008217579289405653
# Relative revenue risk per MW of solar, rc 7, scenario pi: 0.012236370953882534
# Relative revenue risk per MW of solar, rc 7, scenario cb: 0.00770128147080417
# -----------------------------------
# Relative revenue risk per MW of solar, rc 8, scenario mb: 0.03817405768774291
# Relative revenue risk per MW of solar, rc 8, scenario pb: 0.005839091506893383
# Relative revenue risk per MW of solar, rc 8, scenario pi: 0.01009559254418888
# Relative revenue risk per MW of solar, rc 8, scenario cb: 0.006330508345490012
# -----------------------------------
# Relative revenue risk per MW of solar, rc 9, scenario mb: 0.03921800872683395
# Relative revenue risk per MW of solar, rc 9, scenario pb: 0.006079566852081304
# Relative revenue risk per MW of solar, rc 9, scenario pi: 0.012931029990792667
# Relative revenue risk per MW of solar, rc 9, scenario cb: 0.009972966615984496
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 0, scenario mb: 0.03599392731306912
# Relative revenue risk per MW of solar-hsat, rc 0, scenario pb: 0.011026965045373155
# Relative revenue risk per MW of solar-hsat, rc 0, scenario pi: 0.013398727791312194
# Relative revenue risk per MW of solar-hsat, rc 0, scenario cb: 0.013095721476551015
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 1, scenario mb: 0.03506174908126135
# Relative revenue risk per MW of solar-hsat, rc 1, scenario pb: 0.010992575100478798
# Relative revenue risk per MW of solar-hsat, rc 1, scenario pi: 0.011706093647264208
# Relative revenue risk per MW of solar-hsat, rc 1, scenario cb: 0.011365390768608671
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 2, scenario mb: 0.03444306740491403
# Relative revenue risk per MW of solar-hsat, rc 2, scenario pb: 0.010678779276396188
# Relative revenue risk per MW of solar-hsat, rc 2, scenario pi: 0.011165164450643616
# Relative revenue risk per MW of solar-hsat, rc 2, scenario cb: 0.011437951689514708
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 3, scenario mb: 0.03446602310163988
# Relative revenue risk per MW of solar-hsat, rc 3, scenario pb: 0.010249832649931102
# Relative revenue risk per MW of solar-hsat, rc 3, scenario pi: 0.010117397566129595
# Relative revenue risk per MW of solar-hsat, rc 3, scenario cb: 0.01000064069478359
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 4, scenario mb: 0.034743997384057604
# Relative revenue risk per MW of solar-hsat, rc 4, scenario pb: 0.010187445653925946
# Relative revenue risk per MW of solar-hsat, rc 4, scenario pi: 0.00913354836432903
# Relative revenue risk per MW of solar-hsat, rc 4, scenario cb: 0.008122003227309455
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 5, scenario mb: 0.03527987588912368
# Relative revenue risk per MW of solar-hsat, rc 5, scenario pb: 0.010234235898213038
# Relative revenue risk per MW of solar-hsat, rc 5, scenario pi: 0.00845918284302384
# Relative revenue risk per MW of solar-hsat, rc 5, scenario cb: 0.007665962153955703
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 6, scenario mb: 0.036396926020334834
# Relative revenue risk per MW of solar-hsat, rc 6, scenario pb: 0.009934793355244602
# Relative revenue risk per MW of solar-hsat, rc 6, scenario pi: 0.008191099985277618
# Relative revenue risk per MW of solar-hsat, rc 6, scenario cb: 0.0043521400903578245
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 7, scenario mb: 0.03708420106445124
# Relative revenue risk per MW of solar-hsat, rc 7, scenario pb: 0.008328616541284558
# Relative revenue risk per MW of solar-hsat, rc 7, scenario pi: 0.010044167401945078
# Relative revenue risk per MW of solar-hsat, rc 7, scenario cb: 0.005282321196952661
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 8, scenario mb: 0.03571236758116966
# Relative revenue risk per MW of solar-hsat, rc 8, scenario pb: 0.007151801399918362
# Relative revenue risk per MW of solar-hsat, rc 8, scenario pi: 0.007937538398269616
# Relative revenue risk per MW of solar-hsat, rc 8, scenario cb: 0.00418879422629082
# -----------------------------------
# Relative revenue risk per MW of solar-hsat, rc 9, scenario mb: 0.03677159166989501
# Relative revenue risk per MW of solar-hsat, rc 9, scenario pb: 0.005788358979169472
# Relative revenue risk per MW of solar-hsat, rc 9, scenario pi: 0.010633181176524628
# Relative revenue risk per MW of solar-hsat, rc 9, scenario cb: 0.006749863645871556
# -----------------------------------

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        af.revenue_statistics_comparison(run_name, carrier, n, rc)
        print('-----------------------------------')
# Out:
# Revenue Statistics for Offshore Wind (AC), Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       4597806.2668       4596758.8388       4596399.2292       4596648.6582
# median     4585015.6615       4597634.1003       4598109.2742       4600660.5798
# std_dev    234694.7297        40264.9501         111245.8980        80262.9696
# risk       0.0510             0.0088             0.0242             0.0175
# min        3846865.0444       4455223.1578       4141961.7591       4248904.6195
# max        5556217.0374       4748134.4351       4968184.7797       4849492.1192
# wacc       0.0594             0.0578             0.0584             0.0581
# -----------------------------------
# Revenue Statistics for Offshore Wind (AC), Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       6168752.6305       6167399.6364       6167345.5929       6167595.0219
# median     6155529.2072       6167758.8571       6168106.7080       6167873.2897
# std_dev    298371.1880        50042.5547         55904.1042         13185.8046
# risk       0.0484             0.0081             0.0091             0.0021
# min        5209613.8843       5973882.6245       5938101.7827       6118575.4943
# max        7368021.1575       6355901.1956       6374697.6378       6216783.3450
# wacc       0.0593             0.0578             0.0578             0.0576
# -----------------------------------
# Revenue Statistics for Offshore Wind (AC), Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       7311441.1513       7309839.0149       7310034.1137       7310283.5427
# median     7298234.2714       7310761.1967       7310812.1308       7309318.2353
# std_dev    341266.3653        42335.9353         45741.2757         44841.6212
# risk       0.0467             0.0058             0.0063             0.0061
# min        6217366.3761       7148978.2139       7126390.8269       7143023.6879
# max        8712206.6692       7450487.5937       7466933.6293       7477004.7211
# wacc       0.0592             0.0577             0.0577             0.0577
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Revenue Statistics for Offshore Wind (AC), Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       nan                nan                nan                nan
# median     nan                nan                nan                nan
# std_dev    nan                nan                nan                nan
# risk       nan                nan                nan                nan
# min        nan                nan                nan                nan
# max        nan                nan                nan                nan
# wacc       0.0700             0.0700             0.0700             0.0700
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Revenue Statistics for Offshore Wind (DC), Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       nan                nan                nan                nan
# median     nan                nan                nan                nan
# std_dev    nan                nan                nan                nan
# risk       nan                nan                nan                nan
# min        nan                nan                nan                nan
# max        nan                nan                nan                nan
# wacc       0.0700             0.0700             0.0700             0.0700
# -----------------------------------
# Revenue Statistics for Offshore Wind (DC), Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       7809524.8251       7808639.2998       7807217.2369       7807939.9268
# median     7803432.8140       7809936.0952       7806086.3930       7808661.7197
# std_dev    360339.0600        51347.0168         132695.7235        136884.1168
# risk       0.0461             0.0066             0.0170             0.0175
# min        6623370.1477       7567343.8376       7298269.4627       7311400.7137
# max        9287976.6448       8001535.3843       8370930.5073       8325141.0381
# wacc       0.0592             0.0577             0.0581             0.0581
# -----------------------------------
# Revenue Statistics for Offshore Wind (DC), Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       7134904.7371       7133293.1399       7132597.1489       7133319.8387
# median     7120991.2465       7131815.8608       7130422.6882       7132742.0771
# std_dev    332299.0451        50289.7342         63020.7981         36496.7346
# risk       0.0466             0.0071             0.0088             0.0051
# min        6095159.3375       6942412.8488       6913779.7600       7002880.2458
# max        8518814.4395       7333446.5542       7395597.3604       7269627.4734
# wacc       0.0592             0.0578             0.0578             0.0577
# -----------------------------------
# Revenue Statistics for Offshore Wind (DC), Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       7379688.5393       7377183.4944       7377380.9511       7378103.6409
# median     7363182.0649       7376411.5255       7377710.3559       7378285.4372
# std_dev    344730.9287        49888.0395         49786.2784         10421.4634
# risk       0.0467             0.0068             0.0067             0.0014
# min        6285867.7601       7148708.6900       7135675.1030       7339194.7511
# max        8844643.4425       7613500.2809       7593697.2818       7415357.3337
# wacc       0.0592             0.0577             0.0577             0.0576
# -----------------------------------
# Revenue Statistics for Offshore Wind (Floating), Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1412129.4056       1410420.3186       1409325.4176       1409452.8415
# median     1403920.0235       1410429.6807       1412295.9477       1414748.8337
# std_dev    101674.9747        19524.7229         89118.1622         79751.7800
# risk       0.0720             0.0138             0.0632             0.0566
# min        1121647.0071       1340873.6284       995191.8218        1035182.5284
# max        1975754.2657       1489654.6633       1736902.6043       1656162.9221
# wacc       0.0611             0.0582             0.0606             0.0603
# -----------------------------------
# Revenue Statistics for Offshore Wind (Floating), Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2358961.9030       2356397.7298       2356157.9150       2356285.3389
# median     2347489.9477       2356823.4190       2356705.7095       2357106.7531
# std_dev    157737.2303        27462.5776         42996.5906         27228.0662
# risk       0.0669             0.0117             0.0182             0.0116
# min        1901485.6819       2261072.0576       2192470.2108       2232460.9174
# max        3181567.9120       2451569.1460       2535324.9035       2458321.0226
# wacc       0.0608             0.0581             0.0584             0.0581
# -----------------------------------
# Revenue Statistics for Offshore Wind (Floating), Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       3410667.0844       3407486.7218       3407863.0965       3407990.5204
# median     3396569.7292       3408114.3857       3407086.0433       3405748.5543
# std_dev    213727.1143        30219.3521         44219.9149         42029.2460
# risk       0.0627             0.0089             0.0130             0.0123
# min        2771966.4013       3293292.4323       3238978.4555       3268596.3662
# max        4459679.7074       3514091.4864       3583427.8432       3589707.0386
# wacc       0.0606             0.0579             0.0581             0.0581
# -----------------------------------
# Revenue Statistics for Offshore Wind (Floating), Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       3508331.9738       3504920.3151       3505527.9858       3505655.4097
# median     3490754.2506       3505617.6730       3501921.0765       3502820.2553
# std_dev    221432.0711        27236.2191         55125.3587         56433.9245
# risk       0.0631             0.0078             0.0157             0.0161
# min        2890321.4810       3390596.0937       3344853.7221       3293896.9742
# max        4665614.8173       3604630.5707       3744415.2056       3740320.5226
# wacc       0.0606             0.0579             0.0583             0.0583
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1499889.3596       1500206.3392       1499020.1536       1499160.9428
# median     1496640.4418       1500963.0346       1505107.5891       1505243.4860
# std_dev    79214.2839         33618.6844         167415.8193        138235.8749
# risk       0.0528             0.0224             0.1117             0.0922
# min        1203057.7711       1380539.8114       844373.6852        934471.9043
# max        1819433.9445       1620195.8427       2066828.5573       1970974.1252
# wacc       0.0548             0.0537             0.0570             0.0563
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2500967.1784       2501742.1837       2500097.9724       2500238.7617
# median     2496332.2458       2504100.3615       2501920.5657       2500484.9184
# std_dev    128530.5268        62586.8138         149341.6447        126584.5201
# risk       0.0514             0.0250             0.0597             0.0506
# min        2023571.6556       2281268.8462       1940662.7561       2001166.8291
# max        3016441.0250       2731181.7622       3080464.5053       3030447.3187
# wacc       0.0548             0.0538             0.0551             0.0547
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2682246.6387       2683011.8259       2681377.4327       2681518.2219
# median     2677999.4548       2684308.6578       2681459.9041       2680608.5107
# std_dev    139861.1647        61004.3413         134022.6868        113070.8833
# risk       0.0521             0.0227             0.0500             0.0422
# min        2151764.3654       2467157.5414       2175369.4129       2247420.1019
# max        3244995.0233       2904673.8858       3220015.5765       3169998.3898
# wacc       0.0548             0.0537             0.0547             0.0544
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2746828.1232       2747351.0514       2745958.9172       2746099.7064
# median     2741907.4621       2748229.2768       2745854.2479       2745858.9304
# std_dev    141219.5456        56950.1041         122836.9504        100478.7913
# risk       0.0514             0.0207             0.0447             0.0366
# min        2212822.7428       2540363.5005       2297072.7675       2376329.6721
# max        3320167.7043       2952805.7670       3217955.1726       3167937.9860
# wacc       0.0548             0.0536             0.0545             0.0542
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 4:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2676719.2777       2677030.2195       2675850.0717       2675990.8610
# median     2673025.7732       2677774.5366       2677002.8288       2677034.0250
# std_dev    127972.4488        53246.1973         117691.1705        89390.0401
# risk       0.0478             0.0199             0.0440             0.0334
# min        2218907.3717       2486786.2551       2225438.1141       2337740.7298
# max        3197869.6466       2878938.1721       3092512.8638       3039664.3571
# wacc       0.0546             0.0536             0.0545             0.0541
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 5:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2574027.6326       2574088.5918       2573158.4266       2573299.2159
# median     2569094.8602       2574808.9041       2574747.0342       2575909.6296
# std_dev    118354.3840        49517.8749         115814.0055        83921.4820
# risk       0.0460             0.0192             0.0450             0.0326
# min        2183638.7171       2395551.8144       2140007.8165       2247589.1745
# max        3060319.0345       2768676.7647       2935226.2349       2880119.9786
# wacc       0.0546             0.0536             0.0545             0.0541
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 6:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2696739.8184       2696678.0375       2695870.6124       2696011.4017
# median     2691258.6848       2696987.0190       2697031.5335       2699057.9040
# std_dev    125060.2121        46075.2197         100712.5431        68602.5997
# risk       0.0464             0.0171             0.0374             0.0254
# min        2267989.6843       2529931.2745       2308828.1370       2408807.2140
# max        3182976.8100       2875469.2284       3050708.4774       2924881.8177
# wacc       0.0546             0.0535             0.0542             0.0538
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 7:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2767189.9771       2767019.0245       2766320.7711       2766461.5604
# median     2762019.2625       2766955.8655       2768016.0263       2769590.9583
# std_dev    131700.2661        43345.4634         94761.3795         64999.6448
# risk       0.0476             0.0157             0.0343             0.0235
# min        2309851.0300       2613469.7581       2381254.3833       2492804.4320
# max        3271117.0638       2930157.4959       3114722.1646       2988895.5050
# wacc       0.0546             0.0535             0.0541             0.0537
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 8:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2962857.2589       2962420.5481       2961988.0529       2962128.8421
# median     2955588.4480       2962133.1666       2962451.6715       2964459.6574
# std_dev    143985.6025        40949.5844         76816.9993         43411.8053
# risk       0.0486             0.0138             0.0259             0.0147
# min        2490593.1722       2825561.8095       2672679.6248       2784229.6736
# max        3539058.4802       3123822.0235       3232383.1561       3106556.4965
# wacc       0.0547             0.0534             0.0538             0.0534
# -----------------------------------
# Revenue Statistics for Onshore Wind, Resource Class 9:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       3784107.0518       3783031.3816       3783237.8458       3783378.6351
# median     3773431.1781       3783302.8818       3783878.0922       3782296.2153
# std_dev    200715.4489        44122.1336         34301.2178         20606.6766
# risk       0.0530             0.0117             0.0091             0.0054
# min        3149785.0897       3614697.4167       3649710.3552       3714955.8740
# max        4620975.0165       3953949.8619       3906043.3787       3867724.7523
# wacc       0.0548             0.0533             0.0532             0.0531
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1485796.6307       1485527.3388       1485382.9216       1485278.4176
# median     1483439.6568       1485776.5143       1485970.0385       1485393.6877
# std_dev    55368.7014         12398.1804         18150.6127         17167.6964
# risk       0.0373             0.0083             0.0122             0.0116
# min        1311142.3059       1437951.8966       1411767.8441       1423607.1477
# max        1724167.5313       1531623.4699       1548590.9153       1549010.6595
# wacc       0.0497             0.0488             0.0490             0.0489
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1504050.9117       1503797.6335       1503637.2027       1503532.6986
# median     1502369.8724       1503974.9687       1504067.3006       1503602.1761
# std_dev    55963.7306         12455.2719         15806.0473         13612.4282
# risk       0.0372             0.0083             0.0105             0.0091
# min        1327938.9558       1456091.5169       1438961.7396       1454139.3098
# max        1741912.9890       1550240.2440       1562769.1975       1557814.6834
# wacc       0.0497             0.0488             0.0489             0.0489
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1505247.3162       1504977.6688       1504833.6071       1504729.1031
# median     1503149.7954       1505086.9498       1504966.7289       1504748.7540
# std_dev    55299.6008         12253.5485         13969.5990         12713.4745
# risk       0.0367             0.0081             0.0093             0.0084
# min        1328906.5342       1458224.6187       1443943.4898       1455682.7080
# max        1746038.0674       1550150.5286       1559021.7438       1554067.2297
# wacc       0.0497             0.0488             0.0489             0.0488
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1521196.2427       1520909.1102       1520782.5337       1520678.0297
# median     1519215.9683       1521130.1874       1520862.0829       1520660.1726
# std_dev    56518.6573         12342.9482         12635.1923         9542.6127
# risk       0.0372             0.0081             0.0083             0.0063
# min        1342635.0979       1474463.1575       1465705.3607       1482867.0574
# max        1763980.0175       1565080.7799       1565453.1957       1557294.3155
# wacc       0.0497             0.0488             0.0488             0.0488
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 4:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1525157.2761       1524839.3913       1524743.5670       1524639.0630
# median     1523722.3441       1524996.4822       1524867.3176       1524560.5351
# std_dev    57346.1694         12354.5124         12559.4531         6306.4200
# risk       0.0376             0.0081             0.0082             0.0041
# min        1340862.4244       1478535.7162       1479413.3788       1500714.5418
# max        1764265.0259       1570861.8190       1576684.4958       1548990.5948
# wacc       0.0497             0.0488             0.0488             0.0487
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 5:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1532669.7875       1532303.5950       1532256.0784       1532151.5744
# median     1530857.7567       1532298.0409       1532368.4332       1532199.3379
# std_dev    57496.5969         12023.0085         10926.6686         5347.3400
# risk       0.0375             0.0078             0.0071             0.0035
# min        1351420.3566       1486543.9135       1493999.5994       1511427.9794
# max        1775541.5663       1580828.3052       1577562.9859       1554206.6840
# wacc       0.0497             0.0488             0.0488             0.0487
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 6:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1570865.8571       1570481.8905       1570452.1480       1570347.6440
# median     1569283.5875       1570579.7903       1570069.4831       1570068.1900
# std_dev    61693.4567         13103.9111         14016.7299         5140.9465
# risk       0.0393             0.0083             0.0089             0.0033
# min        1372408.5605       1522256.5859       1519550.9232       1554608.9991
# max        1825094.2707       1614911.6133       1625407.0029       1592652.0632
# wacc       0.0497             0.0488             0.0489             0.0487
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 7:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1618368.1866       1617962.9335       1617954.4775       1617849.9735
# median     1616637.7155       1617893.1136       1616457.2789       1616629.1430
# std_dev    64499.2103         13295.7387         19797.8912         12459.5180
# risk       0.0399             0.0082             0.0122             0.0077
# min        1410473.2767       1566867.6539       1558901.3234       1581742.5852
# max        1907543.2791       1666902.0804       1707443.2600       1675896.5526
# wacc       0.0498             0.0488             0.0490             0.0488
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 8:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1708361.1491       1707840.7997       1707947.4401       1707842.9361
# median     1706904.4217       1707577.5173       1707612.2445       1707767.4028
# std_dev    65215.0771         9972.2387          17242.7414         10811.5140
# risk       0.0382             0.0058             0.0101             0.0063
# min        1486865.6178       1672981.8996       1645265.3960       1663456.8934
# max        1991102.1542       1744759.9271       1776177.3126       1749584.5562
# wacc       0.0497             0.0488             0.0489             0.0488
# -----------------------------------
# Revenue Statistics for Ground-Mounted Solar PV, Resource Class 9:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1868607.0590       1867894.6143       1868193.3499       1868088.8459
# median     1866452.0430       1867750.7175       1867685.9520       1867560.8767
# std_dev    73283.0479         11355.9902         24157.6642         18630.3877
# risk       0.0392             0.0061             0.0129             0.0100
# min        1621459.3486       1827721.3586       1785136.8274       1802761.1990
# max        2169873.1808       1912654.5556       1961129.8146       1943909.2392
# wacc       0.0497             0.0488             0.0490             0.0489
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 0:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1749257.0863       1749093.5930       1748791.1009       1748669.6533
# median     1745987.0752       1749536.6770       1749357.9968       1748902.3466
# std_dev    62962.6324         19287.1939         23431.5759         22900.0907
# risk       0.0360             0.0110             0.0134             0.0131
# min        1550929.4780       1676858.7138       1648002.0821       1664026.2238
# max        2017941.0088       1815699.1297       1836457.9823       1832839.6852
# wacc       0.0496             0.0489             0.0490             0.0490
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 1:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1752212.5513       1752047.2740       1751746.5658       1751625.1182
# median     1749747.3909       1752418.8912       1752025.5122       1751747.7681
# std_dev    61435.6368         19259.5112         20506.1093         19907.9039
# risk       0.0351             0.0110             0.0117             0.0114
# min        1557083.6315       1679774.9404       1664322.8452       1675658.8620
# max        2014461.5455       1819211.4980       1832856.9465       1827471.7478
# wacc       0.0496             0.0489             0.0489             0.0489
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 2:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1768465.7037       1768262.5558       1767999.7183       1767878.2707
# median     1766115.5064       1768581.7465       1767977.2126       1768037.9539
# std_dev    60911.3834         18882.8855         19740.0076         20220.9063
# risk       0.0344             0.0107             0.0112             0.0114
# min        1572759.5760       1697651.0692       1683891.3005       1683658.0397
# max        2034296.7887       1834267.3918       1845081.7608       1839696.5621
# wacc       0.0496             0.0489             0.0489             0.0489
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 3:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1780668.3456       1780452.0726       1780202.3602       1780080.9126
# median     1778350.8504       1780661.2925       1780283.5150       1780187.6941
# std_dev    61372.5563         18249.3358         18011.0150         17801.9496
# risk       0.0345             0.0102             0.0101             0.0100
# min        1583949.6909       1713611.4762       1702399.2546       1707210.3359
# max        2046961.7355       1843719.5653       1845988.1601       1840394.6532
# wacc       0.0496             0.0489             0.0489             0.0489
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 4:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1779319.1165       1779056.9097       1778853.1311       1778731.6834
# median     1777557.3204       1779251.6597       1778777.9780       1778880.4097
# std_dev    61820.6587         18124.0456         16247.2411         14446.8645
# risk       0.0347             0.0102             0.0091             0.0081
# min        1579661.2600       1711076.8879       1714569.0599       1718385.2816
# max        2042141.9301       1847468.4275       1842915.5725       1835102.2978
# wacc       0.0496             0.0489             0.0489             0.0488
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 5:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1774416.4861       1774100.9238       1773950.5007       1773829.0531
# median     1772253.5687       1774287.2427       1773806.4723       1774026.4749
# std_dev    62601.1934         18156.5674         15006.1716         13598.1064
# risk       0.0353             0.0102             0.0085             0.0077
# min        1575899.5561       1703862.7593       1720238.1685       1718080.6165
# max        2040330.1875       1845760.9791       1835859.2476       1827307.4123
# wacc       0.0496             0.0489             0.0488             0.0488
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 6:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1840858.3978       1840534.6716       1840392.4123       1840270.9647
# median     1838874.6841       1840773.3371       1840337.7650       1840292.1271
# std_dev    67001.5869         18285.3316         15074.8383         8009.1170
# risk       0.0364             0.0099             0.0082             0.0044
# min        1626292.7196       1774711.3232       1784847.5964       1809721.7032
# max        2112203.9852       1906379.2232       1898899.2977       1869170.4331
# wacc       0.0497             0.0489             0.0488             0.0487
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 7:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1875148.8188       1874756.0776       1874682.8334       1874561.3858
# median     1873540.6899       1874720.8390       1873474.2991       1874292.0518
# std_dev    69538.3958         15614.1245         18829.6282         9902.0353
# risk       0.0371             0.0083             0.0100             0.0053
# min        1651202.6328       1820896.6436       1816407.6576       1835676.0387
# max        2172952.6870       1930671.4707       1955136.1571       1920863.1134
# wacc       0.0497             0.0488             0.0489             0.0488
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 8:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       1956826.7918       1956342.7386       1956360.8064       1956239.3588
# median     1955436.8238       1956162.8639       1956038.5294       1956610.4380
# std_dev    69882.9177         13991.3747         15528.6890         8194.2841
# risk       0.0357             0.0072             0.0079             0.0042
# min        1716742.8428       1907425.0552       1898810.0078       1923214.8958
# max        2251120.5739       2011260.7760       2017701.5183       1983326.2834
# wacc       0.0496             0.0488             0.0488             0.0487
# -----------------------------------
# Revenue Statistics for Rotating Solar PV, Resource Class 9:
# Statistic  Market (€)         PB CfD (€)         PI CfD (€)         CB CfD (€)
# mean       2150183.8824       2149458.2750       2149717.8970       2149596.4493
# median     2148227.1537       2149040.1306       2149283.8510       2149169.8679
# std_dev    79065.6837         12441.8361         22858.3399         14509.4829
# risk       0.0368             0.0058             0.0106             0.0067
# min        1877919.0416       2107766.5981       2068372.9785       2097005.7672
# max        2473266.4480       2198443.3813       2239858.5512       2212677.5382
# wacc       0.0497             0.0488             0.0489             0.0488
# -----------------------------------

# %%
importlib.reload(af)

for carrier in ['offwind-ac', 'offwind-dc', 'offwind-float', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        for scenario in ['mb', 'pb', 'pi', 'cb']:    
            wacc = af.wacc_updated(run_name, n, carrier, rc, scenario=scenario)
            print(f"Updated WACC for {carrier}, rc {rc}, scenario {scenario}: {wacc}")
        print('-----------------------------------')
# Out:
# Updated WACC for offwind-ac, rc 0, scenario mb: 0.05940382408364282
# Updated WACC for offwind-ac, rc 0, scenario pb: 0.05782234821434075
# Updated WACC for offwind-ac, rc 0, scenario pi: 0.05839503187505346
# Updated WACC for offwind-ac, rc 0, scenario cb: 0.058144345757404514
# -----------------------------------
# Updated WACC for offwind-ac, rc 1, scenario mb: 0.05930245223181247
# Updated WACC for offwind-ac, rc 1, scenario pb: 0.05779853731830252
# Updated WACC for offwind-ac, rc 1, scenario pi: 0.05783360850281061
# Updated WACC for offwind-ac, rc 1, scenario cb: 0.05757851131529593
# -----------------------------------
# Updated WACC for offwind-ac, rc 2, scenario mb: 0.05923844489673278
# Updated WACC for offwind-ac, rc 2, scenario pb: 0.0577129334636581
# Updated WACC for offwind-ac, rc 2, scenario pi: 0.05773008872196772
# Updated WACC for offwind-ac, rc 2, scenario cb: 0.057725546780625865
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-ac, rc 3, scenario cb: 0.07
# -----------------------------------
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario mb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pb: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario pi: 0.07
# c:\Users\justu\Documents\PhD\RE Financing\Code\CfDs_cost_of_capital\analysis\analysis_functions.py:1364: RuntimeWarning:
#
# The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
# Updated WACC for offwind-dc, rc 0, scenario cb: 0.07
# -----------------------------------
# Updated WACC for offwind-dc, rc 1, scenario mb: 0.05921823797478217
# Updated WACC for offwind-dc, rc 1, scenario pb: 0.05774181876326734
# Updated WACC for offwind-dc, rc 1, scenario pi: 0.05812710730105617
# Updated WACC for offwind-dc, rc 1, scenario cb: 0.05814695087501352
# -----------------------------------
# Updated WACC for offwind-dc, rc 2, scenario mb: 0.05923459170399243
# Updated WACC for offwind-dc, rc 2, scenario pb: 0.05775930118124347
# Updated WACC for offwind-dc, rc 2, scenario pi: 0.05782515952703946
# Updated WACC for offwind-dc, rc 2, scenario cb: 0.05768806684970548
# -----------------------------------
# Updated WACC for offwind-dc, rc 3, scenario mb: 0.0592398742921241
# Updated WACC for offwind-dc, rc 3, scenario pb: 0.05774870334422279
# Updated WACC for offwind-dc, rc 3, scenario pi: 0.05774818830254947
# Updated WACC for offwind-dc, rc 3, scenario cb: 0.05755185921835331
# -----------------------------------
# Updated WACC for offwind-float, rc 0, scenario mb: 0.06107822040833082
# Updated WACC for offwind-float, rc 0, scenario pb: 0.058175779439103244
# Updated WACC for offwind-float, rc 0, scenario pi: 0.06063406924422079
# Updated WACC for offwind-float, rc 0, scenario cb: 0.06029868433905222
# -----------------------------------
# Updated WACC for offwind-float, rc 1, scenario mb: 0.060817822583153255
# Updated WACC for offwind-float, rc 1, scenario pb: 0.05806855260836813
# Updated WACC for offwind-float, rc 1, scenario pi: 0.058392038644333
# Updated WACC for offwind-float, rc 1, scenario cb: 0.05806370739116604
# -----------------------------------
# Updated WACC for offwind-float, rc 2, scenario mb: 0.06060525757724595
# Updated WACC for offwind-float, rc 2, scenario pb: 0.0579322739308907
# Updated WACC for offwind-float, rc 2, scenario pi: 0.058133270424666726
# Updated WACC for offwind-float, rc 2, scenario cb: 0.0581017571044316
# -----------------------------------
# Updated WACC for offwind-float, rc 3, scenario mb: 0.06062807836555078
# Updated WACC for offwind-float, rc 3, scenario pb: 0.057878643970736686
# Updated WACC for offwind-float, rc 3, scenario pi: 0.058268098090914135
# Updated WACC for offwind-float, rc 3, scenario cb: 0.05828639229161309
# -----------------------------------
# Updated WACC for onwind, rc 0, scenario mb: 0.054813998106799836
# Updated WACC for onwind, rc 0, scenario pb: 0.05370441254437106
# Updated WACC for onwind, rc 0, scenario pi: 0.05702360662004502
# Updated WACC for onwind, rc 0, scenario cb: 0.05628357158027885
# -----------------------------------
# Updated WACC for onwind, rc 1, scenario mb: 0.054761663493631235
# Updated WACC for onwind, rc 1, scenario pb: 0.05379876140679757
# Updated WACC for onwind, rc 1, scenario pi: 0.055069542880071924
# Updated WACC for onwind, rc 1, scenario cb: 0.05473357056907557
# -----------------------------------
# Updated WACC for onwind, rc 2, scenario mb: 0.054789313421530664
# Updated WACC for onwind, rc 2, scenario pb: 0.053716266359485794
# Updated WACC for onwind, rc 2, scenario pi: 0.05470979981674131
# Updated WACC for onwind, rc 2, scenario cb: 0.054423043739302186
# -----------------------------------
# Updated WACC for onwind, rc 3, scenario mb: 0.054762382502339176
# Updated WACC for onwind, rc 3, scenario pb: 0.053643705222761205
# Updated WACC for onwind, rc 3, scenario pi: 0.05451706651517331
# Updated WACC for onwind, rc 3, scenario cb: 0.054219287139565225
# -----------------------------------
# Updated WACC for onwind, rc 4, scenario mb: 0.05462992297198704
# Updated WACC for onwind, rc 4, scenario pb: 0.053613414005733995
# Updated WACC for onwind, rc 4, scenario pi: 0.054489543536521724
# Updated WACC for onwind, rc 4, scenario cb: 0.054103237499133
# -----------------------------------
# Updated WACC for onwind, rc 5, scenario mb: 0.054562778181141955
# Updated WACC for onwind, rc 5, scenario pb: 0.05358985209683938
# Updated WACC for onwind, rc 5, scenario pi: 0.05452714023220604
# Updated WACC for onwind, rc 5, scenario cb: 0.05407441537277559
# -----------------------------------
# Updated WACC for onwind, rc 6, scenario mb: 0.054577247541819154
# Updated WACC for onwind, rc 6, scenario pb: 0.05351229854939
# Updated WACC for onwind, rc 6, scenario pi: 0.05424731943980251
# Updated WACC for onwind, rc 6, scenario cb: 0.053814284464419854
# -----------------------------------
# Updated WACC for onwind, rc 7, scenario mb: 0.05462199259574318
# Updated WACC for onwind, rc 7, scenario pb: 0.053461129662921464
# Updated WACC for onwind, rc 7, scenario pi: 0.05413421753100585
# Updated WACC for onwind, rc 7, scenario cb: 0.05374369078342024
# -----------------------------------
# Updated WACC for onwind, rc 8, scenario mb: 0.054658851070850153
# Updated WACC for onwind, rc 8, scenario pb: 0.05339486201703414
# Updated WACC for onwind, rc 8, scenario pi: 0.053831972333984866
# Updated WACC for onwind, rc 8, scenario cb: 0.05342480552926893
# -----------------------------------
# Updated WACC for onwind, rc 9, scenario mb: 0.05482240920081688
# Updated WACC for onwind, rc 9, scenario pb: 0.05331725773822111
# Updated WACC for onwind, rc 9, scenario pi: 0.0532241014904906
# Updated WACC for onwind, rc 9, scenario cb: 0.05309447859102966
# -----------------------------------
# Updated WACC for solar, rc 0, scenario mb: 0.04968604055984391
# Updated WACC for solar, rc 0, scenario pb: 0.04884098612490892
# Updated WACC for solar, rc 0, scenario pi: 0.0489532691670666
# Updated WACC for solar, rc 0, scenario cb: 0.04893409131119367
# -----------------------------------
# Updated WACC for solar, rc 1, scenario mb: 0.04968436948662479
# Updated WACC for solar, rc 1, scenario pb: 0.04883914964563519
# Updated WACC for solar, rc 1, scenario pi: 0.0489037356767816
# Updated WACC for solar, rc 1, scenario cb: 0.04886147835574107
# -----------------------------------
# Updated WACC for solar, rc 2, scenario mb: 0.04967048749140085
# Updated WACC for solar, rc 2, scenario pb: 0.04883508137723941
# Updated WACC for solar, rc 2, scenario pi: 0.048868126882666243
# Updated WACC for solar, rc 2, scenario cb: 0.0488439691881853
# -----------------------------------
# Updated WACC for solar, rc 3, scenario mb: 0.04968275984632379
# Updated WACC for solar, rc 3, scenario pb: 0.048834314072078146
# Updated WACC for solar, rc 3, scenario pi: 0.048839896685530154
# Updated WACC for solar, rc 3, scenario cb: 0.048781074470224214
# -----------------------------------
# Updated WACC for solar, rc 4, scenario mb: 0.04969591682632597
# Updated WACC for solar, rc 4, scenario pb: 0.04883392809362085
# Updated WACC for solar, rc 4, scenario pi: 0.04883783377540511
# Updated WACC for solar, rc 4, scenario cb: 0.04871927410078366
# -----------------------------------
# Updated WACC for solar, rc 5, scenario mb: 0.049693375481605885
# Updated WACC for solar, rc 5, scenario pb: 0.0488265237197236
# Updated WACC for solar, rc 5, scenario pi: 0.04880582704743227
# Updated WACC for solar, rc 5, scenario cb: 0.048700618233170886
# -----------------------------------
# Updated WACC for solar, rc 6, scenario mb: 0.049745305703304266
# Updated WACC for solar, rc 6, scenario pb: 0.04884092532172149
# Updated WACC for solar, rc 6, scenario pi: 0.048857760988457684
# Updated WACC for solar, rc 6, scenario cb: 0.04869437519942156
# -----------------------------------
# Updated WACC for solar, rc 7, scenario mb: 0.0497624642339409
# Updated WACC for solar, rc 7, scenario pb: 0.048837268893842885
# Updated WACC for solar, rc 7, scenario pi: 0.048953759288552966
# Updated WACC for solar, rc 7, scenario cb: 0.04882232494801911
# -----------------------------------
# Updated WACC for solar, rc 8, scenario mb: 0.049712849017856046
# Updated WACC for solar, rc 8, scenario pb: 0.04876846587037327
# Updated WACC for solar, rc 8, scenario pi: 0.04889166853075732
# Updated WACC for solar, rc 8, scenario cb: 0.04878267261960325
# -----------------------------------
# Updated WACC for solar, rc 9, scenario mb: 0.04974366598615229
# Updated WACC for solar, rc 9, scenario pb: 0.048775417400583526
# Updated WACC for solar, rc 9, scenario pi: 0.04897392532644889
# Updated WACC for solar, rc 9, scenario cb: 0.048888114482711
# -----------------------------------
# Updated WACC for solar-hsat, rc 0, scenario mb: 0.04964855901025867
# Updated WACC for solar-hsat, rc 0, scenario pb: 0.04891867145033609
# Updated WACC for solar-hsat, rc 0, scenario pi: 0.04898750769825857
# Updated WACC for solar-hsat, rc 0, scenario cb: 0.0489787076544356
# -----------------------------------
# Updated WACC for solar-hsat, rc 1, scenario mb: 0.04962109735171163
# Updated WACC for solar-hsat, rc 1, scenario pb: 0.0489176741101682
# Updated WACC for solar-hsat, rc 1, scenario pi: 0.04893837130019858
# Updated WACC for solar-hsat, rc 1, scenario cb: 0.04892848727870869
# -----------------------------------
# Updated WACC for solar-hsat, rc 2, scenario mb: 0.04960288025216024
# Updated WACC for solar-hsat, rc 2, scenario pb: 0.04890857475424743
# Updated WACC for solar-hsat, rc 2, scenario pi: 0.04892267958187555
# Updated WACC for solar-hsat, rc 2, scenario cb: 0.04893059213977408
# -----------------------------------
# Updated WACC for solar-hsat, rc 3, scenario mb: 0.049603556054287186
# Updated WACC for solar-hsat, rc 3, scenario pb: 0.048896139243186115
# Updated WACC for solar-hsat, rc 3, scenario pi: 0.04889230053146488
# Updated WACC for solar-hsat, rc 3, scenario cb: 0.048888916531853746
# -----------------------------------
# Updated WACC for solar-hsat, rc 4, scenario mb: 0.04961174024178045
# Updated WACC for solar-hsat, rc 4, scenario pb: 0.04889433087754643
# Updated WACC for solar-hsat, rc 4, scenario pi: 0.0488637932347872
# Updated WACC for solar-hsat, rc 4, scenario cb: 0.048834502127285705
# -----------------------------------
# Updated WACC for solar-hsat, rc 5, scenario mb: 0.049627521824150506
# Updated WACC for solar-hsat, rc 5, scenario pb: 0.04889568714493586
# Updated WACC for solar-hsat, rc 5, scenario pi: 0.048844263664853504
# Updated WACC for solar-hsat, rc 5, scenario cb: 0.04882130283074296
# -----------------------------------
# Updated WACC for solar-hsat, rc 6, scenario mb: 0.04966043629791244
# Updated WACC for solar-hsat, rc 6, scenario pb: 0.0488870081699451
# Updated WACC for solar-hsat, rc 6, scenario pi: 0.0488365023455116
# Updated WACC for solar-hsat, rc 6, scenario cb: 0.04872550560441003
# -----------------------------------
# Updated WACC for solar-hsat, rc 7, scenario mb: 0.04968069893405489
# Updated WACC for solar-hsat, rc 7, scenario pb: 0.04884048344814128
# Updated WACC for solar-hsat, rc 7, scenario pi: 0.048890178050003806
# Updated WACC for solar-hsat, rc 7, scenario cb: 0.04875237515689002
# -----------------------------------
# Updated WACC for solar-hsat, rc 8, scenario mb: 0.04964026262541097
# Updated WACC for solar-hsat, rc 8, scenario pb: 0.04880642597674643
# Updated WACC for solar-hsat, rc 8, scenario pi: 0.0488291626580178
# Updated WACC for solar-hsat, rc 8, scenario cb: 0.048720788784079656
# -----------------------------------
# Updated WACC for solar-hsat, rc 9, scenario mb: 0.04967148129830132
# Updated WACC for solar-hsat, rc 9, scenario pb: 0.048766999458562534
# Updated WACC for solar-hsat, rc 9, scenario pi: 0.048907252666306904
# Updated WACC for solar-hsat, rc 9, scenario cb: 0.04879479961472936
# -----------------------------------

# %%
importlib.reload(af)

af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='offwind-dc', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='onwind', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar-hsat', N=10000)
af.lifetime_revenue_mcs_dist_plot(run_name, scenario, carrier='solar', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_offwind-dc_cb.png
# --- Goodness of Fit Results for Offshore Wind (DC) ---
# Normal:     KS Stat = 0.1528, p-value = 0.0000e+00
# Log-Normal: KS Stat = 0.1477, p-value = 0.0000e+00
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_onwind_cb.png
# --- Goodness of Fit Results for Onshore Wind ---
# Normal:     KS Stat = 0.1114, p-value = 0.0000e+00
# Log-Normal: KS Stat = 0.1114, p-value = 0.0000e+00
# -> The Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_solar-hsat_cb.png
# --- Goodness of Fit Results for Rotating Solar PV ---
# Normal:     KS Stat = 0.0562, p-value = 4.9436e-275
# Log-Normal: KS Stat = 0.0529, p-value = 2.9866e-243
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_v3/my_plots/norm_revenue_dist_MCS_solar_cb.png
# --- Goodness of Fit Results for Ground-Mounted Solar PV ---
# Normal:     KS Stat = 0.0260, p-value = 3.5210e-59
# Log-Normal: KS Stat = 0.0256, p-value = 3.1450e-57
# -> The Log-Normal distribution fits the data best (lowest KS statistic).
#        0         1         2         3         4         5         6     \
# 0  1.007800  0.997717  0.992723  0.989009  1.006537  0.997956  0.992339
# 1  1.002768  1.004985  0.999457  0.992727  1.002856  0.996990  0.995065
# 2  1.004462  1.006946  0.998426  0.991272  1.004070  0.998730  0.992587
# 3  1.004055  1.006942  1.001396  0.993219  1.002625  0.997737  0.993526
# 4  1.002313  1.005649  1.002583  0.996365  1.000165  0.997636  0.996591
# 5  1.003603  1.001697  0.999063  0.995395  1.001461  0.998976  0.996159
# 6  1.002859  0.999740  1.002503  1.001837  0.999372  0.996674  1.000520
# 7  0.990869  0.998450  1.005644  1.013281  0.998901  0.994638  1.010587
# 8  0.992837  0.999270  0.999611  1.007513  0.999386  1.003292  1.004555
# 9  1.005894  0.985452  0.993458  0.994853  0.991798  1.012771  1.000027
#
#        7         8         9     ...      9990      9991      9992      9993  \
# 0  0.995956  1.003562  1.002297  ...  0.993268  0.990342  1.001752  1.002791
# 1  0.996124  1.000668  1.003914  ...  0.991800  0.989384  0.998817  1.001142
# 2  0.997195  1.001662  1.004831  ...  0.990002  0.992428  0.996667  1.001276
# 3  1.000793  1.000574  1.005018  ...  0.990803  0.992521  0.996112  1.001833
# 4  1.004346  1.000848  1.003595  ...  0.993694  0.994358  0.997168  1.002501
# 5  1.005708  1.003072  1.002460  ...  0.997043  0.999325  0.997737  1.000559
# 6  1.008360  1.001768  1.001277  ...  1.002353  0.999262  0.999908  1.000240
# 7  0.997581  1.000837  0.998178  ...  1.009214  1.002631  1.004182  0.997022
# 8  0.994213  0.996915  0.995017  ...  1.004935  1.007792  1.002100  0.999970
# 9  1.003746  0.995830  0.994507  ...  1.006588  1.010883  0.999909  0.996924
#
#        9994      9995      9996      9997      9998      9999
# 0  1.001630  0.988652  1.005961  1.000597  1.010285  1.008607
# 1  0.998689  0.992003  1.000719  1.002965  1.005100  1.007878
# 2  1.000517  0.995223  1.001992  1.005829  1.006762  1.007976
# 3  0.999769  0.997147  1.001899  1.004505  1.004834  1.006655
# 4  0.998616  0.999355  1.002252  1.001692  1.003678  1.005690
# 5  1.000909  1.001204  1.003063  1.001829  1.005013  1.004003
# 6  1.000104  0.999536  1.002587  0.996558  0.998875  1.001157
# 7  0.996828  1.000173  0.997538  0.993947  0.990348  0.996392
# 8  0.998905  1.003246  0.995264  1.000296  0.995521  0.991947
# 9  1.006390  1.010401  0.998890  0.998287  0.998325  0.990497
#
# [10 rows x 10000 columns]

# %%
importlib.reload(af)
af.plot_roi_per_rc(run_name, carrier='offwind-ac', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-dc', N=10000)
af.plot_roi_per_rc(run_name, carrier='offwind-float', N=10000)
af.plot_roi_per_rc(run_name, carrier='onwind', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar', N=10000)
af.plot_roi_per_rc(run_name, carrier='solar-hsat', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-ac.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-dc.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_offwind-float.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_onwind.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.1.2 available! (Current: 0.35.2)
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/1_Iteration_One/my_plots/expected_roi_per_resource_class_solar-hsat.png

# %%
importlib.reload(af)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-ac', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-dc', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='offwind-float', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='onwind', N=10000)
af.plot_lifetime_risk_per_rc(run_name, carrier='solar', N=10000)
# af.plot_lifetime_risk_per_rc(run_name, carrier='solar-hsat', N=10000)
# Out:
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-ac.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-dc.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_offwind-float.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# WARNING:pypsa.network.io:Importing network from PyPSA version v0.0.0 while current version is v0.35.2. Read the release notes at https://pypsa.readthedocs.io/en/latest/release_notes.html to prepare your network for import.
# INFO:pypsa.network.io:New version 1.0.7 available! (Current: 0.35.2)
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_onwind.png
# INFO:pypsa.network.io:Imported network 'Unnamed Network' has buses, carriers, generators, loads, storage_units
# Plot saved to ../results/0_Iteration_Zero_v2/my_plots/lifetime_risk_per_resource_class_solar.png

# %%
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 9
t = 30
print(af.risk_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, N=10000))
print(af.annual_revenue_risk(costs, carrier, n, rc) * (t) ** (-1/2))
# Out:
# 0.0765013543433343
# 0.04652417971471111

# %%
import importlib
importlib.reload(af)
rc=0
print(af.avg_lifetime_revenues_mcs_per_MW(run_name, n, 'onwind', rc, T=20, N=1000))
af.expected_roi_mcs(run_name, n, 'offwind-float', rc, T=20, N=1000)

# investment costs for onwind should be 1.095.853,3 EUR/kW
# Out:
# 852825.5975128612
# Calculated Offshore costs for offwind-float rc 0: Dist 57.9km, Total Life Cost 3428978
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-float: 3428977.84969747 €/MW
# -0.005682683084719589

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-ac'
af.annual_revenue_per_MW(run_name, carrier, 2000, n, 2)
# Out:
# 188911.77180655298

# %%
import importlib
importlib.reload(af)

print(af.wacc_cagr_simplified(f_cagr=0.02, T=30, sigma=0.0))
print(af.wacc_cagr_simplified(f_cagr=0.02, T=30, sigma=0.1))

print(af.wacc_irr_simplified(f_irr=0.05, T=30, sigma=0.0))
print(af.wacc_irr_simplified(f_irr=0.05, T=30, sigma=0.1))
# Out:
# 0.02
# 0.021356483826980494
# 0.05000000000000002
# 0.05361088228911649

# %%
importlib.reload(af)

#Plot debt CAGR vs. sigma
af.plot_wacc_vs_volatility()
# Out:
# Plot saved to ../results/my_plots/wacc_vs_volatility.png

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'solar-hsat'
t = 40
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 0: 1748970.213923753 €/MW
# Expected ROI for solar-hsat, rc 0: 2.6900736466845165%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 1: 1747292.8817136388 €/MW
# Expected ROI for solar-hsat, rc 1: 2.6869258018119977%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 2: 1773351.9050013581 €/MW
# Expected ROI for solar-hsat, rc 2: 2.735388722086028%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 3: 1779852.0020296462 €/MW
# Expected ROI for solar-hsat, rc 3: 2.747332200793607%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 4 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 4: 1773669.7170508187 €/MW
# Expected ROI for solar-hsat, rc 4: 2.735974008349114%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 5 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 5: 1767959.5623151467 €/MW
# Expected ROI for solar-hsat, rc 5: 2.725437179912821%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 6 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 6: 1787068.8234304534 €/MW
# Expected ROI for solar-hsat, rc 6: 2.7605261090873774%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 7 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 7: 1812151.8988997932 €/MW
# Expected ROI for solar-hsat, rc 7: 2.8058492623598474%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 8 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 8: 1904299.2069967273 €/MW
# Expected ROI for solar-hsat, rc 8: 2.9656351676055173%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 9 solar-hsat: 870474.2338080001 €/MW
# Annualized investment + capital costs: 1779580.9676732535 €/MW
# Average lifetime revenue per MW for solar-hsat: 1881864.9059451288 €/MW
# Average lifetime revenues per MW for solar-hsat, rc 9: 2077725.7236586795 €/MW
# Expected ROI for solar-hsat, rc 9: 3.241192504151501%

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 0: 1401563.3561692934 €/MW
# Expected ROI for onwind, rc 0: -0.2998953695875714%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 1: 2620431.276215778 €/MW
# Expected ROI for onwind, rc 1: 2.353897604844978%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 2: 3073611.140212139 €/MW
# Expected ROI for onwind, rc 2: 2.9729922799553212%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 3: 3453666.9311946714 €/MW
# Expected ROI for onwind, rc 3: 3.416035529854088%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 4 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 4: 3806015.2309607132 €/MW
# Expected ROI for onwind, rc 4: 3.780034947866396%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 5 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 5: 3998465.9334173235 €/MW
# Expected ROI for onwind, rc 5: 3.963250049142255%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 6 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 6: 4363534.899637499 €/MW
# Expected ROI for onwind, rc 6: 4.285345340010701%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 7 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 7: 4634495.673881591 €/MW
# Expected ROI for onwind, rc 7: 4.505771724891173%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 8 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 8: 5153013.644447655 €/MW
# Expected ROI for onwind, rc 8: 4.8908202780234555%
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 9 onwind: 1495850.7130329998 €/MW
# Annualized investment + capital costs: 3049323.6997164832 €/MW
# Average lifetime revenue per MW for onwind: 4430593.917239723 €/MW
# Average lifetime revenues per MW for onwind, rc 9: 6962203.825857054 €/MW
# Expected ROI for onwind, rc 9: 5.965978535404768%

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'offwind-ac'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
    print('-----------------------------------')
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-ac: 119011749.97415066 €/MW
# Annualized investment + capital costs: 6085155.166275688 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 0: 7820230.507286922 €/MW
# Expected ROI for offwind-ac, rc 0: 4.581983374006039%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 offwind-ac: 119027162.5270976 €/MW
# Annualized investment + capital costs: 6124831.9404777 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 1: 9332441.63885774 €/MW
# Expected ROI for offwind-ac, rc 1: 5.2649561682754715%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 offwind-ac: 119115274.84593372 €/MW
# Annualized investment + capital costs: 6351660.850062896 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 2: 10748364.833075166 €/MW
# Expected ROI for offwind-ac, rc 2: 5.798168015095164%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 offwind-ac: 118982218.77799998 €/MW
# Annualized investment + capital costs: 6009132.549800642 €/MW
# Average lifetime revenue per MW for offwind-ac: nan €/MW
# Average lifetime revenues per MW for offwind-ac, rc 3: nan €/MW
# Expected ROI for offwind-ac, rc 3: nan%
# -----------------------------------

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'offwind-dc'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    invest_fom = af.fixed_costs(run_name, n, carrier, rc, costs)
    print(f"Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 {rc} {carrier}: {invest_fom} €/MW")
    cc_full = n.generators.capital_cost[f'DE0 0 {rc} {carrier}'] * t / 35
    print(f"Annualized investment + capital costs: {cc_full} €/MW")
    avg_rev_carrier = af.avg_lifetime_revenues_mcs_carrier_per_MW(run_name, n, carrier, T=t, N=10000)
    print(f"Average lifetime revenue per MW for {carrier}: {avg_rev_carrier} €/MW")
    rev_T = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Average lifetime revenues per MW for {carrier}, rc {rc}: {rev_T} €/MW")
    roi = af.expected_roi_mcs(run_name, n, carrier, rc)
    print(f"Expected ROI for {carrier}, rc {rc}: {roi * 100 }%")
    print('-----------------------------------')
# Out:
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 0 offwind-dc: 119145132.05299999 €/MW
# Annualized investment + capital costs: 6428522.721496519 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 0: nan €/MW
# Expected ROI for offwind-dc, rc 0: nan%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 1 offwind-dc: 119272830.98397441 €/MW
# Annualized investment + capital costs: 6757260.0609597415 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 1: 10242817.924019352 €/MW
# Expected ROI for offwind-dc, rc 1: 5.617421375044238%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 2 offwind-dc: 119285656.60601264 €/MW
# Annualized investment + capital costs: 6790277.258783089 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 2: 11008443.357717419 €/MW
# Expected ROI for offwind-dc, rc 2: 5.887470056087913%
# -----------------------------------
# Fixed costs (Total Lifetime incl Investment and O&M) of DE0 0 3 offwind-dc: 119512784.55491354 €/MW
# Annualized investment + capital costs: 7374976.261896734 €/MW
# Average lifetime revenue per MW for offwind-dc: nan €/MW
# Average lifetime revenues per MW for offwind-dc, rc 3: 11325462.151123935 €/MW
# Expected ROI for offwind-dc, rc 3: 5.993184061756819%
# -----------------------------------

# %%
import importlib
importlib.reload(af)
carrier = 'onwind'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for onwind, rc 0: 79664.45767261281 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 0: 0.06395775560444539
# Standard deviation of lifetime revenues per MW for onwind, rc 1: 122900.85334593887 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 1: 0.0644767691952761
# Standard deviation of lifetime revenues per MW for onwind, rc 2: 143135.70445368916 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 2: 0.06903882604043635
# Standard deviation of lifetime revenues per MW for onwind, rc 3: 153069.23605189443 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 3: 0.06758303931385985
# Standard deviation of lifetime revenues per MW for onwind, rc 4: 172199.40357082617 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 4: 0.07007581828863237
# Standard deviation of lifetime revenues per MW for onwind, rc 5: 180702.8804769587 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 5: 0.07140525166704995
# Standard deviation of lifetime revenues per MW for onwind, rc 6: 198613.7958305833 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 6: 0.0710065081856664
# Standard deviation of lifetime revenues per MW for onwind, rc 7: 212009.027693664 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 7: 0.07116775348302773
# Standard deviation of lifetime revenues per MW for onwind, rc 8: 254835.35712389706 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 8: 0.07532431827611799
# Standard deviation of lifetime revenues per MW for onwind, rc 9: 392834.8012813255 €/MW
# Normalized std. deviation of lifetime revenues per MW for onwind, rc 9: 0.08093151293274856

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-ac'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 0: 447820.18118016835 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 0: 0.08004243071641366
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 1: 558924.3326763231 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 1: 0.07748310302003324
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 2: 655393.6868321103 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 2: 0.07661015085561583
# Standard deviation of lifetime revenues per MW for offwind-ac, rc 3: nan €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-ac, rc 3: nan

# %%
import importlib
importlib.reload(af)
carrier = 'offwind-dc'
t = 30
for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    std_dev = af.std_dev_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    print(f"Standard deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_dev} €/MW")
    avg_rev = af.avg_lifetime_revenues_mcs_per_MW(run_name, n, carrier, rc, T=t, N=10000)
    std_norm = std_dev / avg_rev
    print(f"Normalized std. deviation of lifetime revenues per MW for {carrier}, rc {rc}: {std_norm}")
# Out:
# Standard deviation of lifetime revenues per MW for offwind-dc, rc 0: 682106.1663329814 €/MW
# Normalized std. deviation of lifetime revenues per MW for offwind-dc, rc 0: 0.0760864367637472

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
for carrier in ['offwind-dc', 'onwind', 'solar', 'solar-hsat']:
    for rc in range(n.generators.index[n.generators.carrier == carrier].size):
        strike_price = af.strike_price_per_MW(costs, carrier, n, rc)
        print(f"Strike price for {carrier}, rc {rc}: {strike_price} €/MW")
# Out:
# Strike price for offwind-dc, rc 0: 214284.09071655062 €/MW
# Strike price for offwind-dc, rc 1: 225242.0020319914 €/MW
# Strike price for offwind-dc, rc 2: 226342.57529276964 €/MW
# Strike price for offwind-dc, rc 3: 245832.54206322448 €/MW
# Strike price for onwind, rc 0: 101644.12332388277 €/MW
# Strike price for onwind, rc 1: 101644.12332388277 €/MW
# Strike price for onwind, rc 2: 101644.12332388277 €/MW
# Strike price for onwind, rc 3: 101644.12332388277 €/MW
# Strike price for onwind, rc 4: 101644.12332388277 €/MW
# Strike price for onwind, rc 5: 101644.12332388277 €/MW
# Strike price for onwind, rc 6: 101644.12332388277 €/MW
# Strike price for onwind, rc 7: 101644.12332388277 €/MW
# Strike price for onwind, rc 8: 101644.12332388277 €/MW
# Strike price for onwind, rc 9: 101644.12332388277 €/MW
# Strike price for solar, rc 0: 38283.380189337135 €/MW
# Strike price for solar, rc 1: 38283.380189337135 €/MW
# Strike price for solar, rc 2: 38283.380189337135 €/MW
# Strike price for solar, rc 3: 38283.380189337135 €/MW
# Strike price for solar, rc 4: 38283.380189337135 €/MW
# Strike price for solar, rc 5: 38283.380189337135 €/MW
# Strike price for solar, rc 6: 38283.380189337135 €/MW
# Strike price for solar, rc 7: 38283.380189337135 €/MW
# Strike price for solar, rc 8: 38283.380189337135 €/MW
# Strike price for solar, rc 9: 38283.380189337135 €/MW
# Strike price for solar-hsat, rc 0: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 1: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 2: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 3: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 4: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 5: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 6: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 7: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 8: 44489.52419183134 €/MW
# Strike price for solar-hsat, rc 9: 44489.52419183134 €/MW

# %%
import importlib
importlib.reload(af)

carrier = 'onwind'
year = 2000
years = n.generators_t.p.index.year.unique()
costs = af.get_costs(run_name)

for rc in range(n.generators.index[n.generators.carrier == carrier].size):
    strike_price = af.strike_price_per_MWh(costs, carrier, n, rc)
    # rev = af.annual_revenue_per_MW(costs, carrier, year, n, rc)
    # print(f"Market-based Annual revenue for {carrier}, rc {rc} in {year}: {rev} €/MW")
    # rev_con_cfd = af.annual_revenue_con_cfd_per_MW(costs, carrier, year, n, rc, strike_price)
    # print(f"Conventional CfD revenue for {carrier}, rc {rc} in {year}: {rev_con_cfd} €/MW")
    # rev_fin_cfd = af.annual_revenue_fin_cfd_per_MW(costs, carrier, year, n, rc, strike_price)
    # print(f"Financial CfD revenue for {carrier}, rc {rc} in {year}: {rev_fin_cfd} €/MW")
    # print('.......................................')
    capital_cost = n.generators.capital_cost[f'DE0 0 {rc} {carrier}']
    print(f"Capital cost for {carrier}, rc {rc}: {capital_cost} €/MW")
    rev_tot = sum([af.annual_revenue_per_MW(costs, carrier, y, n, rc) for y in years])
    print(f"Total market-based revenue for {carrier}, rc {rc} over all years: {rev_tot} €/MW")
    rev_con_cfd_tot = sum([af.annual_revenue_con_cfd_per_MW(costs, carrier, y, n, rc, strike_price) for y in years])
    print(f"Total conventional CfD revenue for {carrier}, rc {rc} over all years: {rev_con_cfd_tot} €/MW")
    rev_fin_cfd_tot = sum([af.annual_revenue_fin_cfd_per_MW(costs, carrier, y, n, rc, strike_price) for y in years])
    print(f"Total financial CfD revenue for {carrier}, rc {rc} over all years: {rev_fin_cfd_tot} €/MW")
    print('-----------------------------------')
# Out:
# Capital cost for onwind, rc 0: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 0 over all years: 1232525.759111582 €/MW
# Total conventional CfD revenue for onwind, rc 0 over all years: 3533457.6058166362 €/MW
# Total financial CfD revenue for onwind, rc 0 over all years: 17712900.369935524 €/MW
# -----------------------------------
# Capital cost for onwind, rc 1: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 1 over all years: 2266878.98181007 €/MW
# Total conventional CfD revenue for onwind, rc 1 over all years: 3505450.6073090183 €/MW
# Total financial CfD revenue for onwind, rc 1 over all years: 9826556.325886596 €/MW
# -----------------------------------
# Capital cost for onwind, rc 2: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 2 over all years: 2528155.1353878947 €/MW
# Total conventional CfD revenue for onwind, rc 2 over all years: 3495349.2150755962 €/MW
# Total financial CfD revenue for onwind, rc 2 over all years: 8841784.451989355 €/MW
# -----------------------------------
# Capital cost for onwind, rc 3: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 3 over all years: 2796721.3973040585 €/MW
# Total conventional CfD revenue for onwind, rc 3 over all years: 3483888.7021149383 €/MW
# Total financial CfD revenue for onwind, rc 3 over all years: 8110495.7014073385 €/MW
# -----------------------------------
# Capital cost for onwind, rc 4: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 4 over all years: 3012929.772192646 €/MW
# Total conventional CfD revenue for onwind, rc 4 over all years: 3473633.4865072537 €/MW
# Total financial CfD revenue for onwind, rc 4 over all years: 7663547.729819507 €/MW
# -----------------------------------
# Capital cost for onwind, rc 5: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 5 over all years: 3134383.442622863 €/MW
# Total conventional CfD revenue for onwind, rc 5 over all years: 3469721.820976288 €/MW
# Total financial CfD revenue for onwind, rc 5 over all years: 7572856.336714567 €/MW
# -----------------------------------
# Capital cost for onwind, rc 6: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 6 over all years: 3463593.168670448 €/MW
# Total conventional CfD revenue for onwind, rc 6 over all years: 3462118.847652248 €/MW
# Total financial CfD revenue for onwind, rc 6 over all years: 7539482.2608936215 €/MW
# -----------------------------------
# Capital cost for onwind, rc 7: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 7 over all years: 3662811.156547265 €/MW
# Total conventional CfD revenue for onwind, rc 7 over all years: 3457212.194978234 €/MW
# Total financial CfD revenue for onwind, rc 7 over all years: 7533878.520404613 €/MW
# -----------------------------------
# Capital cost for onwind, rc 8: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 8 over all years: 4107421.2987086526 €/MW
# Total conventional CfD revenue for onwind, rc 8 over all years: 3448646.593365514 €/MW
# Total financial CfD revenue for onwind, rc 8 over all years: 7665164.35825542 €/MW
# -----------------------------------
# Capital cost for onwind, rc 9: 3557544.316335897 €/MW
# Total market-based revenue for onwind, rc 9 over all years: 5764649.374134543 €/MW
# Total conventional CfD revenue for onwind, rc 9 over all years: 3408889.5850176574 €/MW
# Total financial CfD revenue for onwind, rc 9 over all years: 8340845.279825741 €/MW
# -----------------------------------

# %%
year = 2000
carrier = 'onwind'
rc = 9
hg = af.get_hourly_generation(carrier, n, rc)
print(hg)
print('____________________________')
hg_year = hg[hg.index.year == year]
print(hg_year)
print('____________________________')
print(hg_year.values)
print(hg_year.values.sum())
# Out:
# snapshot
# 1982-01-01 00:00:00     5025.617648
# 1982-01-01 01:00:00     4545.337912
# 1982-01-01 02:00:00     4288.858902
# 1982-01-01 03:00:00     4240.467835
# 1982-01-01 04:00:00     3764.344087
#                            ...
# 2016-12-31 19:00:00    15684.415558
# 2016-12-31 20:00:00    15774.134343
# 2016-12-31 21:00:00    15782.358007
# 2016-12-31 22:00:00    15306.479209
# 2016-12-31 23:00:00    15595.239057
# Name: DE0 0 9 onwind, Length: 306600, dtype: float64
# ____________________________
# snapshot
# 2000-01-01 00:00:00    3031.792815
# 2000-01-01 01:00:00    3414.255961
# 2000-01-01 02:00:00    3609.850793
# 2000-01-01 03:00:00    4003.407405
# 2000-01-01 04:00:00    4518.664515
#                           ...
# 2000-12-31 19:00:00    4546.545429
# 2000-12-31 20:00:00    4774.522363
# 2000-12-31 21:00:00    5129.732879
# 2000-12-31 22:00:00    6004.763968
# 2000-12-31 23:00:00    5624.841536
# Name: DE0 0 9 onwind, Length: 8760, dtype: float64
# ____________________________
# [3031.79281537 3414.25596081 3609.85079314 ... 5129.73287916 6004.7639679
#  5624.84153596]
# 51475537.516917855

# %%
import importlib
importlib.reload(af)
costs = af.get_costs(run_name)
carrier = 'onwind'
rc = 7
year = 2014
rev_mb = af.annual_revenue_per_MW(costs, carrier, year, n, rc)
print(f"Market-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_mb} €/MW")
print('-----------------------------------')
strike_price_pb = af.strike_price_PB(costs, carrier, n, rc)
rev_pb = af.annual_revenue_PB_per_MW(costs, carrier, year, n, rc, strike_price_pb)
print(f"Production-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_pb} €/MW")
print('-----------------------------------')
strike_price_pi = af.strike_price_PI(costs, carrier, n, rc)
rev_pi = af.annual_revenue_PI_per_MW(costs, carrier, year, n, rc, strike_price_pi)
print(f"Production-independent Annual revenue for {carrier}, rc {rc} in {year}: {rev_pi} €/MW")
print('-----------------------------------')
strike_price_cb = af.strike_price_CB(costs, carrier, n, rc)
rev_cb = af.annual_revenue_CB_per_MW(costs, carrier, year, n, rc, strike_price_cb)
print(f"Capacity-based Annual revenue for {carrier}, rc {rc} in {year}: {rev_cb} €/MW")
print('-----------------------------------')
# Out:
# Market-based Annual revenue for onwind, rc 7 in 2014: 148660.56465945707 €/MW
# -----------------------------------
# Production-based Annual revenue for onwind, rc 7 in 2014: 100973.11884594103 €/MW
# -----------------------------------
# Production-independent Annual revenue for onwind, rc 7 in 2014: 91446.8354910319 €/MW
# -----------------------------------
# Capacity-based Annual revenue for onwind, rc 7 in 2014: -26154.302745327954 €/MW
# -----------------------------------
